# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
from IPython.display import display

from pkdb_analysis import PKData, PKFilter
from pkdb_analysis.tests.constants import TEST_HDF5

# %% [markdown]
# # Working with PK-DB data
# To easily work with PK-DB data we provide the `pkdb_analysis` python library.
# These includes helper functions for querying data and filter existing data sets. In the following we provide an overview over the typical functionality when working with PK-DB data.

# %% [markdown]
# The main class to work with is `PKData`. It is possible to directly query the database or to load data from file.
#
# ## Load data from file
# PKData can be serialized to HDF5 files. In the following we will load the test data set and print an overview.

# %%
from pkdb_analysis import PKData, PKFilter
from pkdb_analysis.tests.constants import TEST_HDF5

data = PKData.from_hdf5(TEST_HDF5)
print(data)
# Out:
# INFO Note: NumExpr detected 32 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO NumExpr defaulting to 8 threads.
# ------------------------------
# PKData (140432779705360)
# ------------------------------
# studies             4
# groups              8  (   86)
# individuals       246  ( 3144)
# interventions      18  (   18)
# outputs          1064  ( 1106)
# timecourses        40  (   46)
# ------------------------------

# %% [markdown]
# ## Load data from database
# Alternatively data can be loaded from the database using the `PKDB.query()` function.
# This is documented in the `Querying PK-DB` section.

# %% [markdown]
# ## Accessing groups, individuals, interventions, outputs and timecourses
# All PKData consists of consistent information on:
# - `studies`: PK-DB studies, uniquely identified via a `study_sid`
# - `groups`: groups, uniquely identified via `group_pk`
# - `individuals`: individuals, uniquely identified via `individual_pk`
# - `interventions`: interventions, uniquely identified via `intervention_pk`
# - `outputs`: outputs, uniquely identified via `output_pk`
# - `timecourses`: groups, uniquely identified via `timecourse_pk`
#
# The `print` function provides a simple overview over the content

# %%
print(data)
# Out:
# ------------------------------
# PKData (140432779705360)
# ------------------------------
# studies             4
# groups              8  (   86)
# individuals       246  ( 3144)
# interventions      18  (   18)
# outputs          1064  ( 1106)
# timecourses        40  (   46)
# ------------------------------

# %% [markdown]
# We can access the information via the respective fields, e.g., groups via `data.groups` or the multi-index data via `data.groups_mi`.

# %%
data.groups
# Out:
#     study_sid study_name  group_pk group_name  group_count  group_parent_pk  \
# 0   PKDB99997      Test3        26        all            2               -1
# 1   PKDB99997      Test3        26        all            2               -1
# 2   PKDB99997      Test3        26        all            2               -1
# 3   PKDB99997      Test3        26        all            2               -1
# 4   PKDB99999      Test1        20        all            6               -1
# ..        ...        ...       ...        ...          ...              ...
# 81  PKDB99998      Test2        25      80-90           10               21
# 82  PKDB99998      Test2        25      80-90           10               21
# 83  PKDB99998      Test2        25      80-90           10               21
# 84  PKDB99998      Test2        25      80-90           10               21
# 85  PKDB99998      Test2        25      80-90           10               21
#
#     characteristica_pk  count measurement_type        choice substance  value  \
# 0                 1068      2       abstinence          None     cocoa    NaN
# 1                 1067      2       abstinence          None       tea    NaN
# 2                 1066      2       abstinence          None    coffee    NaN
# 3                 1065      2          species  homo sapiens      None    NaN
# 4                  481      6          species  homo sapiens      None    NaN
# ..                 ...    ...              ...           ...       ...    ...
# 81                 523     40       medication             N      None    NaN
# 82                 584     10              gfr          None      None    NaN
# 83                 526     40        ethnicity     caucasian      None    NaN
# 84                 527     38          smoking             N      None    NaN
# 85                 528      2          smoking             Y      None    NaN
#
#         mean  median  min  max         sd  se  cv  \
# 0        NaN     NaN  NaN  NaN        NaN NaN NaN
# 1        NaN     NaN  NaN  NaN        NaN NaN NaN
# 2        NaN     NaN  NaN  NaN        NaN NaN NaN
# 3        NaN     NaN  NaN  NaN        NaN NaN NaN
# 4        NaN     NaN  NaN  NaN        NaN NaN NaN
# ..       ...     ...  ...  ...        ...  ..  ..
# 81       NaN     NaN  NaN  NaN        NaN NaN NaN
# 82  36.99422     NaN  NaN  NaN  10.982659 NaN NaN
# 83       NaN     NaN  NaN  NaN        NaN NaN NaN
# 84       NaN     NaN  NaN  NaN        NaN NaN NaN
# 85       NaN     NaN  NaN  NaN        NaN NaN NaN
#
#                                 unit
# 0                               None
# 1                               None
# 2                               None
# 3                               None
# 4                               None
# ..                               ...
# 81                              None
# 82  milliliter / meter ** 2 / minute
# 83                              None
# 84                              None
# 85                              None
#
# [86 rows x 20 columns]

# %%
data.groups_mi
# Out:
#                              study_sid study_name group_name  group_count  \
# group_pk characteristica_pk
# 20       481                 PKDB99999      Test1        all            6
#          482                 PKDB99999      Test1        all            6
#          483                 PKDB99999      Test1        all            6
#          484                 PKDB99999      Test1        all            6
#          485                 PKDB99999      Test1        all            6
# ...                                ...        ...        ...          ...
# 27       1086                PKDB99996      Test4        all           16
#          1087                PKDB99996      Test4        all           16
#          1088                PKDB99996      Test4        all           16
#          1089                PKDB99996      Test4        all           16
#          1090                PKDB99996      Test4        all           16
#
#                              group_parent_pk  count measurement_type  \
# group_pk characteristica_pk
# 20       481                              -1      6          species
#          482                              -1      6          healthy
#          483                              -1      1          smoking
#          484                              -1      5          smoking
#          485                              -1      6              age
# ...                                      ...    ...              ...
# 27       1086                             -1     16          alcohol
#          1087                             -1     16           weight
#          1088                             -1     16              age
#          1089                             -1     16        ethnicity
#          1090                             -1     16   overnight fast
#
#                                    choice substance  value  mean  median  \
# group_pk characteristica_pk
# 20       481                 homo sapiens      None    NaN   NaN     NaN
#          482                            Y      None    NaN   NaN     NaN
#          483                            Y      None    NaN   NaN     NaN
#          484                            N      None    NaN   NaN     NaN
#          485                         None      None    NaN   NaN     NaN
# ...                                   ...       ...    ...   ...     ...
# 27       1086                           N      None    NaN   NaN     NaN
#          1087                        None      None    NaN  76.7     NaN
#          1088                        None      None    NaN  27.1     NaN
#          1089                          NR      None    NaN   NaN     NaN
#          1090                           Y      None    NaN   NaN     NaN
#
#                               min   max   sd  se  cv      unit
# group_pk characteristica_pk
# 20       481                  NaN   NaN  NaN NaN NaN      None
#          482                  NaN   NaN  NaN NaN NaN      None
#          483                  NaN   NaN  NaN NaN NaN      None
#          484                  NaN   NaN  NaN NaN NaN      None
#          485                 25.0  37.0  NaN NaN NaN        yr
# ...                           ...   ...  ...  ..  ..       ...
# 27       1086                 NaN   NaN  NaN NaN NaN      None
#          1087                 NaN   NaN  6.8 NaN NaN  kilogram
#          1088                 NaN   NaN  3.1 NaN NaN        yr
#          1089                 NaN   NaN  NaN NaN NaN      None
#          1090                 NaN   NaN  NaN NaN NaN      None
#
# [86 rows x 18 columns]

# %% [markdown]
# To access the number of items use the `*_count`.

# %%
print(f"Number of groups: {data.groups_count}")
# Out:
# Number of groups: 8

# %% [markdown]
# The `groups`, `individuals`, `interventions`, `outputs` and `timecourses` are `pandas.DataFrame` instances, so all the classical pandas operations can be applied on the data.
# For instance to access a single `group` use logical indexing by the `group_pk` field.
# E.g. to get the group `20` use

# %%
data.groups[data.groups.group_pk==20]
# Out:
#    study_sid study_name  group_pk group_name  group_count  group_parent_pk  \
# 4  PKDB99999      Test1        20        all            6               -1
# 5  PKDB99999      Test1        20        all            6               -1
# 6  PKDB99999      Test1        20        all            6               -1
# 7  PKDB99999      Test1        20        all            6               -1
# 8  PKDB99999      Test1        20        all            6               -1
# 9  PKDB99999      Test1        20        all            6               -1
#
#    characteristica_pk  count measurement_type        choice substance  value  \
# 4                 481      6          species  homo sapiens      None    NaN
# 5                 482      6          healthy             Y      None    NaN
# 6                 483      1          smoking             Y      None    NaN
# 7                 484      5          smoking             N      None    NaN
# 8                 485      6              age          None      None    NaN
# 9                 486      6   overnight fast             Y      None    NaN
#
#    mean  median   min   max  sd  se  cv  unit
# 4   NaN     NaN   NaN   NaN NaN NaN NaN  None
# 5   NaN     NaN   NaN   NaN NaN NaN NaN  None
# 6   NaN     NaN   NaN   NaN NaN NaN NaN  None
# 7   NaN     NaN   NaN   NaN NaN NaN NaN  None
# 8   NaN     NaN  25.0  37.0 NaN NaN NaN    yr
# 9   NaN     NaN   NaN   NaN NaN NaN NaN  None

# %% [markdown]
# In the group tables multiple rows exist which belong to a single group! This is important to understand filtering of the data later on. For instance in this example the information on `species`, `healthy`, `smoking`, `age` and `overnight_fast` are all separate rows in the `groups` table, but belong to a single row.
#
# When looking at the multi-index table this becomes more clear. We now get the group 20 form the `groups_mi`. We can simply use the `.loc` to lookup the group by `pk`

# %%
data.groups_mi.loc[20]
# Out:
#                     study_sid study_name group_name  group_count  \
# characteristica_pk
# 481                 PKDB99999      Test1        all            6
# 482                 PKDB99999      Test1        all            6
# 483                 PKDB99999      Test1        all            6
# 484                 PKDB99999      Test1        all            6
# 485                 PKDB99999      Test1        all            6
# 486                 PKDB99999      Test1        all            6
#
#                     group_parent_pk  count measurement_type        choice  \
# characteristica_pk
# 481                              -1      6          species  homo sapiens
# 482                              -1      6          healthy             Y
# 483                              -1      1          smoking             Y
# 484                              -1      5          smoking             N
# 485                              -1      6              age          None
# 486                              -1      6   overnight fast             Y
#
#                    substance  value  mean  median   min   max  sd  se  cv  \
# characteristica_pk
# 481                     None    NaN   NaN     NaN   NaN   NaN NaN NaN NaN
# 482                     None    NaN   NaN     NaN   NaN   NaN NaN NaN NaN
# 483                     None    NaN   NaN     NaN   NaN   NaN NaN NaN NaN
# 484                     None    NaN   NaN     NaN   NaN   NaN NaN NaN NaN
# 485                     None    NaN   NaN     NaN  25.0  37.0 NaN NaN NaN
# 486                     None    NaN   NaN     NaN   NaN   NaN NaN NaN NaN
#
#                     unit
# characteristica_pk
# 481                 None
# 482                 None
# 483                 None
# 484                 None
# 485                   yr
# 486                 None

# %% [markdown]
# In a similar manner we can explore the other information, i.e. `individuals`, `interventions`, `outputs` and `timecourses`.

# %%
data.individuals_mi
# Out:
#                                   study_sid study_name individual_name  \
# individual_pk characteristica_pk
# 39            481                 PKDB99999      Test1              WS
#               482                 PKDB99999      Test1              WS
#               483                 PKDB99999      Test1              WS
#               484                 PKDB99999      Test1              WS
#               486                 PKDB99999      Test1              WS
# ...                                     ...        ...             ...
# 283           1068                PKDB99997      Test3            H.C.
# 284           1065                PKDB99997      Test3            F.M.
#               1066                PKDB99997      Test3            F.M.
#               1067                PKDB99997      Test3            F.M.
#               1068                PKDB99997      Test3            F.M.
#
#                                   individual_group_pk  count measurement_type  \
# individual_pk characteristica_pk
# 39            481                                  20      6          species
#               482                                  20      6          healthy
#               483                                  20      1          smoking
#               484                                  20      5          smoking
#               486                                  20      6   overnight fast
# ...                                               ...    ...              ...
# 283           1068                                 26      2       abstinence
# 284           1065                                 26      2          species
#               1066                                 26      2       abstinence
#               1067                                 26      2       abstinence
#               1068                                 26      2       abstinence
#
#                                         choice substance  value  mean  median  \
# individual_pk characteristica_pk
# 39            481                 homo sapiens      None    NaN   NaN     NaN
#               482                            Y      None    NaN   NaN     NaN
#               483                            Y      None    NaN   NaN     NaN
#               484                            N      None    NaN   NaN     NaN
#               486                            Y      None    NaN   NaN     NaN
# ...                                        ...       ...    ...   ...     ...
# 283           1068                        None     cocoa    NaN   NaN     NaN
# 284           1065                homo sapiens      None    NaN   NaN     NaN
#               1066                        None    coffee    NaN   NaN     NaN
#               1067                        None       tea    NaN   NaN     NaN
#               1068                        None     cocoa    NaN   NaN     NaN
#
#                                   min  max  sd  se  cv  unit
# individual_pk characteristica_pk
# 39            481                 NaN  NaN NaN NaN NaN  None
#               482                 NaN  NaN NaN NaN NaN  None
#               483                 NaN  NaN NaN NaN NaN  None
#               484                 NaN  NaN NaN NaN NaN  None
#               486                 NaN  NaN NaN NaN NaN  None
# ...                               ...  ...  ..  ..  ..   ...
# 283           1068                NaN  NaN NaN NaN NaN  None
# 284           1065                NaN  NaN NaN NaN NaN  None
#               1066                NaN  NaN NaN NaN NaN  None
#               1067                NaN  NaN NaN NaN NaN  None
#               1068                NaN  NaN NaN NaN NaN  None
#
# [3144 rows x 17 columns]

# %%
data.interventions_mi
# Out:
#                  study_sid study_name  raw_pk  normed                  name  \
# intervention_pk
# 91               PKDB99999      Test1      -1   False                  po75
# 92               PKDB99999      Test1      -1   False                  po15
# 93               PKDB99999      Test1      91    True                  po75
# 94               PKDB99999      Test1      92    True                  po15
# 95               PKDB99999      Test1      -1   False                    iv
# 96               PKDB99999      Test1      95    True                    iv
# 97               PKDB99998      Test2      -1   False  paracetamol1000mg_iv
# 98               PKDB99998      Test2      97    True  paracetamol1000mg_iv
# 99               PKDB99997      Test3      -1   False           theobromine
# 100              PKDB99997      Test3      99    True           theobromine
# 101              PKDB99997      Test3      -1   False          theophylline
# 102              PKDB99997      Test3     101    True          theophylline
# 103              PKDB99997      Test3      -1   False              caffeine
# 104              PKDB99997      Test3     103    True              caffeine
# 105              PKDB99996      Test4      -1   False                  Dcaf
# 106              PKDB99996      Test4     105    True                  Dcaf
# 107              PKDB99996      Test4      -1   False                  Dlom
# 108              PKDB99996      Test4     107    True                  Dlom
#
#                 route      form        application  time time_unit  ...  \
# intervention_pk                                                     ...
# 91               oral    tablet        single dose   0.0        hr  ...
# 92               oral    tablet        single dose   0.0        hr  ...
# 93               oral    tablet        single dose   0.0        hr  ...
# 94               oral    tablet        single dose   0.0        hr  ...
# 95                 iv  solution        single dose   0.0        hr  ...
# 96                 iv  solution        single dose   0.0        hr  ...
# 97                 iv  solution  constant infusion   0.0       min  ...
# 98                 iv  solution  constant infusion   0.0       min  ...
# 99               oral      None               None   0.0        hr  ...
# 100              oral      None               None   0.0        hr  ...
# 101              oral      None               None   0.0        hr  ...
# 102              oral      None               None   0.0        hr  ...
# 103              oral      None               None   0.0        hr  ...
# 104              oral      None               None   0.0        hr  ...
# 105              oral    tablet        single dose   0.0        hr  ...
# 106              oral    tablet        single dose   0.0        hr  ...
# 107              oral   capsule      multiple dose   NaN      None  ...
# 108              oral   capsule      multiple dose   NaN      None  ...
#
#                     substance        value mean  median  min  max  sd  se  cv  \
# intervention_pk
# 91                  midazolam     7.500000  NaN     NaN  NaN  NaN NaN NaN NaN
# 92                  midazolam    15.000000  NaN     NaN  NaN  NaN NaN NaN NaN
# 93                  midazolam     0.007500  NaN     NaN  NaN  NaN NaN NaN NaN
# 94                  midazolam     0.015000  NaN     NaN  NaN  NaN NaN NaN NaN
# 95                  midazolam     0.075000  NaN     NaN  NaN  NaN NaN NaN NaN
# 96                  midazolam     0.000075  NaN     NaN  NaN  NaN NaN NaN NaN
# 97                paracetamol  1000.000000  NaN     NaN  NaN  NaN NaN NaN NaN
# 98                paracetamol     1.000000  NaN     NaN  NaN  NaN NaN NaN NaN
# 99                theobromine     1.000000  NaN     NaN  NaN  NaN NaN NaN NaN
# 100               theobromine     1.000000  NaN     NaN  NaN  NaN NaN NaN NaN
# 101              theophylline     1.000000  NaN     NaN  NaN  NaN NaN NaN NaN
# 102              theophylline     1.000000  NaN     NaN  NaN  NaN NaN NaN NaN
# 103                  caffeine     1.000000  NaN     NaN  NaN  NaN NaN NaN NaN
# 104                  caffeine     1.000000  NaN     NaN  NaN  NaN NaN NaN NaN
# 105                  caffeine   200.000000  NaN     NaN  NaN  NaN NaN NaN NaN
# 106                  caffeine     0.200000  NaN     NaN  NaN  NaN NaN NaN NaN
# 107              lomefloxacin   400.000000  NaN     NaN  NaN  NaN NaN NaN NaN
# 108              lomefloxacin     0.400000  NaN     NaN  NaN  NaN NaN NaN NaN
#
#                             unit
# intervention_pk
# 91                            mg
# 92                            mg
# 93                          gram
# 94                          gram
# 95                         mg/kg
# 96               gram / kilogram
# 97                            mg
# 98                          gram
# 99                             g
# 100                         gram
# 101                            g
# 102                         gram
# 103                            g
# 104                         gram
# 105                           mg
# 106                         gram
# 107                           mg
# 108                         gram
#
# [18 rows x 22 columns]

# %%
data.outputs_mi
# Out:
#                                                   study_sid study_name  \
# output_pk intervention_pk group_pk individual_pk
# 1409      96              -1        39            PKDB99999      Test1
# 1410      96              -1        39            PKDB99999      Test1
# 1411      96              -1        39            PKDB99999      Test1
# 1412      96              -1        39            PKDB99999      Test1
# 1413      96              -1        39            PKDB99999      Test1
# ...                                                     ...        ...
# 2604      108              27      -1             PKDB99996      Test4
# 2605      106              27      -1             PKDB99996      Test4
#           108              27      -1             PKDB99996      Test4
# 2606      106              27      -1             PKDB99996      Test4
#           108              27      -1             PKDB99996      Test4
#
#                                                   normed  calculated  tissue  \
# output_pk intervention_pk group_pk individual_pk
# 1409      96              -1        39             False       False  plasma
# 1410      96              -1        39             False       False  plasma
# 1411      96              -1        39             False       False  plasma
# 1412      96              -1        39             False       False  plasma
# 1413      96              -1        39             False       False  plasma
# ...                                                  ...         ...     ...
# 2604      108              27      -1               True        True  plasma
# 2605      106              27      -1               True        True  plasma
#           108              27      -1               True        True  plasma
# 2606      106              27      -1               True        True  plasma
#           108              27      -1               True        True  plasma
#
#                                                   time time_unit  \
# output_pk intervention_pk group_pk individual_pk
# 1409      96              -1        39             NaN      None
# 1410      96              -1        39             NaN      None
# 1411      96              -1        39             NaN      None
# 1412      96              -1        39             NaN      None
# 1413      96              -1        39             NaN      None
# ...                                                ...       ...
# 2604      108              27      -1              NaN      None
# 2605      106              27      -1              NaN      None
#           108              27      -1              NaN      None
# 2606      106              27      -1              NaN      None
#           108              27      -1              NaN      None
#
#                                                    measurement_type choice  \
# output_pk intervention_pk group_pk individual_pk
# 1409      96              -1        39                        thalf   None
# 1410      96              -1        39                           vd   None
# 1411      96              -1        39                    clearance   None
# 1412      96              -1        39            clearance_unbound   None
# 1413      96              -1        39               plasma_binding   None
# ...                                                             ...    ...
# 2604      108              27      -1                         thalf   None
# 2605      106              27      -1                            vd   None
#           108              27      -1                            vd   None
# 2606      106              27      -1                          tmax   None
#           108              27      -1                          tmax   None
#
#                                                      substance    value  \
# output_pk intervention_pk group_pk individual_pk
# 1409      96              -1        39               midazolam     2.30
# 1410      96              -1        39               midazolam     0.71
# 1411      96              -1        39               midazolam   292.00
# 1412      96              -1        39               midazolam  5840.00
# 1413      96              -1        39               midazolam    95.00
# ...                                                        ...      ...
# 2604      108              27      -1             paraxanthine      NaN
# 2605      106              27      -1             paraxanthine      NaN
#           108              27      -1             paraxanthine      NaN
# 2606      106              27      -1             paraxanthine      NaN
#           108              27      -1             paraxanthine      NaN
#
#                                                    mean  median  min  max  sd  \
# output_pk intervention_pk group_pk individual_pk
# 1409      96              -1        39              NaN     NaN  NaN  NaN NaN
# 1410      96              -1        39              NaN     NaN  NaN  NaN NaN
# 1411      96              -1        39              NaN     NaN  NaN  NaN NaN
# 1412      96              -1        39              NaN     NaN  NaN  NaN NaN
# 1413      96              -1        39              NaN     NaN  NaN  NaN NaN
# ...                                                 ...     ...  ...  ...  ..
# 2604      108              27      -1              9.36     NaN  NaN  NaN NaN
# 2605      106              27      -1             90.30     NaN  NaN  NaN NaN
#           108              27      -1             90.30     NaN  NaN  NaN NaN
# 2606      106              27      -1              6.00     NaN  NaN  NaN NaN
#           108              27      -1              6.00     NaN  NaN  NaN NaN
#
#                                                   se  cv     unit
# output_pk intervention_pk group_pk individual_pk
# 1409      96              -1        39           NaN NaN       hr
# 1410      96              -1        39           NaN NaN     l/kg
# 1411      96              -1        39           NaN NaN   ml/min
# 1412      96              -1        39           NaN NaN   ml/min
# 1413      96              -1        39           NaN NaN  percent
# ...                                               ..  ..      ...
# 2604      108              27      -1            NaN NaN     hour
# 2605      106              27      -1            NaN NaN    liter
#           108              27      -1            NaN NaN    liter
# 2606      106              27      -1            NaN NaN     hour
#           108              27      -1            NaN NaN     hour
#
# [1106 rows x 19 columns]

# %%
data.timecourses_mi
# Out:
#                                                       study_sid study_name  \
# timecourse_pk intervention_pk group_pk individual_pk
# 67            96              20       -1             PKDB99999      Test1
# 68            94              20       -1             PKDB99999      Test1
# 69            96              20       -1             PKDB99999      Test1
# 70            94              20       -1             PKDB99999      Test1
# 71            98              22       -1             PKDB99998      Test2
# 72            98              22       -1             PKDB99998      Test2
# 73            98              22       -1             PKDB99998      Test2
# 74            98              23       -1             PKDB99998      Test2
# 75            98              23       -1             PKDB99998      Test2
# 76            98              23       -1             PKDB99998      Test2
# 77            98              24       -1             PKDB99998      Test2
# 78            98              24       -1             PKDB99998      Test2
# 79            98              24       -1             PKDB99998      Test2
# 80            98              25       -1             PKDB99998      Test2
# 81            98              25       -1             PKDB99998      Test2
# 82            98              25       -1             PKDB99998      Test2
# 83            98              22       -1             PKDB99998      Test2
# 84            98              22       -1             PKDB99998      Test2
# 85            98              22       -1             PKDB99998      Test2
# 86            98              23       -1             PKDB99998      Test2
# 87            98              23       -1             PKDB99998      Test2
# 88            98              23       -1             PKDB99998      Test2
# 89            98              24       -1             PKDB99998      Test2
# 90            98              24       -1             PKDB99998      Test2
# 91            98              24       -1             PKDB99998      Test2
# 92            98              25       -1             PKDB99998      Test2
# 93            98              25       -1             PKDB99998      Test2
# 94            98              25       -1             PKDB99998      Test2
# 95            106             27       -1             PKDB99996      Test4
# 96            106             27       -1             PKDB99996      Test4
#               108             27       -1             PKDB99996      Test4
# 97            106             27       -1             PKDB99996      Test4
# 98            106             27       -1             PKDB99996      Test4
#               108             27       -1             PKDB99996      Test4
# 99            106             27       -1             PKDB99996      Test4
# 100           106             27       -1             PKDB99996      Test4
#               108             27       -1             PKDB99996      Test4
# 101           106             27       -1             PKDB99996      Test4
# 102           106             27       -1             PKDB99996      Test4
#               108             27       -1             PKDB99996      Test4
# 103           106             27       -1             PKDB99996      Test4
# 104           106             27       -1             PKDB99996      Test4
#               108             27       -1             PKDB99996      Test4
# 105           106             27       -1             PKDB99996      Test4
# 106           106             27       -1             PKDB99996      Test4
#               108             27       -1             PKDB99996      Test4
#
#                                                       normed  tissue  \
# timecourse_pk intervention_pk group_pk individual_pk
# 67            96              20       -1              False  plasma
# 68            94              20       -1              False  plasma
# 69            96              20       -1               True  plasma
# 70            94              20       -1               True  plasma
# 71            98              22       -1              False  plasma
# 72            98              22       -1              False  plasma
# 73            98              22       -1              False  plasma
# 74            98              23       -1              False  plasma
# 75            98              23       -1              False  plasma
# 76            98              23       -1              False  plasma
# 77            98              24       -1              False  plasma
# 78            98              24       -1              False  plasma
# 79            98              24       -1              False  plasma
# 80            98              25       -1              False  plasma
# 81            98              25       -1              False  plasma
# 82            98              25       -1              False  plasma
# 83            98              22       -1               True  plasma
# 84            98              22       -1               True  plasma
# 85            98              22       -1               True  plasma
# 86            98              23       -1               True  plasma
# 87            98              23       -1               True  plasma
# 88            98              23       -1               True  plasma
# 89            98              24       -1               True  plasma
# 90            98              24       -1               True  plasma
# 91            98              24       -1               True  plasma
# 92            98              25       -1               True  plasma
# 93            98              25       -1               True  plasma
# 94            98              25       -1               True  plasma
# 95            106             27       -1              False  plasma
# 96            106             27       -1              False  plasma
#               108             27       -1              False  plasma
# 97            106             27       -1               True  plasma
# 98            106             27       -1               True  plasma
#               108             27       -1               True  plasma
# 99            106             27       -1              False  plasma
# 100           106             27       -1              False  plasma
#               108             27       -1              False  plasma
# 101           106             27       -1               True  plasma
# 102           106             27       -1               True  plasma
#               108             27       -1               True  plasma
# 103           106             27       -1              False  plasma
# 104           106             27       -1              False  plasma
#               108             27       -1              False  plasma
# 105           106             27       -1               True  plasma
# 106           106             27       -1               True  plasma
#               108             27       -1               True  plasma
#
#                                                                                                    time  \
# timecourse_pk intervention_pk group_pk individual_pk
# 67            96              20       -1             [0.0, 0.17, 0.33, 0.5, 0.75, 1.0, 1.5, 2.0, 3....
# 68            94              20       -1             [0.17, 0.33, 0.75, 1.0, 1.5, 2.0, 2.5, 3.0, 4....
# 69            96              20       -1             [0.0, 0.17, 0.33, 0.5, 0.75, 1.0, 1.5, 2.0, 3....
# 70            94              20       -1             [0.17, 0.33, 0.75, 1.0, 1.5, 2.0, 2.5, 3.0, 4....
# 71            98              22       -1             [0.0, 0.125, 0.25, 0.292, 0.333, 0.417, 0.5, 0...
# 72            98              22       -1             [0.0, 0.125, 0.25, 0.292, 0.333, 0.417, 0.5, 0...
# 73            98              22       -1             [0.0, 0.125, 0.25, 0.292, 0.333, 0.417, 0.5, 0...
# 74            98              23       -1             [0.0, 0.125, 0.25, 0.292, 0.333, 0.417, 0.5, 0...
# 75            98              23       -1             [0.0, 0.125, 0.25, 0.292, 0.333, 0.417, 0.5, 0...
# 76            98              23       -1             [0.0, 0.125, 0.25, 0.292, 0.333, 0.417, 0.5, 0...
# 77            98              24       -1             [0.0, 0.125, 0.25, 0.292, 0.333, 0.417, 0.5, 0...
# 78            98              24       -1             [0.0, 0.125, 0.25, 0.292, 0.333, 0.417, 0.5, 0...
# 79            98              24       -1             [0.0, 0.125, 0.25, 0.292, 0.333, 0.417, 0.5, 0...
# 80            98              25       -1             [0.0, 0.125, 0.25, 0.292, 0.333, 0.417, 0.5, 0...
# 81            98              25       -1             [0.0, 0.125, 0.25, 0.292, 0.333, 0.417, 0.5, 0...
# 82            98              25       -1             [0.0, 0.125, 0.25, 0.292, 0.333, 0.417, 0.5, 0...
# 83            98              22       -1             [0.0, 0.125, 0.25, 0.292, 0.333, 0.417, 0.5, 0...
# 84            98              22       -1             [0.0, 0.125, 0.25, 0.292, 0.333, 0.417, 0.5, 0...
# 85            98              22       -1             [0.0, 0.125, 0.25, 0.292, 0.333, 0.417, 0.5, 0...
# 86            98              23       -1             [0.0, 0.125, 0.25, 0.292, 0.333, 0.417, 0.5, 0...
# 87            98              23       -1             [0.0, 0.125, 0.25, 0.292, 0.333, 0.417, 0.5, 0...
# 88            98              23       -1             [0.0, 0.125, 0.25, 0.292, 0.333, 0.417, 0.5, 0...
# 89            98              24       -1             [0.0, 0.125, 0.25, 0.292, 0.333, 0.417, 0.5, 0...
# 90            98              24       -1             [0.0, 0.125, 0.25, 0.292, 0.333, 0.417, 0.5, 0...
# 91            98              24       -1             [0.0, 0.125, 0.25, 0.292, 0.333, 0.417, 0.5, 0...
# 92            98              25       -1             [0.0, 0.125, 0.25, 0.292, 0.333, 0.417, 0.5, 0...
# 93            98              25       -1             [0.0, 0.125, 0.25, 0.292, 0.333, 0.417, 0.5, 0...
# 94            98              25       -1             [0.0, 0.125, 0.25, 0.292, 0.333, 0.417, 0.5, 0...
# 95            106             27       -1             [0.0, 0.25, 0.5, 0.75, 1.0, 1.5, 2.0, 2.5, 3.0...
# 96            106             27       -1             [0.0, 0.25, 0.5, 0.75, 1.0, 1.5, 2.0, 2.5, 3.0...
#               108             27       -1             [0.0, 0.25, 0.5, 0.75, 1.0, 1.5, 2.0, 2.5, 3.0...
# 97            106             27       -1             [0.0, 0.25, 0.5, 0.75, 1.0, 1.5, 2.0, 2.5, 3.0...
# 98            106             27       -1             [0.0, 0.25, 0.5, 0.75, 1.0, 1.5, 2.0, 2.5, 3.0...
#               108             27       -1             [0.0, 0.25, 0.5, 0.75, 1.0, 1.5, 2.0, 2.5, 3.0...
# 99            106             27       -1             [0.0, 0.25, 0.5, 0.75, 1.0, 1.5, 2.0, 2.5, 3.0...
# 100           106             27       -1             [0.0, 0.25, 0.5, 0.75, 1.0, 1.5, 2.0, 2.5, 3.0...
#               108             27       -1             [0.0, 0.25, 0.5, 0.75, 1.0, 1.5, 2.0, 2.5, 3.0...
# 101           106             27       -1             [0.0, 0.25, 0.5, 0.75, 1.0, 1.5, 2.0, 2.5, 3.0...
# 102           106             27       -1             [0.0, 0.25, 0.5, 0.75, 1.0, 1.5, 2.0, 2.5, 3.0...
#               108             27       -1             [0.0, 0.25, 0.5, 0.75, 1.0, 1.5, 2.0, 2.5, 3.0...
# 103           106             27       -1             [0.0, 0.25, 0.5, 0.75, 1.0, 1.5, 2.0, 2.5, 3.0...
# 104           106             27       -1             [0.0, 0.25, 0.5, 0.75, 1.0, 1.5, 2.0, 2.5, 3.0...
#               108             27       -1             [0.0, 0.25, 0.5, 0.75, 1.0, 1.5, 2.0, 2.5, 3.0...
# 105           106             27       -1             [0.0, 0.25, 0.5, 0.75, 1.0, 1.5, 2.0, 2.5, 3.0...
# 106           106             27       -1             [0.0, 0.25, 0.5, 0.75, 1.0, 1.5, 2.0, 2.5, 3.0...
#               108             27       -1             [0.0, 0.25, 0.5, 0.75, 1.0, 1.5, 2.0, 2.5, 3.0...
#
#                                                      time_unit  \
# timecourse_pk intervention_pk group_pk individual_pk
# 67            96              20       -1                   hr
# 68            94              20       -1                   hr
# 69            96              20       -1                   hr
# 70            94              20       -1                   hr
# 71            98              22       -1                   hr
# 72            98              22       -1                   hr
# 73            98              22       -1                   hr
# 74            98              23       -1                   hr
# 75            98              23       -1                   hr
# 76            98              23       -1                   hr
# 77            98              24       -1                   hr
# 78            98              24       -1                   hr
# 79            98              24       -1                   hr
# 80            98              25       -1                   hr
# 81            98              25       -1                   hr
# 82            98              25       -1                   hr
# 83            98              22       -1                   hr
# 84            98              22       -1                   hr
# 85            98              22       -1                   hr
# 86            98              23       -1                   hr
# 87            98              23       -1                   hr
# 88            98              23       -1                   hr
# 89            98              24       -1                   hr
# 90            98              24       -1                   hr
# 91            98              24       -1                   hr
# 92            98              25       -1                   hr
# 93            98              25       -1                   hr
# 94            98              25       -1                   hr
# 95            106             27       -1                   hr
# 96            106             27       -1                   hr
#               108             27       -1                   hr
# 97            106             27       -1                   hr
# 98            106             27       -1                   hr
#               108             27       -1                   hr
# 99            106             27       -1                   hr
# 100           106             27       -1                   hr
#               108             27       -1                   hr
# 101           106             27       -1                   hr
# 102           106             27       -1                   hr
#               108             27       -1                   hr
# 103           106             27       -1                   hr
# 104           106             27       -1                   hr
#               108             27       -1                   hr
# 105           106             27       -1                   hr
# 106           106             27       -1                   hr
#               108             27       -1                   hr
#
#                                                      measurement_type choice  \
# timecourse_pk intervention_pk group_pk individual_pk
# 67            96              20       -1               concentration   None
# 68            94              20       -1               concentration   None
# 69            96              20       -1               concentration   None
# 70            94              20       -1               concentration   None
# 71            98              22       -1               concentration   None
# 72            98              22       -1               concentration   None
# 73            98              22       -1               concentration   None
# 74            98              23       -1               concentration   None
# 75            98              23       -1               concentration   None
# 76            98              23       -1               concentration   None
# 77            98              24       -1               concentration   None
# 78            98              24       -1               concentration   None
# 79            98              24       -1               concentration   None
# 80            98              25       -1               concentration   None
# 81            98              25       -1               concentration   None
# 82            98              25       -1               concentration   None
# 83            98              22       -1               concentration   None
# 84            98              22       -1               concentration   None
# 85            98              22       -1               concentration   None
# 86            98              23       -1               concentration   None
# 87            98              23       -1               concentration   None
# 88            98              23       -1               concentration   None
# 89            98              24       -1               concentration   None
# 90            98              24       -1               concentration   None
# 91            98              24       -1               concentration   None
# 92            98              25       -1               concentration   None
# 93            98              25       -1               concentration   None
# 94            98              25       -1               concentration   None
# 95            106             27       -1               concentration   None
# 96            106             27       -1               concentration   None
#               108             27       -1               concentration   None
# 97            106             27       -1               concentration   None
# 98            106             27       -1               concentration   None
#               108             27       -1               concentration   None
# 99            106             27       -1               concentration   None
# 100           106             27       -1               concentration   None
#               108             27       -1               concentration   None
# 101           106             27       -1               concentration   None
# 102           106             27       -1               concentration   None
#               108             27       -1               concentration   None
# 103           106             27       -1             metabolic ratio   None
# 104           106             27       -1             metabolic ratio   None
#               108             27       -1             metabolic ratio   None
# 105           106             27       -1             metabolic ratio   None
# 106           106             27       -1             metabolic ratio   None
#               108             27       -1             metabolic ratio   None
#
#                                                                     substance  \
# timecourse_pk intervention_pk group_pk individual_pk
# 67            96              20       -1                           midazolam
# 68            94              20       -1                           midazolam
# 69            96              20       -1                           midazolam
# 70            94              20       -1                           midazolam
# 71            98              22       -1                         paracetamol
# 72            98              22       -1             paracetamol glucuronide
# 73            98              22       -1                 paracetamol sulfate
# 74            98              23       -1                         paracetamol
# 75            98              23       -1             paracetamol glucuronide
# 76            98              23       -1                 paracetamol sulfate
# 77            98              24       -1                         paracetamol
# 78            98              24       -1             paracetamol glucuronide
# 79            98              24       -1                 paracetamol sulfate
# 80            98              25       -1                         paracetamol
# 81            98              25       -1             paracetamol glucuronide
# 82            98              25       -1                 paracetamol sulfate
# 83            98              22       -1                         paracetamol
# 84            98              22       -1             paracetamol glucuronide
# 85            98              22       -1                 paracetamol sulfate
# 86            98              23       -1                         paracetamol
# 87            98              23       -1             paracetamol glucuronide
# 88            98              23       -1                 paracetamol sulfate
# 89            98              24       -1                         paracetamol
# 90            98              24       -1             paracetamol glucuronide
# 91            98              24       -1                 paracetamol sulfate
# 92            98              25       -1                         paracetamol
# 93            98              25       -1             paracetamol glucuronide
# 94            98              25       -1                 paracetamol sulfate
# 95            106             27       -1                            caffeine
# 96            106             27       -1                            caffeine
#               108             27       -1                            caffeine
# 97            106             27       -1                            caffeine
# 98            106             27       -1                            caffeine
#               108             27       -1                            caffeine
# 99            106             27       -1                        paraxanthine
# 100           106             27       -1                        paraxanthine
#               108             27       -1                        paraxanthine
# 101           106             27       -1                        paraxanthine
# 102           106             27       -1                        paraxanthine
#               108             27       -1                        paraxanthine
# 103           106             27       -1                              px/caf
# 104           106             27       -1                              px/caf
#               108             27       -1                              px/caf
# 105           106             27       -1                              px/caf
# 106           106             27       -1                              px/caf
#               108             27       -1                              px/caf
#
#                                                      value  \
# timecourse_pk intervention_pk group_pk individual_pk
# 67            96              20       -1             None
# 68            94              20       -1             None
# 69            96              20       -1             None
# 70            94              20       -1             None
# 71            98              22       -1             None
# 72            98              22       -1             None
# 73            98              22       -1             None
# 74            98              23       -1             None
# 75            98              23       -1             None
# 76            98              23       -1             None
# 77            98              24       -1             None
# 78            98              24       -1             None
# 79            98              24       -1             None
# 80            98              25       -1             None
# 81            98              25       -1             None
# 82            98              25       -1             None
# 83            98              22       -1             None
# 84            98              22       -1             None
# 85            98              22       -1             None
# 86            98              23       -1             None
# 87            98              23       -1             None
# 88            98              23       -1             None
# 89            98              24       -1             None
# 90            98              24       -1             None
# 91            98              24       -1             None
# 92            98              25       -1             None
# 93            98              25       -1             None
# 94            98              25       -1             None
# 95            106             27       -1             None
# 96            106             27       -1             None
#               108             27       -1             None
# 97            106             27       -1             None
# 98            106             27       -1             None
#               108             27       -1             None
# 99            106             27       -1             None
# 100           106             27       -1             None
#               108             27       -1             None
# 101           106             27       -1             None
# 102           106             27       -1             None
#               108             27       -1             None
# 103           106             27       -1             None
# 104           106             27       -1             None
#               108             27       -1             None
# 105           106             27       -1             None
# 106           106             27       -1             None
#               108             27       -1             None
#
#                                                                                                    mean  \
# timecourse_pk intervention_pk group_pk individual_pk
# 67            96              20       -1             [185.0, 144.0, 121.0, 106.0, 83.8, 76.7, 58.3,...
# 68            94              20       -1             [10.1, 132.0, 134.0, 96.7, 96.6, 67.7, 57.5, 4...
# 69            96              20       -1             [0.000185, 0.000144, 0.000121, 0.000106, 8.38e...
# 70            94              20       -1             [1.01e-05, 0.000132, 0.000134, 9.67e-05, 9.66e...
# 71            98              22       -1             [0.0, 7.92, 15.1, 15.2, 14.4, 13.7, 12.3, 11.4...
# 72            98              22       -1             [0.0, 0.482, 1.1, 2.27, 2.75, 3.99, 5.92, 9.63...
# 73            98              22       -1             [0.0, 0.547, 1.09, 1.55, 2.44, 3.3, 3.9, 4.12,...
# 74            98              23       -1             [0.0, 9.64, 14.6, 15.4, 15.5, 13.9, 13.5, 12.7...
# 75            98              23       -1             [0.0, 0.138, 1.03, 1.79, 2.48, 3.37, 4.61, 8.6...
# 76            98              23       -1             [0.0, 0.501, 0.934, 1.62, 2.07, 2.64, 3.23, 4....
# 77            98              24       -1             [0.0, 8.39, 14.5, 15.2, 15.2, 15.2, 14.2, 13.1...
# 78            98              24       -1             [0.0, 0.206, 0.688, 1.31, 2.06, 3.1, 3.72, 7.7...
# 79            98              24       -1             [0.0, 0.205, 1.12, 1.53, 2.14, 2.87, 3.55, 4.8...
# 80            98              25       -1             [0.0671, 18.3, 25.1, 21.9, 21.0, 20.1, 18.9, 1...
# 81            98              25       -1             [0.0, 0.619, 1.17, 2.06, 3.03, 3.99, 5.3, 8.74...
# 82            98              25       -1             [0.0, 0.501, 2.21, 2.96, 3.6, 3.9, 4.56, 5.92,...
# 83            98              22       -1             [0.0, 0.00792, 0.0151, 0.0152, 0.0144, 0.0137,...
# 84            98              22       -1             [0.0, 0.000482, 0.0011, 0.00227, 0.00275, 0.00...
# 85            98              22       -1             [0.0, 0.000547, 0.00109, 0.00155, 0.00244, 0.0...
# 86            98              23       -1             [0.0, 0.00964, 0.0146, 0.0154, 0.0155, 0.0139,...
# 87            98              23       -1             [0.0, 0.000138, 0.00103, 0.00179, 0.00248, 0.0...
# 88            98              23       -1             [0.0, 0.000501, 0.000934, 0.00162, 0.00207, 0....
# 89            98              24       -1             [0.0, 0.00839, 0.0145, 0.0152, 0.0152, 0.0152,...
# 90            98              24       -1             [0.0, 0.000206, 0.000688, 0.00131, 0.00206, 0....
# 91            98              24       -1             [0.0, 0.000205, 0.00112, 0.00153, 0.00214, 0.0...
# 92            98              25       -1             [6.71e-05, 0.0183, 0.0251, 0.0219, 0.021, 0.02...
# 93            98              25       -1             [0.0, 0.000619, 0.00117, 0.00206, 0.00303, 0.0...
# 94            98              25       -1             [0.0, 0.000501, 0.00221, 0.00296, 0.0036, 0.00...
# 95            106             27       -1             [0.155, 1.07, 3.16, 4.13, 3.95, 3.54, 3.37, 3....
# 96            106             27       -1             [0.15, 0.817, 2.6, 3.48, 3.81, 3.68, 3.38, 3.0...
#               108             27       -1             [0.15, 0.817, 2.6, 3.48, 3.81, 3.68, 3.38, 3.0...
# 97            106             27       -1             [0.000155, 0.00107, 0.00316, 0.00413, 0.00395,...
# 98            106             27       -1             [0.00015, 0.000817, 0.0026, 0.00348, 0.00381, ...
#               108             27       -1             [0.00015, 0.000817, 0.0026, 0.00348, 0.00381, ...
# 99            106             27       -1             [0.361, 0.462, 0.637, 0.807, 0.854, 0.973, 1.0...
# 100           106             27       -1             [0.383, 0.446, 0.591, 0.731, 0.831, 0.935, 1.0...
#               108             27       -1             [0.383, 0.446, 0.591, 0.731, 0.831, 0.935, 1.0...
# 101           106             27       -1             [0.000361, 0.000462, 0.000637, 0.000807, 0.000...
# 102           106             27       -1             [0.000383, 0.000446, 0.000591, 0.000731, 0.000...
#               108             27       -1             [0.000383, 0.000446, 0.000591, 0.000731, 0.000...
# 103           106             27       -1             [2.33, 0.431, 0.201, 0.195, 0.217, 0.275, 0.32...
# 104           106             27       -1             [2.56, 0.546, 0.227, 0.21, 0.218, 0.254, 0.308...
#               108             27       -1             [2.56, 0.546, 0.227, 0.21, 0.218, 0.254, 0.308...
# 105           106             27       -1             [2.33, 0.431, 0.201, 0.195, 0.217, 0.275, 0.32...
# 106           106             27       -1             [2.56, 0.546, 0.227, 0.21, 0.218, 0.254, 0.308...
#               108             27       -1             [2.56, 0.546, 0.227, 0.21, 0.218, 0.254, 0.308...
#
#                                                      median   min   max  \
# timecourse_pk intervention_pk group_pk individual_pk
# 67            96              20       -1              None  None  None
# 68            94              20       -1              None  None  None
# 69            96              20       -1              None  None  None
# 70            94              20       -1              None  None  None
# 71            98              22       -1              None  None  None
# 72            98              22       -1              None  None  None
# 73            98              22       -1              None  None  None
# 74            98              23       -1              None  None  None
# 75            98              23       -1              None  None  None
# 76            98              23       -1              None  None  None
# 77            98              24       -1              None  None  None
# 78            98              24       -1              None  None  None
# 79            98              24       -1              None  None  None
# 80            98              25       -1              None  None  None
# 81            98              25       -1              None  None  None
# 82            98              25       -1              None  None  None
# 83            98              22       -1              None  None  None
# 84            98              22       -1              None  None  None
# 85            98              22       -1              None  None  None
# 86            98              23       -1              None  None  None
# 87            98              23       -1              None  None  None
# 88            98              23       -1              None  None  None
# 89            98              24       -1              None  None  None
# 90            98              24       -1              None  None  None
# 91            98              24       -1              None  None  None
# 92            98              25       -1              None  None  None
# 93            98              25       -1              None  None  None
# 94            98              25       -1              None  None  None
# 95            106             27       -1              None  None  None
# 96            106             27       -1              None  None  None
#               108             27       -1              None  None  None
# 97            106             27       -1              None  None  None
# 98            106             27       -1              None  None  None
#               108             27       -1              None  None  None
# 99            106             27       -1              None  None  None
# 100           106             27       -1              None  None  None
#               108             27       -1              None  None  None
# 101           106             27       -1              None  None  None
# 102           106             27       -1              None  None  None
#               108             27       -1              None  None  None
# 103           106             27       -1              None  None  None
# 104           106             27       -1              None  None  None
#               108             27       -1              None  None  None
# 105           106             27       -1              None  None  None
# 106           106             27       -1              None  None  None
#               108             27       -1              None  None  None
#
#                                                                                                      sd  \
# timecourse_pk intervention_pk group_pk individual_pk
# 67            96              20       -1             [23.3, 18.2, 20.6, 26.8, 10.3, 19.9, 9.37, 13....
# 68            94              20       -1             [4.76, 74.8, 30.1, 42.3, 52.9, 25.1, 11.8, 10....
# 69            96              20       -1             [2.33e-05, 1.82e-05, 2.06e-05, 2.68e-05, 1.03e...
# 70            94              20       -1             [4.76e-06, 7.49e-05, 3.01e-05, 4.23e-05, 5.29e...
# 71            98              22       -1             [nan, 0.872, 1.48, 1.95, 1.81, 2.15, 1.61, 13....
# 72            98              22       -1             [nan, 0.894, 0.688, 0.55, 0.894, 0.619, 1.17, ...
# 73            98              22       -1             [nan, 0.0911, 0.228, 0.205, 0.592, 0.592, 0.6,...
# 74            98              23       -1             [nan, 0.357, 0.57, 0.5, 1.2, 1.57, 0.97, 1.1, ...
# 75            98              23       -1             [nan, 1.03, 0.55, 1.03, 1.24, 1.44, 1.38, 1.03...
# 76            98              23       -1             [nan, 0.137, 0.342, 0.183, 0.364, 0.501, 0.592...
# 77            98              24       -1             [nan, 1.21, 1.07, 1.41, 1.88, 0.537, 0.604, 1....
# 78            98              24       -1             [nan, 0.482, 0.482, 0.344, 0.688, 0.206, 0.826...
# 79            98              24       -1             [nan, 0.251, 0.114, 0.0738, 0.2, 0.387, 0.319,...
# 80            98              25       -1             [nan, 4.16, 2.95, 1.61, 1.61, 0.671, 1.01, 17....
# 81            98              25       -1             [nan, 1.1, 0.757, 1.03, 1.03, 0.963, 2.0, 1.44...
# 82            98              25       -1             [nan, 0.251, 0.319, 0.364, 0.524, 0.41, 0.478,...
# 83            98              22       -1             [nan, 0.000872, 0.00148, 0.00195, 0.00181, 0.0...
# 84            98              22       -1             [nan, 0.000894, 0.000688, 0.00055, 0.000894, 0...
# 85            98              22       -1             [nan, 9.11e-05, 0.000228, 0.000205, 0.000592, ...
# 86            98              23       -1             [nan, 0.000357, 0.00057, 0.0005, 0.0012, 0.001...
# 87            98              23       -1             [nan, 0.00103, 0.00055, 0.00103, 0.00124, 0.00...
# 88            98              23       -1             [nan, 0.000137, 0.000342, 0.000183, 0.000364, ...
# 89            98              24       -1             [nan, 0.00121, 0.00107, 0.00141, 0.00188, 0.00...
# 90            98              24       -1             [nan, 0.000482, 0.000482, 0.000344, 0.000688, ...
# 91            98              24       -1             [nan, 0.000251, 0.000114, 7.38e-05, 0.0002, 0....
# 92            98              25       -1             [nan, 0.00416, 0.00295, 0.00161, 0.00161, 0.00...
# 93            98              25       -1             [nan, 0.0011, 0.000757, 0.00103, 0.00103, 0.00...
# 94            98              25       -1             [nan, 0.000251, 0.000319, 0.000364, 0.000524, ...
# 95            106             27       -1             [0.169, 0.667, 1.35, 0.469, 0.343, 0.367, 0.38...
# 96            106             27       -1             [0.189, 0.329, 1.15, 0.759, 0.522, 0.305, 0.33...
#               108             27       -1             [0.189, 0.329, 1.15, 0.759, 0.522, 0.305, 0.33...
# 97            106             27       -1             [0.000169, 0.000667, 0.00135, 0.000469, 0.0003...
# 98            106             27       -1             [0.000189, 0.000329, 0.00115, 0.000759, 0.0005...
#               108             27       -1             [0.000189, 0.000329, 0.00115, 0.000759, 0.0005...
# 99            106             27       -1             [0.2, 0.206, 0.262, 0.316, 0.167, 0.17, 0.199,...
# 100           106             27       -1             [0.13, 0.193, 0.216, 0.236, 0.246, 0.19, 0.195...
#               108             27       -1             [0.13, 0.193, 0.216, 0.236, 0.246, 0.19, 0.195...
# 101           106             27       -1             [0.0002, 0.000206, 0.000262, 0.000316, 0.00016...
# 102           106             27       -1             [0.00013, 0.000193, 0.000216, 0.000236, 0.0002...
#               108             27       -1             [0.00013, 0.000193, 0.000216, 0.000236, 0.0002...
# 103           106             27       -1             [0.611, 0.301, 0.277, 0.111, 0.0827, 0.111, 0....
# 104           106             27       -1             [0.586, 0.208, 0.265, 0.167, 0.126, 0.0912, 0....
#               108             27       -1             [0.586, 0.208, 0.265, 0.167, 0.126, 0.0912, 0....
# 105           106             27       -1             [0.611, 0.301, 0.277, 0.111, 0.0827, 0.111, 0....
# 106           106             27       -1             [0.586, 0.208, 0.265, 0.167, 0.126, 0.0912, 0....
#               108             27       -1             [0.586, 0.208, 0.265, 0.167, 0.126, 0.0912, 0....
#
#                                                                                                      se  \
# timecourse_pk intervention_pk group_pk individual_pk
# 67            96              20       -1                                                          None
# 68            94              20       -1                                                          None
# 69            96              20       -1             [9.52e-06, 7.42e-06, 8.4e-06, 1.09e-05, 4.19e-...
# 70            94              20       -1             [1.94e-06, 3.06e-05, 1.23e-05, 1.73e-05, 2.16e...
# 71            98              22       -1                                                          None
# 72            98              22       -1                                                          None
# 73            98              22       -1                                                          None
# 74            98              23       -1                                                          None
# 75            98              23       -1                                                          None
# 76            98              23       -1                                                          None
# 77            98              24       -1                                                          None
# 78            98              24       -1                                                          None
# 79            98              24       -1                                                          None
# 80            98              25       -1                                                          None
# 81            98              25       -1                                                          None
# 82            98              25       -1                                                          None
# 83            98              22       -1             [nan, 0.000276, 0.000467, 0.000615, 0.000573, ...
# 84            98              22       -1             [nan, 0.000283, 0.000218, 0.000174, 0.000283, ...
# 85            98              22       -1             [nan, 2.88e-05, 7.2e-05, 6.48e-05, 0.000187, 0...
# 86            98              23       -1             [nan, 0.000113, 0.00018, 0.000158, 0.000379, 0...
# 87            98              23       -1             [nan, 0.000326, 0.000174, 0.000326, 0.000392, ...
# 88            98              23       -1             [nan, 4.32e-05, 0.000108, 5.78e-05, 0.000115, ...
# 89            98              24       -1             [nan, 0.000382, 0.00034, 0.000446, 0.000594, 0...
# 90            98              24       -1             [nan, 0.000152, 0.000152, 0.000109, 0.000218, ...
# 91            98              24       -1             [nan, 7.92e-05, 3.6e-05, 2.33e-05, 6.32e-05, 0...
# 92            98              25       -1             [nan, 0.00132, 0.000934, 0.000509, 0.000509, 0...
# 93            98              25       -1             [nan, 0.000348, 0.000239, 0.000326, 0.000326, ...
# 94            98              25       -1             [nan, 7.92e-05, 0.000101, 0.000115, 0.000166, ...
# 95            106             27       -1                                                          None
# 96            106             27       -1                                                          None
#               108             27       -1                                                          None
# 97            106             27       -1             [4.23e-05, 0.000167, 0.000337, 0.000117, 8.58e...
# 98            106             27       -1             [4.71e-05, 8.22e-05, 0.000287, 0.00019, 0.0001...
#               108             27       -1             [4.71e-05, 8.22e-05, 0.000287, 0.00019, 0.0001...
# 99            106             27       -1                                                          None
# 100           106             27       -1                                                          None
#               108             27       -1                                                          None
# 101           106             27       -1             [5.01e-05, 5.15e-05, 6.54e-05, 7.9e-05, 4.18e-...
# 102           106             27       -1             [3.25e-05, 4.83e-05, 5.4e-05, 5.9e-05, 6.15e-0...
#               108             27       -1             [3.25e-05, 4.83e-05, 5.4e-05, 5.9e-05, 6.15e-0...
# 103           106             27       -1                                                          None
# 104           106             27       -1                                                          None
#               108             27       -1                                                          None
# 105           106             27       -1             [0.153, 0.0752, 0.0692, 0.0276, 0.0207, 0.0278...
# 106           106             27       -1             [0.147, 0.0521, 0.0662, 0.0418, 0.0315, 0.0228...
#               108             27       -1             [0.147, 0.0521, 0.0662, 0.0418, 0.0315, 0.0228...
#
#                                                                                                      cv  \
# timecourse_pk intervention_pk group_pk individual_pk
# 67            96              20       -1                                                          None
# 68            94              20       -1                                                          None
# 69            96              20       -1             [0.126, 0.126, 0.171, 0.253, 0.123, 0.259, 0.1...
# 70            94              20       -1             [0.471, 0.566, 0.224, 0.437, 0.548, 0.37, 0.20...
# 71            98              22       -1                                                          None
# 72            98              22       -1                                                          None
# 73            98              22       -1                                                          None
# 74            98              23       -1                                                          None
# 75            98              23       -1                                                          None
# 76            98              23       -1                                                          None
# 77            98              24       -1                                                          None
# 78            98              24       -1                                                          None
# 79            98              24       -1                                                          None
# 80            98              25       -1                                                          None
# 81            98              25       -1                                                          None
# 82            98              25       -1                                                          None
# 83            98              22       -1             [nan, 0.11, 0.0978, 0.128, 0.126, 0.157, 0.13,...
# 84            98              22       -1             [nan, 1.86, 0.625, 0.242, 0.325, 0.155, 0.198,...
# 85            98              22       -1             [nan, 0.167, 0.208, 0.132, 0.243, 0.179, 0.154...
# 86            98              23       -1             [nan, 0.037, 0.039, 0.0325, 0.0772, 0.113, 0.0...
# 87            98              23       -1             [nan, 7.5, 0.533, 0.577, 0.5, 0.429, 0.299, 0....
# 88            98              23       -1             [nan, 0.273, 0.366, 0.113, 0.176, 0.19, 0.183,...
# 89            98              24       -1             [nan, 0.144, 0.0741, 0.0925, 0.123, 0.0352, 0....
# 90            98              24       -1             [nan, 2.33, 0.7, 0.263, 0.333, 0.0667, 0.222, ...
# 91            98              24       -1             [nan, 1.22, 0.102, 0.0484, 0.0934, 0.135, 0.08...
# 92            98              25       -1             [nan, 0.228, 0.118, 0.0734, 0.0767, 0.0334, 0....
# 93            98              25       -1             [nan, 1.78, 0.647, 0.5, 0.341, 0.241, 0.377, 0...
# 94            98              25       -1             [nan, 0.5, 0.144, 0.123, 0.146, 0.105, 0.105, ...
# 95            106             27       -1                                                          None
# 96            106             27       -1                                                          None
#               108             27       -1                                                          None
# 97            106             27       -1             [1.09, 0.622, 0.427, 0.114, 0.087, 0.104, 0.11...
# 98            106             27       -1             [1.26, 0.402, 0.441, 0.218, 0.137, 0.0828, 0.0...
#               108             27       -1             [1.26, 0.402, 0.441, 0.218, 0.137, 0.0828, 0.0...
# 99            106             27       -1                                                          None
# 100           106             27       -1                                                          None
#               108             27       -1                                                          None
# 101           106             27       -1             [0.556, 0.446, 0.411, 0.392, 0.196, 0.175, 0.1...
# 102           106             27       -1             [0.34, 0.433, 0.366, 0.323, 0.296, 0.204, 0.18...
#               108             27       -1             [0.34, 0.433, 0.366, 0.323, 0.296, 0.204, 0.18...
# 103           106             27       -1                                                          None
# 104           106             27       -1                                                          None
#               108             27       -1                                                          None
# 105           106             27       -1             [0.262, 0.698, 1.37, 0.566, 0.382, 0.405, 0.43...
# 106           106             27       -1             [0.229, 0.381, 1.17, 0.795, 0.577, 0.359, 0.38...
#               108             27       -1             [0.229, 0.381, 1.17, 0.795, 0.577, 0.359, 0.38...
#
#                                                               unit
# timecourse_pk intervention_pk group_pk individual_pk
# 67            96              20       -1                    ng/ml
# 68            94              20       -1                    ng/ml
# 69            96              20       -1             gram / liter
# 70            94              20       -1             gram / liter
# 71            98              22       -1                     mg/L
# 72            98              22       -1                     mg/L
# 73            98              22       -1                     mg/L
# 74            98              23       -1                     mg/L
# 75            98              23       -1                     mg/L
# 76            98              23       -1                     mg/L
# 77            98              24       -1                     mg/L
# 78            98              24       -1                     mg/L
# 79            98              24       -1                     mg/L
# 80            98              25       -1                     mg/L
# 81            98              25       -1                     mg/L
# 82            98              25       -1                     mg/L
# 83            98              22       -1             gram / liter
# 84            98              22       -1             gram / liter
# 85            98              22       -1             gram / liter
# 86            98              23       -1             gram / liter
# 87            98              23       -1             gram / liter
# 88            98              23       -1             gram / liter
# 89            98              24       -1             gram / liter
# 90            98              24       -1             gram / liter
# 91            98              24       -1             gram / liter
# 92            98              25       -1             gram / liter
# 93            98              25       -1             gram / liter
# 94            98              25       -1             gram / liter
# 95            106             27       -1                     mg/l
# 96            106             27       -1                     mg/l
#               108             27       -1                     mg/l
# 97            106             27       -1             gram / liter
# 98            106             27       -1             gram / liter
#               108             27       -1             gram / liter
# 99            106             27       -1                     mg/l
# 100           106             27       -1                     mg/l
#               108             27       -1                     mg/l
# 101           106             27       -1             gram / liter
# 102           106             27       -1             gram / liter
#               108             27       -1             gram / liter
# 103           106             27       -1                     none
# 104           106             27       -1                     none
#               108             27       -1                     none
# 105           106             27       -1                     none
# 106           106             27       -1                     none
#               108             27       -1                     none
