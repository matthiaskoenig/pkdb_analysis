# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_csv("report_data.tsv", sep="\t")
df['study_count'] = [1]*len(df)

count_fields = ['study_count', 'group_count', 'individual_count', 'intervention_count', 'output_count', 'timecourse_count']
for key in count_fields:
    # cumulative sums
    df[f'{key}_cum'] = df[key].cumsum()
print(df.head())
# Out:
#          sid        date  name_x substance         name_y licence  access  \
# 0  PKDB00001  2019-05-03     NaN  caffeine  Abernethy1985  closed  public
# 1  PKDB00002  2019-05-03     NaN  caffeine  Akinyinka2000  closed  public
# 2  PKDB00003  2019-05-03     NaN  caffeine     Amchin1999  closed  public
# 3  PKDB00004  2019-05-03     NaN  caffeine    Backman2008  closed  public
# 4  PKDB00005  2019-05-03     NaN  caffeine     Balogh1992  closed  public
#
#                            curators  group_count  individual_count  \
# 0             ['mkoenig', 'janekg']            3                54
# 1  ['mkoenig', 'dimitra', 'janekg']            4                20
# 2             ['mkoenig', 'janekg']            1                16
# 3             ['mkoenig', 'janekg']            5                70
# 4             ['mkoenig', 'janekg']            1                12
#
#    intervention_count  output_count  timecourse_count  study_count  \
# 0                   1            64                 0            1
# 1                   1           160                 6            1
# 2                   2            72                 2            1
# 3                   1           140                 0            1
# 4                   1           363                72            1
#
#    study_count_cum  group_count_cum  individual_count_cum  \
# 0                1                3                    54
# 1                2                7                    74
# 2                3                8                    90
# 3                4               13                   160
# 4                5               14                   172
#
#    intervention_count_cum  output_count_cum  timecourse_count_cum
# 0                       1                64                     0
# 1                       2               224                     6
# 2                       4               296                     8
# 3                       5               436                     8
# 4                       6               799                    80

# %%
 # 4. altair plot
import altair as alt
from vega_datasets import data

source = data.unemployment_across_industries.url

for key in count_fields:
    chart = alt.Chart(df).mark_area().encode(
        alt.X('date'),
        alt.Y(f'{key}_cum'),
    )
    chart
    
chart
# Out:
# alt.Chart(...)
