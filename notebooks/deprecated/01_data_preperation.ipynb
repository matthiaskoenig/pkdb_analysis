# %% [markdown]
# ## Analysis
# This project demonstrated the usage of pkdb for the test substance caffeine.
# ### Data Sources
# - pkdb rest api : "http://0.0.0.0:8000/api/v1/"
#
# ### Outputs:
# - data/processed/outputs.tsv
# - data/processed/timecourses.tsv
# - data/processed/interventions.tsv
# - data/processed/individuals.tsv
# - data/processed/groups.tsv
#
# #### Groups and Individuals
# - data/processed/all_subjects.tsv
#
# ### Merged Dataframes
# - data/processed/all_subjects.tsv
#
# ### Normalized Dataframes
# - data/processed/all_subjects.tsv
#
# ### Changes
# - 11-29-2018 : Started project

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from utils import PkdbModel, Preprocessed, flatten_json
import pandas as pd

# %%
queries = [
    'outputs', 
    'timecourses',
    'interventions',
    'individuals',
    'groups',
    'studies',
    'substances'
]
#queries = ["studies","substances"]
#queries = ["substances"]
#queries = ["studies"]
#queries = ["individuals"]

# %%
outputs = PkdbModel("outputs",destination='1-preprocessed')

# %%
outputs.load()
outputs.data
# Out:
#           pk        study  tissue  time time_unit value      mean    median  \
# 0       8442  Grattan2000   serum   NaN      None  None  2.98e-02      None
# 1       8449  Grattan2000   serum   NaN      None  None  5.89e-01  3.75e-01
# 2       8460  Grattan2000   serum   NaN      None  None  1.70e-02      None
# 3       8477  Grattan2000   serum   1.5        hr  None  1.79e-02      None
# 4       8481  Grattan2000   serum   NaN      None  None  1.37e-02      None
# ...      ...          ...     ...   ...       ...   ...       ...       ...
# 20977  61760    Depre1992  plasma   NaN      None  None  2.00e+01      None
# 20978  61769    Depre1992  plasma   NaN      None  None  2.92e+01      None
# 20979  61771    Depre1992  plasma   NaN      None  None  1.92e-03      None
# 20980  61774    Depre1992  plasma   NaN      None  None  2.00e+00      None
# 20981  61789    Depre1992  plasma   NaN      None  None  1.39e+02      None
#
#         min   max  ... individual normed raw_pk calculated timecourse  \
# 0      None  None  ...        NaN   True   8412      False        NaN
# 1      None  None  ...        NaN   True   8419      False        NaN
# 2      None  None  ...        NaN   True   8430      False        NaN
# 3      None  None  ...        NaN   True   8469       True        NaN
# 4      None  None  ...        NaN   True   8473       True        NaN
# ...     ...   ...  ...        ...    ...    ...        ...        ...
# 20977  None  None  ...        NaN   True  61744      False        NaN
# 20978  None  None  ...        NaN   True  61763       True        NaN
# 20979  None  None  ...        NaN   True  61765       True        NaN
# 20980  None  None  ...        NaN   True  61768       True        NaN
# 20981  None  None  ...        NaN   True  61781       True        NaN
#
#                                          interventions timecourse_pk group  \
# 0               [{'pk': 356, 'name': 'Formulation A'}]           NaN   NaN
# 1               [{'pk': 358, 'name': 'Formulation B'}]           NaN   NaN
# 2               [{'pk': 362, 'name': 'Formulation D'}]           NaN   NaN
# 3               [{'pk': 356, 'name': 'Formulation A'}]         578.0   NaN
# 4               [{'pk': 356, 'name': 'Formulation A'}]         578.0   NaN
# ...                                                ...           ...   ...
# 20977  [{'pk': 2110, 'name': 'propacetamol1000mg_iv'}]           NaN   NaN
# 20978       [{'pk': 2112, 'name': 'paracetamol500mg'}]        4021.0   NaN
# 20979       [{'pk': 2112, 'name': 'paracetamol500mg'}]        4021.0   NaN
# 20980       [{'pk': 2112, 'name': 'paracetamol500mg'}]        4021.0   NaN
# 20981  [{'pk': 2110, 'name': 'propacetamol1000mg_iv'}]        4022.0   NaN
#
#       individual_pk  individual_name
# 0               NaN              NaN
# 1               NaN              NaN
# 2               NaN              NaN
# 3               NaN              NaN
# 4               NaN              NaN
# ...             ...              ...
# 20977           NaN              NaN
# 20978           NaN              NaN
# 20979           NaN              NaN
# 20980           NaN              NaN
# 20981           NaN              NaN
#
# [20982 rows x 32 columns]

# %%
import numpy as np
lst_col = "interventions"
df = outputs.data
data = pd.DataFrame({ col:np.repeat(df[col].values, df[lst_col].str.len())
              for col in df.columns.difference([lst_col])}).assign(**{lst_col:np.concatenate(df[lst_col].values)})[df.columns.tolist()]
#data["intervention_pk"] = data["interventions"].apply(lambda intervention: intervention.get("pk"))
#del data["interventions"]

# %%
 outputs.data
# Out:
#           pk        study  tissue  time time_unit value      mean    median  \
# 0       8442  Grattan2000   serum   NaN      None  None  2.98e-02      None
# 1       8449  Grattan2000   serum   NaN      None  None  5.89e-01  3.75e-01
# 2       8460  Grattan2000   serum   NaN      None  None  1.70e-02      None
# 3       8477  Grattan2000   serum   1.5        hr  None  1.79e-02      None
# 4       8481  Grattan2000   serum   NaN      None  None  1.37e-02      None
# ...      ...          ...     ...   ...       ...   ...       ...       ...
# 20977  61760    Depre1992  plasma   NaN      None  None  2.00e+01      None
# 20978  61769    Depre1992  plasma   NaN      None  None  2.92e+01      None
# 20979  61771    Depre1992  plasma   NaN      None  None  1.92e-03      None
# 20980  61774    Depre1992  plasma   NaN      None  None  2.00e+00      None
# 20981  61789    Depre1992  plasma   NaN      None  None  1.39e+02      None
#
#         min   max  ... individual normed raw_pk calculated timecourse  \
# 0      None  None  ...        NaN   True   8412      False        NaN
# 1      None  None  ...        NaN   True   8419      False        NaN
# 2      None  None  ...        NaN   True   8430      False        NaN
# 3      None  None  ...        NaN   True   8469       True        NaN
# 4      None  None  ...        NaN   True   8473       True        NaN
# ...     ...   ...  ...        ...    ...    ...        ...        ...
# 20977  None  None  ...        NaN   True  61744      False        NaN
# 20978  None  None  ...        NaN   True  61763       True        NaN
# 20979  None  None  ...        NaN   True  61765       True        NaN
# 20980  None  None  ...        NaN   True  61768       True        NaN
# 20981  None  None  ...        NaN   True  61781       True        NaN
#
#                                          interventions timecourse_pk group  \
# 0               [{'pk': 356, 'name': 'Formulation A'}]           NaN   NaN
# 1               [{'pk': 358, 'name': 'Formulation B'}]           NaN   NaN
# 2               [{'pk': 362, 'name': 'Formulation D'}]           NaN   NaN
# 3               [{'pk': 356, 'name': 'Formulation A'}]         578.0   NaN
# 4               [{'pk': 356, 'name': 'Formulation A'}]         578.0   NaN
# ...                                                ...           ...   ...
# 20977  [{'pk': 2110, 'name': 'propacetamol1000mg_iv'}]           NaN   NaN
# 20978       [{'pk': 2112, 'name': 'paracetamol500mg'}]        4021.0   NaN
# 20979       [{'pk': 2112, 'name': 'paracetamol500mg'}]        4021.0   NaN
# 20980       [{'pk': 2112, 'name': 'paracetamol500mg'}]        4021.0   NaN
# 20981  [{'pk': 2110, 'name': 'propacetamol1000mg_iv'}]        4022.0   NaN
#
#       individual_pk  individual_name
# 0               NaN              NaN
# 1               NaN              NaN
# 2               NaN              NaN
# 3               NaN              NaN
# 4               NaN              NaN
# ...             ...              ...
# 20977           NaN              NaN
# 20978           NaN              NaN
# 20979           NaN              NaN
# 20980           NaN              NaN
# 20981           NaN              NaN
#
# [20982 rows x 32 columns]

# %% [markdown]
# ### Query, Process and Save
# Json data is loaded, transformed to dataframes, preprocessed and saved as tab seperated files.

# %%
for pk_instance in queries:
    pk_instance = PkdbModel(pk_instance)  
    pk_instance.load()
    pk_instance.preprocess()
    pk_instance.save()
    pk_instance.report()
# Out:
# ____________________________________________________________
# Name: outputs
# Loaded: True
# Preprocessed: True
# saved: True
# outputs were succsesfully saved to </home/janekg/Dev/pkdb_analysis/data/1-preprocessed/outputs.tsv>
# ____________________________________________________________
# Name: timecourses
# Loaded: True
# Preprocessed: True
# saved: True
# timecourses were succsesfully saved to </home/janekg/Dev/pkdb_analysis/data/1-preprocessed/timecourses.tsv>
# ____________________________________________________________
# Name: interventions
# Loaded: True
# Preprocessed: True
# saved: True
# interventions were succsesfully saved to </home/janekg/Dev/pkdb_analysis/data/1-preprocessed/interventions.tsv>
# ____________________________________________________________
# Name: individuals
# Loaded: True
# Preprocessed: True
# saved: True
# individuals were succsesfully saved to </home/janekg/Dev/pkdb_analysis/data/1-preprocessed/individuals.tsv>
# ____________________________________________________________
# Name: groups
# Loaded: True
# Preprocessed: True
# saved: True
# groups were succsesfully saved to </home/janekg/Dev/pkdb_analysis/data/1-preprocessed/groups.tsv>
# ____________________________________________________________
# Name: studies
# Loaded: True
# Preprocessed: True
# saved: True
# studies were succsesfully saved to </home/janekg/Dev/pkdb_analysis/data/1-preprocessed/studies.tsv>
# ____________________________________________________________
# Name: substances
# Loaded: True
# Preprocessed: True
# saved: True
# substances were succsesfully saved to </home/janekg/Dev/pkdb_analysis/data/1-preprocessed/substances.tsv>

# %%
studies = PkdbModel('studies',destination='1-preprocessed')
studies.read()
frames = []
for number,row in studies.data.dropna(subset=["substances"]).iterrows():
    substances = [{"study":row["name"],"substance":x.strip()} for x in row["substances"].split(",")]
    frames.append(pd.DataFrame(substances))

study_substance_map = pd.concat(frames)

def agg_studies(x):
    return pd.Series([','.join(x["study"]),len(x["study"])], index = ["studies","study_number"])
    
substance_study = study_substance_map.groupby(['substance']).apply(agg_studies)
substance_study = substance_study.reset_index()

# %%
substances = PkdbModel('substances',destination='1-preprocessed')
substances.read()
substances.data = substance_study.merge(substances.data, left_on="substance", right_on="name")



substances.data.sort_values(by="study_number", ascending=False, inplace=True)
substances.save()

# %%
this_data = PkdbModel('outputs',destination='1-preprocessed')
this_data.read()
this_data.data.groupby(["calculated"]).apply(len)
# Out:
# calculated
# False    4469
# True     2799
# dtype: int64

# %%
this_data = PkdbModel('interventions',destination='1-preprocessed')
this_data.read()
this_data.data.groupby(["unit"]).apply(len)
# Out:
# unit
# gram                 279
# gram / hour            6
# gram / kilogram       31
# gram / meter ** 2      1
# dtype: int64

# %%
this_data = PkdbModel('outputs',destination='1-preprocessed')
this_data.read()
this_data.data.groupby(["measurement_type","unit"]).count()
# Out:
#                                                          allowed_users  \
# measurement_type       unit
# age                    yr                                            2
# amount                 gram                                         30
# auc_end                gram * hour / liter                         561
# auc_inf                gram * hour / liter                         828
# aumc_inf               gram * hour ** 2 / liter                      1
# bioavailability        dimensionless                                12
# clearance              liter / hour                                642
#                        liter / hour / kilogram                     553
#                        milliliter / meter ** 2 / minute             77
# clearance_intrinsic    liter / hour                                  9
#                        liter / hour / kilogram                       2
# clearance_renal        liter / hour                                 95
#                        liter / hour / kilogram                      62
# clearance_unbound      liter / hour                                  7
# cmax                   gram / liter                                779
# concentration          gram / liter                                 40
# cumulative amount      gram                                        134
#                        mole                                         46
# extraction_ratio       dimensionless                                40
# fraction_absorbed      dimensionless                               116
#                        none                                          5
# fraction_unbound       dimensionless                                20
# kabs                   1 / minute                                   21
# kel                    1 / minute                                  425
# lag_absorption         hour                                          2
# mrt                    hour                                         23
# plasma_binding         dimensionless                                 7
# ra                     1 / minute                                    3
# rate_gastric_emptying  1 / minute                                    7
# recovery               dimensionless                               316
# thalf                  hour                                        982
# thalf_absorption       hour                                         26
# thalf_gastric_emptying hour                                         15
# tmax                   hour                                        709
# vd                     liter                                       324
#                        liter / kilogram                            303
#                        liter / meter ** 2                           22
# vd_ss                  liter                                        20
# weight                 kilogram                                      2
#
#                                                          tissue  access  \
# measurement_type       unit
# age                    yr                                     2       2
# amount                 gram                                  30      30
# auc_end                gram * hour / liter                  561     561
# auc_inf                gram * hour / liter                  828     828
# aumc_inf               gram * hour ** 2 / liter               1       1
# bioavailability        dimensionless                         12      12
# clearance              liter / hour                         642     642
#                        liter / hour / kilogram              553     553
#                        milliliter / meter ** 2 / minute      77      77
# clearance_intrinsic    liter / hour                           9       9
#                        liter / hour / kilogram                2       2
# clearance_renal        liter / hour                          95      95
#                        liter / hour / kilogram               62      62
# clearance_unbound      liter / hour                           7       7
# cmax                   gram / liter                         779     779
# concentration          gram / liter                          40      40
# cumulative amount      gram                                 134     134
#                        mole                                  46      46
# extraction_ratio       dimensionless                         40      40
# fraction_absorbed      dimensionless                        116     116
#                        none                                   5       5
# fraction_unbound       dimensionless                         20      20
# kabs                   1 / minute                            21      21
# kel                    1 / minute                           425     425
# lag_absorption         hour                                   2       2
# mrt                    hour                                  23      23
# plasma_binding         dimensionless                          7       7
# ra                     1 / minute                             3       3
# rate_gastric_emptying  1 / minute                             7       7
# recovery               dimensionless                        316     316
# thalf                  hour                                 982     982
# thalf_absorption       hour                                  26      26
# thalf_gastric_emptying hour                                  15      15
# tmax                   hour                                 709     709
# vd                     liter                                324     324
#                        liter / kilogram                     303     303
#                        liter / meter ** 2                    22      22
# vd_ss                  liter                                 20      20
# weight                 kilogram                               2       2
#
#                                                          raw_pk  calculated  \
# measurement_type       unit
# age                    yr                                     2           2
# amount                 gram                                  30          30
# auc_end                gram * hour / liter                  561         561
# auc_inf                gram * hour / liter                  828         828
# aumc_inf               gram * hour ** 2 / liter               1           1
# bioavailability        dimensionless                         12          12
# clearance              liter / hour                         642         642
#                        liter / hour / kilogram              553         553
#                        milliliter / meter ** 2 / minute      77          77
# clearance_intrinsic    liter / hour                           9           9
#                        liter / hour / kilogram                2           2
# clearance_renal        liter / hour                          95          95
#                        liter / hour / kilogram               62          62
# clearance_unbound      liter / hour                           7           7
# cmax                   gram / liter                         779         779
# concentration          gram / liter                          40          40
# cumulative amount      gram                                 134         134
#                        mole                                  46          46
# extraction_ratio       dimensionless                         40          40
# fraction_absorbed      dimensionless                        116         116
#                        none                                   5           5
# fraction_unbound       dimensionless                         20          20
# kabs                   1 / minute                            21          21
# kel                    1 / minute                           425         425
# lag_absorption         hour                                   2           2
# mrt                    hour                                  23          23
# plasma_binding         dimensionless                          7           7
# ra                     1 / minute                             3           3
# rate_gastric_emptying  1 / minute                             7           7
# recovery               dimensionless                        316         316
# thalf                  hour                                 982         982
# thalf_absorption       hour                                  26          26
# thalf_gastric_emptying hour                                  15          15
# tmax                   hour                                 709         709
# vd                     liter                                324         324
#                        liter / kilogram                     303         303
#                        liter / meter ** 2                    22          22
# vd_ss                  liter                                 20          20
# weight                 kilogram                               2           2
#
#                                                          interventions  \
# measurement_type       unit
# age                    yr                                            2
# amount                 gram                                         30
# auc_end                gram * hour / liter                         561
# auc_inf                gram * hour / liter                         828
# aumc_inf               gram * hour ** 2 / liter                      1
# bioavailability        dimensionless                                12
# clearance              liter / hour                                642
#                        liter / hour / kilogram                     553
#                        milliliter / meter ** 2 / minute             77
# clearance_intrinsic    liter / hour                                  9
#                        liter / hour / kilogram                       2
# clearance_renal        liter / hour                                 95
#                        liter / hour / kilogram                      62
# clearance_unbound      liter / hour                                  7
# cmax                   gram / liter                                779
# concentration          gram / liter                                 40
# cumulative amount      gram                                        134
#                        mole                                         46
# extraction_ratio       dimensionless                                40
# fraction_absorbed      dimensionless                               116
#                        none                                          5
# fraction_unbound       dimensionless                                20
# kabs                   1 / minute                                   21
# kel                    1 / minute                                  425
# lag_absorption         hour                                          2
# mrt                    hour                                         23
# plasma_binding         dimensionless                                 7
# ra                     1 / minute                                    3
# rate_gastric_emptying  1 / minute                                    7
# recovery               dimensionless                               316
# thalf                  hour                                        982
# thalf_absorption       hour                                         26
# thalf_gastric_emptying hour                                         15
# tmax                   hour                                        709
# vd                     liter                                       324
#                        liter / kilogram                            303
#                        liter / meter ** 2                           22
# vd_ss                  liter                                        20
# weight                 kilogram                                      2
#
#                                                          substance  \
# measurement_type       unit
# age                    yr                                        2
# amount                 gram                                     30
# auc_end                gram * hour / liter                     561
# auc_inf                gram * hour / liter                     828
# aumc_inf               gram * hour ** 2 / liter                  1
# bioavailability        dimensionless                            12
# clearance              liter / hour                            642
#                        liter / hour / kilogram                 553
#                        milliliter / meter ** 2 / minute         77
# clearance_intrinsic    liter / hour                              9
#                        liter / hour / kilogram                   2
# clearance_renal        liter / hour                             95
#                        liter / hour / kilogram                  62
# clearance_unbound      liter / hour                              7
# cmax                   gram / liter                            779
# concentration          gram / liter                             40
# cumulative amount      gram                                    134
#                        mole                                     46
# extraction_ratio       dimensionless                            40
# fraction_absorbed      dimensionless                           116
#                        none                                      5
# fraction_unbound       dimensionless                            20
# kabs                   1 / minute                               21
# kel                    1 / minute                              425
# lag_absorption         hour                                      2
# mrt                    hour                                     23
# plasma_binding         dimensionless                             7
# ra                     1 / minute                                3
# rate_gastric_emptying  1 / minute                                7
# recovery               dimensionless                           316
# thalf                  hour                                    982
# thalf_absorption       hour                                     26
# thalf_gastric_emptying hour                                      1
# tmax                   hour                                    709
# vd                     liter                                   324
#                        liter / kilogram                        303
#                        liter / meter ** 2                       22
# vd_ss                  liter                                    20
# weight                 kilogram                                  2
#
#                                                          group_count  \
# measurement_type       unit
# age                    yr                                          2
# amount                 gram                                        0
# auc_end                gram * hour / liter                       412
# auc_inf                gram * hour / liter                       410
# aumc_inf               gram * hour ** 2 / liter                    1
# bioavailability        dimensionless                               4
# clearance              liter / hour                              259
#                        liter / hour / kilogram                   170
#                        milliliter / meter ** 2 / minute            4
# clearance_intrinsic    liter / hour                                1
#                        liter / hour / kilogram                     2
# clearance_renal        liter / hour                               52
#                        liter / hour / kilogram                    27
# clearance_unbound      liter / hour                                1
# cmax                   gram / liter                              484
# concentration          gram / liter                               40
# cumulative amount      gram                                       60
#                        mole                                       16
# extraction_ratio       dimensionless                               0
# fraction_absorbed      dimensionless                              27
#                        none                                        3
# fraction_unbound       dimensionless                               4
# kabs                   1 / minute                                  4
# kel                    1 / minute                                289
# lag_absorption         hour                                        0
# mrt                    hour                                       23
# plasma_binding         dimensionless                               1
# ra                     1 / minute                                  3
# rate_gastric_emptying  1 / minute                                  0
# recovery               dimensionless                             115
# thalf                  hour                                      465
# thalf_absorption       hour                                       13
# thalf_gastric_emptying hour                                        1
# tmax                   hour                                      437
# vd                     liter                                     204
#                        liter / kilogram                          126
#                        liter / meter ** 2                          9
# vd_ss                  liter                                       4
# weight                 kilogram                                    2
#
#                                                          group_name  group_pk  \
# measurement_type       unit
# age                    yr                                         2         2
# amount                 gram                                       0         0
# auc_end                gram * hour / liter                      412       412
# auc_inf                gram * hour / liter                      410       410
# aumc_inf               gram * hour ** 2 / liter                   1         1
# bioavailability        dimensionless                              4         4
# clearance              liter / hour                             259       259
#                        liter / hour / kilogram                  170       170
#                        milliliter / meter ** 2 / minute           4         4
# clearance_intrinsic    liter / hour                               1         1
#                        liter / hour / kilogram                    2         2
# clearance_renal        liter / hour                              52        52
#                        liter / hour / kilogram                   27        27
# clearance_unbound      liter / hour                               1         1
# cmax                   gram / liter                             484       484
# concentration          gram / liter                              40        40
# cumulative amount      gram                                      60        60
#                        mole                                      16        16
# extraction_ratio       dimensionless                              0         0
# fraction_absorbed      dimensionless                             27        27
#                        none                                       3         3
# fraction_unbound       dimensionless                              4         4
# kabs                   1 / minute                                 4         4
# kel                    1 / minute                               289       289
# lag_absorption         hour                                       0         0
# mrt                    hour                                      23        23
# plasma_binding         dimensionless                              1         1
# ra                     1 / minute                                 3         3
# rate_gastric_emptying  1 / minute                                 0         0
# recovery               dimensionless                            115       115
# thalf                  hour                                     465       465
# thalf_absorption       hour                                      13        13
# thalf_gastric_emptying hour                                       1         1
# tmax                   hour                                     437       437
# vd                     liter                                    204       204
#                        liter / kilogram                         126       126
#                        liter / meter ** 2                         9         9
# vd_ss                  liter                                      4         4
# weight                 kilogram                                   2         2
#
#                                                          ...  mean  \
# measurement_type       unit                              ...
# age                    yr                                ...     2
# amount                 gram                              ...     0
# auc_end                gram * hour / liter               ...   403
# auc_inf                gram * hour / liter               ...   382
# aumc_inf               gram * hour ** 2 / liter          ...     1
# bioavailability        dimensionless                     ...     4
# clearance              liter / hour                      ...   248
#                        liter / hour / kilogram           ...   169
#                        milliliter / meter ** 2 / minute  ...     0
# clearance_intrinsic    liter / hour                      ...     1
#                        liter / hour / kilogram           ...     1
# clearance_renal        liter / hour                      ...    34
#                        liter / hour / kilogram           ...    27
# clearance_unbound      liter / hour                      ...     1
# cmax                   gram / liter                      ...   455
# concentration          gram / liter                      ...    40
# cumulative amount      gram                              ...    60
#                        mole                              ...    16
# extraction_ratio       dimensionless                     ...     0
# fraction_absorbed      dimensionless                     ...    25
#                        none                              ...     3
# fraction_unbound       dimensionless                     ...     4
# kabs                   1 / minute                        ...     4
# kel                    1 / minute                        ...   285
# lag_absorption         hour                              ...     0
# mrt                    hour                              ...    22
# plasma_binding         dimensionless                     ...     1
# ra                     1 / minute                        ...     3
# rate_gastric_emptying  1 / minute                        ...     0
# recovery               dimensionless                     ...   115
# thalf                  hour                              ...   435
# thalf_absorption       hour                              ...    13
# thalf_gastric_emptying hour                              ...     1
# tmax                   hour                              ...   388
# vd                     liter                             ...   194
#                        liter / kilogram                  ...   118
#                        liter / meter ** 2                ...     9
# vd_ss                  liter                             ...     4
# weight                 kilogram                          ...     2
#
#                                                          timecourse_pk  \
# measurement_type       unit
# age                    yr                                            0
# amount                 gram                                          0
# auc_end                gram * hour / liter                         363
# auc_inf                gram * hour / liter                         320
# aumc_inf               gram * hour ** 2 / liter                      0
# bioavailability        dimensionless                                 0
# clearance              liter / hour                                251
#                        liter / hour / kilogram                      63
#                        milliliter / meter ** 2 / minute              0
# clearance_intrinsic    liter / hour                                  0
#                        liter / hour / kilogram                       0
# clearance_renal        liter / hour                                  0
#                        liter / hour / kilogram                       0
# clearance_unbound      liter / hour                                  0
# cmax                   gram / liter                                412
# concentration          gram / liter                                  0
# cumulative amount      gram                                          0
#                        mole                                          0
# extraction_ratio       dimensionless                                 0
# fraction_absorbed      dimensionless                                 0
#                        none                                          0
# fraction_unbound       dimensionless                                 0
# kabs                   1 / minute                                    0
# kel                    1 / minute                                  332
# lag_absorption         hour                                          0
# mrt                    hour                                          0
# plasma_binding         dimensionless                                 0
# ra                     1 / minute                                    0
# rate_gastric_emptying  1 / minute                                    0
# recovery               dimensionless                                 0
# thalf                  hour                                        332
# thalf_absorption       hour                                          0
# thalf_gastric_emptying hour                                          0
# tmax                   hour                                        412
# vd                     liter                                       251
#                        liter / kilogram                             63
#                        liter / meter ** 2                            0
# vd_ss                  liter                                         0
# weight                 kilogram                                      0
#
#                                                          time_unit  time   se  \
# measurement_type       unit
# age                    yr                                        0     0    0
# amount                 gram                                     30    30    0
# auc_end                gram * hour / liter                     557   557  116
# auc_inf                gram * hour / liter                       0     0  132
# aumc_inf               gram * hour ** 2 / liter                  0     0    1
# bioavailability        dimensionless                             0     0    3
# clearance              liter / hour                              0     0   49
#                        liter / hour / kilogram                  20    12  100
#                        milliliter / meter ** 2 / minute          0     0    0
# clearance_intrinsic    liter / hour                              0     0    1
#                        liter / hour / kilogram                   0     0    1
# clearance_renal        liter / hour                             23    23   25
#                        liter / hour / kilogram                  23    23   24
# clearance_unbound      liter / hour                              0     0    1
# cmax                   gram / liter                              2     0  145
# concentration          gram / liter                             40    40   16
# cumulative amount      gram                                    134   134   60
#                        mole                                     46    46   16
# extraction_ratio       dimensionless                             0     0    0
# fraction_absorbed      dimensionless                             2     2   16
#                        none                                      0     0    3
# fraction_unbound       dimensionless                             0     0    4
# kabs                   1 / minute                                0     0    3
# kel                    1 / minute                                0     0   22
# lag_absorption         hour                                      0     0    0
# mrt                    hour                                      0     0   10
# plasma_binding         dimensionless                             0     0    1
# ra                     1 / minute                                0     0    3
# rate_gastric_emptying  1 / minute                                0     0    0
# recovery               dimensionless                           313   313  112
# thalf                  hour                                      2     0  151
# thalf_absorption       hour                                      0     0    3
# thalf_gastric_emptying hour                                      0     0    1
# tmax                   hour                                      2     0   83
# vd                     liter                                     0     0   11
#                        liter / kilogram                          0     0   40
#                        liter / meter ** 2                        0     0    9
# vd_ss                  liter                                     0     0    4
# weight                 kilogram                                  0     0    0
#
#                                                           cv   sd  min  max  \
# measurement_type       unit
# age                    yr                                  0    0    2    2
# amount                 gram                                0    0    0    0
# auc_end                gram * hour / liter               116   99    6    6
# auc_inf                gram * hour / liter               129   85   31   31
# aumc_inf               gram * hour ** 2 / liter            1    1    0    0
# bioavailability        dimensionless                       3    0    0    0
# clearance              liter / hour                       49   35   12   12
#                        liter / hour / kilogram            99   75   13   13
#                        milliliter / meter ** 2 / minute    0    0    4    4
# clearance_intrinsic    liter / hour                        1    1    0    0
#                        liter / hour / kilogram             1    1    0    0
# clearance_renal        liter / hour                       25   21   24   24
#                        liter / hour / kilogram            24   18    0    0
# clearance_unbound      liter / hour                        1    1    0    0
# cmax                   gram / liter                      142  105   39   39
# concentration          gram / liter                       16    0   22   22
# cumulative amount      gram                               60    2    0    0
#                        mole                               16    0    0    0
# extraction_ratio       dimensionless                       0    0    0    0
# fraction_absorbed      dimensionless                      16    9    8    8
#                        none                                3    0    0    0
# fraction_unbound       dimensionless                       4    0    0    0
# kabs                   1 / minute                          3    2    0    0
# kel                    1 / minute                         22    6    6    6
# lag_absorption         hour                                0    0    0    0
# mrt                    hour                               10   10    0    0
# plasma_binding         dimensionless                       1    1    0    0
# ra                     1 / minute                          3    0    0    0
# rate_gastric_emptying  1 / minute                          0    0    0    0
# recovery               dimensionless                     112   98    0    0
# thalf                  hour                              144  108   27   27
# thalf_absorption       hour                                3    3    8    8
# thalf_gastric_emptying hour                                1    0    0    0
# tmax                   hour                               81   65   51   51
# vd                     liter                              11    8   12   12
#                        liter / kilogram                   37   21   22   22
#                        liter / meter ** 2                  9    9    0    0
# vd_ss                  liter                               4    0    0    0
# weight                 kilogram                            0    0    2    2
#
#                                                          median
# measurement_type       unit
# age                    yr                                     0
# amount                 gram                                   0
# auc_end                gram * hour / liter                    9
# auc_inf                gram * hour / liter                   25
# aumc_inf               gram * hour ** 2 / liter               0
# bioavailability        dimensionless                          0
# clearance              liter / hour                           7
#                        liter / hour / kilogram                0
#                        milliliter / meter ** 2 / minute       4
# clearance_intrinsic    liter / hour                           0
#                        liter / hour / kilogram                0
# clearance_renal        liter / hour                          16
#                        liter / hour / kilogram                0
# clearance_unbound      liter / hour                           0
# cmax                   gram / liter                          25
# concentration          gram / liter                           0
# cumulative amount      gram                                   0
#                        mole                                   0
# extraction_ratio       dimensionless                          0
# fraction_absorbed      dimensionless                          0
#                        none                                   0
# fraction_unbound       dimensionless                          0
# kabs                   1 / minute                             0
# kel                    1 / minute                             3
# lag_absorption         hour                                   0
# mrt                    hour                                   0
# plasma_binding         dimensionless                          0
# ra                     1 / minute                             0
# rate_gastric_emptying  1 / minute                             0
# recovery               dimensionless                          0
# thalf                  hour                                   7
# thalf_absorption       hour                                   0
# thalf_gastric_emptying hour                                   0
# tmax                   hour                                  52
# vd                     liter                                  7
#                        liter / kilogram                       4
#                        liter / meter ** 2                     0
# vd_ss                  liter                                  0
# weight                 kilogram                               0
#
# [39 rows x 23 columns]

# %% [markdown]
# ### Merge
#  - merge individuals and groups  --> all_subjects,
#  - merge outputs and timecourses --> all_results,
#  - merge all_results with interventions and individuals  --> individuals_complete,
#  - merge all_results with interventions and groups  --> groups_complete,
#  - merge all_results with interventions and all_subjects -->  all_complete

# %%
prepocessed = Preprocessed()

# %%
prepocessed.read()
prepocessed.merge()
prepocessed.save()
# Out:
# /home/janekg/Env/pkdb_analysis/local/lib/python3.6/site-packages/pandas/core/reshape/merge.py:617: UserWarning: merging between different levels can give an unintended result (1 levels on the left, 2 on the right)
#   warnings.warn(msg, UserWarning)
# /home/janekg/Env/pkdb_analysis/local/lib/python3.6/site-packages/pandas/core/generic.py:3946: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   new_axis = axis.drop(labels, errors=errors)
