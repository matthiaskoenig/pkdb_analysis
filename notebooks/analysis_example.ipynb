# %%
# %load_ext autoreload
# %autoreload 2
from IPython.display import display
import pkdb_analysis as pka

# %%
data = pka.PKDBData.from_hdf5("pkdb_all.h5")
print(data)
# Out:
# WARNING:root:/groups
# WARNING:root:/individuals
# WARNING:root:/interventions
# WARNING:root:/outputs
# WARNING:root:/timecourses
# WARNING:root:Calculating choices
# <class 'pkdb_analysis.data.PKDBData'>
# 	interventions: 1362
# 	individuals: 27982
# 	groups: 4591
# 	outputs: 20278
# 	timecourses: 1929

# %%
data.interventions
# Out:
#       study_sid study_name    pk  raw_pk  normed     name route      form  \
# 0     PKDB00203  Klotz1982   117      -1   False       iv    iv  solution
# 1     PKDB00203  Klotz1982   118      -1   False       po  oral   no info
# 2     PKDB00203  Klotz1982   119     117    True       iv    iv  solution
# 3     PKDB00203  Klotz1982   120     118    True       po  oral   no info
# 4     PKDB00203  Klotz1982   121      -1   False  morning  None      None
# ...         ...        ...   ...     ...     ...      ...   ...       ...
# 1357  PKDB00116    Yue1999  1405      -1   False      DEB  oral      None
# 1358  PKDB00116    Yue1999  1404    1403    True     MEAL  oral      None
# 1359  PKDB00116    Yue1999  1403      -1   False     MEAL  oral      None
# 1360    3356089  Arias1988  1408    1407    True      SPA  oral      None
# 1361    3356089  Arias1988  1407      -1   False      SPA  oral      None
#
#       application  time  ...          substance      value mean median  min  \
# ...

# %%
data.print_choices("groups")
# Out:
# *** study_sid ***
# ...

# %%
individuals = data.individuals
print(individuals.substance.unique())
print(individuals.substance.dtype)

# interventions[interventions.substance=="caffeine"]
# Out:
# [nan 'sunitinib' 'grapefruit juice' 'caffeine' 'albumin' 'haemoglobin'
#  'urea' 'creatinine' 'bilirubin' 'alt' 'alp' 'paracetamol' 'ast' 'got'
#  'kola nuts' 'methylxanthine' 'coffee' 'tea' 'cocoa' 'clozapine' 'codeine'
#  'morphine' 'chlordiazepoxide' 'hydrochlorthiazide' 'amiloride'
#  'diltiazem' 'acetylsalicylic acid' 'enalapril' 'salbutamol'
#  'beclometasone']
# object

# %%
print(individuals)
# Out:
#        study_sid   study_name  individual_pk  individual_name  \
# 0      PKDB00181  Allonen1981              6                6
# 1      PKDB00181  Allonen1981              6                6
# 2      PKDB00181  Allonen1981              6                6
# 3      PKDB00181  Allonen1981              6                6
# 4      PKDB00181  Allonen1981              6                6
# ...          ...          ...            ...              ...
# 27977    3356089    Arias1988           2953             2953
# 27978    3356089    Arias1988           2953             2953
# 27979    3356089    Arias1988           2953             2953
# 27980    3356089    Arias1988           2953             2953
# 27981    3356089    Arias1988           2953             2953
#
#        individual_group_pk  characteristica_pk  count       measurement_type  \
# 0                        1                  35      1                 weight
# ...
