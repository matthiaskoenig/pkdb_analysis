# %%
# %load_ext autoreload
# %autoreload 2
from IPython.display import display

import pkdb_analysis as pka
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = pka.PKDBData.from_db()
# Out:
# WARNING:root:*** Querying data ***
# WARNING:root:http://0.0.0.0:8000/api/v1/interventions_elastic/?format=json&page_size=2000
# WARNING:root:http://0.0.0.0:8000/api/v1/interventions_elastic/?format=json&page_size=2000&page=1
# WARNING:root:http://0.0.0.0:8000/api/v1/characteristica_elastic/?format=json&page_size=2000
# WARNING:root:http://0.0.0.0:8000/api/v1/characteristica_elastic/?format=json&page_size=2000&page=1
# WARNING:root:http://0.0.0.0:8000/api/v1/characteristica_elastic/?format=json&page_size=2000&page=2
# WARNING:root:http://0.0.0.0:8000/api/v1/output_intervention/?format=json&page_size=2000
# WARNING:root:http://0.0.0.0:8000/api/v1/output_intervention/?format=json&page_size=2000&page=1
# WARNING:root:http://0.0.0.0:8000/api/v1/output_intervention/?format=json&page_size=2000&page=2
# WARNING:root:http://0.0.0.0:8000/api/v1/output_intervention/?format=json&page_size=2000&page=3
# WARNING:root:http://0.0.0.0:8000/api/v1/timecourse_intervention/?format=json&page_size=2000
# ...

# %%
print("interventions")
display(data.interventions)
print("characteristica")
display(data.characteristica)
print("outputs")
display(data.outputs)
print("timecourses")
display(data.timecourses)
# Out:
# interventions
#       pk  study_sid         study_name  normed  raw_pk     value  mean  \
# 0     93  PKDB00207  Kupferschmidt1995   False     NaN     5.000   NaN
# 1     94  PKDB00207  Kupferschmidt1995   False     NaN    15.000   NaN
# 2     95  PKDB00207  Kupferschmidt1995    True    93.0     0.005   NaN
# 3     96  PKDB00207  Kupferschmidt1995    True    94.0     0.015   NaN
# 4     97  PKDB00207  Kupferschmidt1995   False     NaN   200.000   NaN
# ..   ...        ...                ...     ...     ...       ...   ...
# 399  427  PKDB00214         Kamali1992   False     NaN       NaN   NaN
# 400  430  PKDB00141         Kamali1993    True   429.0     1.500   NaN
# 401  429  PKDB00141         Kamali1993   False     NaN  1500.000   NaN
# 402  432  PKDB00141         Kamali1993    True   431.0     1.000   NaN
# 403  431  PKDB00141         Kamali1993   False     NaN  1000.000   NaN
#
#      median  min  max  ...  unit                       name  route      form  \
# ...

# %%
data.to_hdf5("example1.h5")
data2 = pka.PKDBData.from_hdf5("example1.h5")
# Out:
# /home/janekg/Env/pkdb_analysis/lib/python3.6/site-packages/ipykernel_launcher.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block3_values] [items->['study_sid', 'study_name', 'unit', 'name', 'route', 'form', 'application', 'time_unit', 'measurement_type', 'choice', 'substance']]
#
#   """Entry point for launching an IPython kernel.
# /home/janekg/Env/pkdb_analysis/lib/python3.6/site-packages/ipykernel_launcher.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block3_values] [items->['study_sid', 'study_name', 'subject_type', 'measurement_type', 'choice', 'substance', 'unit', 'group_name', 'individual_name']]
#
#   """Entry point for launching an IPython kernel.
# ...

# %% [markdown]
# # Example queries
#
# ## 1. Get data for study

# %%
# Allonen1981 (sid=PKDB00181)
# TODO: query

# %%
# questions: get groups with characterista X
#            get individuals with characterista X
#            exclude groups with characterista X
#            exclude individuals with characterista X

#            get interventions with characteristca
#            exclude interventions with characteristca

#            get outputs with subjects having a characteristca X
#            exclude outputs with subjects having a characteristca X
