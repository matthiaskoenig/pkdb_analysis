# %%
# %load_ext autoreload
# %autoreload 2
from IPython.display import display
import pkdb_analysis as pka
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# get all data and store as hdf5
#data = pka.PKDBData.from_db()
#data.to_hdf5("pkdb_all.h5")

# %%
# data with filters
general_filter = {"study_name": "Allonen1981"}
# todo: unify Y, "true", True ?
filters = {
    
    "groups":{
        **general_filter, 
       
    },
    "individuals":{
         **general_filter, 
    },
    "interventions": {
       **general_filter, 
        "normed":"true"
    },
    "outputs": {
         **general_filter, 
        "calculated":"true",
        "normed":"true"

    },
    "timecourses": {
         **general_filter, 
        "normed":"true"

    }
}
data = pka.PKDBData.from_db(filters)


print("groups")
display(data.groups)
print("individuals")
display(data.individuals)
print("interventions")
display(data.interventions)
print("outputs")
display(data.outputs)
print("timecourses")
display(data.timecourses)
# Out:
# WARNING:root:*** Querying data ***
# WARNING:root:http://0.0.0.0:8000/api/v1/interventions_elastic/?format=json&page_size=2000&study_name=Allonen1981&normed=true
# WARNING:root:http://0.0.0.0:8000/api/v1/interventions_elastic/?format=json&page_size=2000&study_name=Allonen1981&normed=true&page=1
# WARNING:root:http://0.0.0.0:8000/api/v1/characteristica_individuals/?format=json&page_size=2000&study_name=Allonen1981
# WARNING:root:http://0.0.0.0:8000/api/v1/characteristica_individuals/?format=json&page_size=2000&study_name=Allonen1981&page=1
# WARNING:root:http://0.0.0.0:8000/api/v1/characteristica_groups/?format=json&page_size=2000&study_name=Allonen1981
# WARNING:root:http://0.0.0.0:8000/api/v1/characteristica_groups/?format=json&page_size=2000&study_name=Allonen1981&page=1
# WARNING:root:http://0.0.0.0:8000/api/v1/output_intervention/?format=json&page_size=2000&study_name=Allonen1981&calculated=true&normed=true
# WARNING:root:http://0.0.0.0:8000/api/v1/output_intervention/?format=json&page_size=2000&study_name=Allonen1981&calculated=true&normed=true&page=1
# WARNING:root:http://0.0.0.0:8000/api/v1/timecourse_intervention/?format=json&page_size=2000&study_name=Allonen1981&normed=true
# WARNING:root:http://0.0.0.0:8000/api/v1/timecourse_intervention/?format=json&page_size=2000&study_name=Allonen1981&normed=true&page=1
# WARNING:root:Calculating choices
# groups
#    study_sid   study_name  group_pk group_name  group_count  group_parent_pk  \
# 0  PKDB00181  Allonen1981         1        all            6               -1
# 1  PKDB00181  Allonen1981         1        all            6               -1
# 2  PKDB00181  Allonen1981         1        all            6               -1
# 3  PKDB00181  Allonen1981         1        all            6               -1
# 4  PKDB00181  Allonen1981         1        all            6               -1
# 5  PKDB00181  Allonen1981         1        all            6               -1
#
#    characteristica_pk  count measurement_type        choice substance  value  \
# 0                  12      6   overnight fast             Y      None    NaN
# 1                  11      6              age          None      None    NaN
# 2                  10      5          smoking             N      None    NaN
# 3                   9      1          smoking             Y      None    NaN
# 4                   8      6          healthy             Y      None    NaN
# 5                   7      6          species  homo sapiens      None    NaN
#
#    mean  median   min   max  sd  se  cv  unit
# 0   NaN     NaN   NaN   NaN NaN NaN NaN  None
# 1   NaN     NaN  25.0  37.0 NaN NaN NaN    yr
# 2   NaN     NaN   NaN   NaN NaN NaN NaN  None
# 3   NaN     NaN   NaN   NaN NaN NaN NaN  None
# 4   NaN     NaN   NaN   NaN NaN NaN NaN  None
# 5   NaN     NaN   NaN   NaN NaN NaN NaN  None
# individuals
#     study_sid   study_name  individual_pk individual_name  \
# 0   PKDB00181  Allonen1981              6              GZ
# 1   PKDB00181  Allonen1981              6              GZ
# 2   PKDB00181  Allonen1981              6              GZ
# 3   PKDB00181  Allonen1981              6              GZ
# 4   PKDB00181  Allonen1981              6              GZ
# 5   PKDB00181  Allonen1981              6              GZ
# 6   PKDB00181  Allonen1981              6              GZ
# 7   PKDB00181  Allonen1981              1              WS
# 8   PKDB00181  Allonen1981              1              WS
# 9   PKDB00181  Allonen1981              1              WS
# 10  PKDB00181  Allonen1981              1              WS
# 11  PKDB00181  Allonen1981              1              WS
# 12  PKDB00181  Allonen1981              1              WS
# 13  PKDB00181  Allonen1981              1              WS
# 14  PKDB00181  Allonen1981              3              TF
# 15  PKDB00181  Allonen1981              3              TF
# 16  PKDB00181  Allonen1981              3              TF
# 17  PKDB00181  Allonen1981              3              TF
# 18  PKDB00181  Allonen1981              3              TF
# 19  PKDB00181  Allonen1981              3              TF
# 20  PKDB00181  Allonen1981              3              TF
# 21  PKDB00181  Allonen1981              5              FS
# 22  PKDB00181  Allonen1981              5              FS
# 23  PKDB00181  Allonen1981              5              FS
# 24  PKDB00181  Allonen1981              5              FS
# 25  PKDB00181  Allonen1981              5              FS
# 26  PKDB00181  Allonen1981              5              FS
# 27  PKDB00181  Allonen1981              5              FS
# 28  PKDB00181  Allonen1981              2              HA
# 29  PKDB00181  Allonen1981              2              HA
# 30  PKDB00181  Allonen1981              2              HA
# 31  PKDB00181  Allonen1981              2              HA
# 32  PKDB00181  Allonen1981              2              HA
# 33  PKDB00181  Allonen1981              2              HA
# 34  PKDB00181  Allonen1981              2              HA
# 35  PKDB00181  Allonen1981              4              UK
# 36  PKDB00181  Allonen1981              4              UK
# 37  PKDB00181  Allonen1981              4              UK
# 38  PKDB00181  Allonen1981              4              UK
# 39  PKDB00181  Allonen1981              4              UK
# 40  PKDB00181  Allonen1981              4              UK
# 41  PKDB00181  Allonen1981              4              UK
#
#     individual_group_pk  characteristica_pk  count measurement_type  \
# 0                     1                  12      6   overnight fast
# 1                     1                  10      5          smoking
# 2                     1                   9      1          smoking
# 3                     1                   8      6          healthy
# 4                     1                   7      6          species
# 5                     1                  36      1              age
# 6                     1                  35      1           weight
# 7                     1                  16      1              age
# 8                     1                  15      1           weight
# 9                     1                  12      6   overnight fast
# 10                    1                  10      5          smoking
# 11                    1                   9      1          smoking
# 12                    1                   8      6          healthy
# 13                    1                   7      6          species
# 14                    1                  24      1              age
# 15                    1                  23      1           weight
# 16                    1                  12      6   overnight fast
# 17                    1                  10      5          smoking
# 18                    1                   9      1          smoking
# 19                    1                   8      6          healthy
# 20                    1                   7      6          species
# 21                    1                  31      1           weight
# 22                    1                  12      6   overnight fast
# 23                    1                  10      5          smoking
# 24                    1                   9      1          smoking
# 25                    1                   8      6          healthy
# 26                    1                   7      6          species
# 27                    1                  32      1              age
# 28                    1                  20      1              age
# 29                    1                  19      1           weight
# 30                    1                  12      6   overnight fast
# 31                    1                  10      5          smoking
# 32                    1                   9      1          smoking
# 33                    1                   8      6          healthy
# 34                    1                   7      6          species
# 35                    1                  28      1              age
# 36                    1                  27      1           weight
# 37                    1                  12      6   overnight fast
# 38                    1                  10      5          smoking
# 39                    1                   9      1          smoking
# 40                    1                   8      6          healthy
# 41                    1                   7      6          species
#
#           choice substance  value  mean  median  min  max  sd  se  cv  \
# 0              Y      None    NaN   NaN     NaN  NaN  NaN NaN NaN NaN
# 1              N      None    NaN   NaN     NaN  NaN  NaN NaN NaN NaN
# 2              Y      None    NaN   NaN     NaN  NaN  NaN NaN NaN NaN
# 3              Y      None    NaN   NaN     NaN  NaN  NaN NaN NaN NaN
# 4   homo sapiens      None    NaN   NaN     NaN  NaN  NaN NaN NaN NaN
# 5           None      None   29.0   NaN     NaN  NaN  NaN NaN NaN NaN
# 6           None      None   79.0   NaN     NaN  NaN  NaN NaN NaN NaN
# 7           None      None   25.0   NaN     NaN  NaN  NaN NaN NaN NaN
# 8           None      None   74.0   NaN     NaN  NaN  NaN NaN NaN NaN
# 9              Y      None    NaN   NaN     NaN  NaN  NaN NaN NaN NaN
# 10             N      None    NaN   NaN     NaN  NaN  NaN NaN NaN NaN
# 11             Y      None    NaN   NaN     NaN  NaN  NaN NaN NaN NaN
# 12             Y      None    NaN   NaN     NaN  NaN  NaN NaN NaN NaN
# 13  homo sapiens      None    NaN   NaN     NaN  NaN  NaN NaN NaN NaN
# 14          None      None   27.0   NaN     NaN  NaN  NaN NaN NaN NaN
# 15          None      None   63.0   NaN     NaN  NaN  NaN NaN NaN NaN
# 16             Y      None    NaN   NaN     NaN  NaN  NaN NaN NaN NaN
# 17             N      None    NaN   NaN     NaN  NaN  NaN NaN NaN NaN
# 18             Y      None    NaN   NaN     NaN  NaN  NaN NaN NaN NaN
# 19             Y      None    NaN   NaN     NaN  NaN  NaN NaN NaN NaN
# 20  homo sapiens      None    NaN   NaN     NaN  NaN  NaN NaN NaN NaN
# 21          None      None   78.0   NaN     NaN  NaN  NaN NaN NaN NaN
# 22             Y      None    NaN   NaN     NaN  NaN  NaN NaN NaN NaN
# 23             N      None    NaN   NaN     NaN  NaN  NaN NaN NaN NaN
# 24             Y      None    NaN   NaN     NaN  NaN  NaN NaN NaN NaN
# 25             Y      None    NaN   NaN     NaN  NaN  NaN NaN NaN NaN
# 26  homo sapiens      None    NaN   NaN     NaN  NaN  NaN NaN NaN NaN
# 27          None      None   29.0   NaN     NaN  NaN  NaN NaN NaN NaN
# 28          None      None   32.0   NaN     NaN  NaN  NaN NaN NaN NaN
# 29          None      None   59.0   NaN     NaN  NaN  NaN NaN NaN NaN
# 30             Y      None    NaN   NaN     NaN  NaN  NaN NaN NaN NaN
# 31             N      None    NaN   NaN     NaN  NaN  NaN NaN NaN NaN
# 32             Y      None    NaN   NaN     NaN  NaN  NaN NaN NaN NaN
# 33             Y      None    NaN   NaN     NaN  NaN  NaN NaN NaN NaN
# 34  homo sapiens      None    NaN   NaN     NaN  NaN  NaN NaN NaN NaN
# 35          None      None   37.0   NaN     NaN  NaN  NaN NaN NaN NaN
# 36          None      None   67.0   NaN     NaN  NaN  NaN NaN NaN NaN
# 37             Y      None    NaN   NaN     NaN  NaN  NaN NaN NaN NaN
# 38             N      None    NaN   NaN     NaN  NaN  NaN NaN NaN NaN
# 39             Y      None    NaN   NaN     NaN  NaN  NaN NaN NaN NaN
# 40             Y      None    NaN   NaN     NaN  NaN  NaN NaN NaN NaN
# 41  homo sapiens      None    NaN   NaN     NaN  NaN  NaN NaN NaN NaN
#
#         unit
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# 5         yr
# 6   kilogram
# 7         yr
# 8   kilogram
# 9       None
# 10      None
# 11      None
# 12      None
# 13      None
# 14        yr
# 15  kilogram
# 16      None
# 17      None
# 18      None
# 19      None
# 20      None
# 21  kilogram
# 22      None
# 23      None
# 24      None
# 25      None
# 26      None
# 27        yr
# 28        yr
# 29  kilogram
# 30      None
# 31      None
# 32      None
# 33      None
# 34      None
# 35        yr
# 36  kilogram
# 37      None
# 38      None
# 39      None
# 40      None
# 41      None
# interventions
#    study_sid   study_name  pk  raw_pk  normed  name route      form  \
# 0  PKDB00181  Allonen1981   4       2    True  po15  oral    tablet
# 1  PKDB00181  Allonen1981   3       1    True  po75  oral    tablet
# 2  PKDB00181  Allonen1981   6       5    True    iv    iv  solution
#
#    application  time  ...  substance     value mean median  min  max  sd  se  \
# 0  single dose   0.0  ...  midazolam  0.015000  NaN    NaN  NaN  NaN NaN NaN
# 1  single dose   0.0  ...  midazolam  0.007500  NaN    NaN  NaN  NaN NaN NaN
# 2  single dose   0.0  ...  midazolam  0.000075  NaN    NaN  NaN  NaN NaN NaN
#
#    cv             unit
# 0 NaN             gram
# 1 NaN             gram
# 2 NaN  gram / kilogram
#
# [3 rows x 23 columns]
# outputs
#     study_sid   study_name  output_pk  intervention_pk  group_pk  \
# 0   PKDB00181  Allonen1981        191                6         1
# 1   PKDB00181  Allonen1981        206                4         1
# 2   PKDB00181  Allonen1981        207                4         1
# 3   PKDB00181  Allonen1981        188                6         1
# 4   PKDB00181  Allonen1981        204                4         1
# 5   PKDB00181  Allonen1981        187                6         1
# 6   PKDB00181  Allonen1981        189                6         1
# 7   PKDB00181  Allonen1981        193                6         1
# 8   PKDB00181  Allonen1981        203                4         1
# 9   PKDB00181  Allonen1981        205                4         1
# 10  PKDB00181  Allonen1981        190                6         1
# 11  PKDB00181  Allonen1981        192                6         1
# 12  PKDB00181  Allonen1981        194                6         1
# 13  PKDB00181  Allonen1981        208                4         1
# 14  PKDB00181  Allonen1981        209                4         1
# 15  PKDB00181  Allonen1981        210                4         1
#
#     individual_pk  normed  calculated  tissue  time  ...  substance value  \
# 0              -1    True        True  plasma   NaN  ...  midazolam   NaN
# 1              -1    True        True  plasma   NaN  ...  midazolam   NaN
# 2              -1    True        True  plasma   NaN  ...  midazolam   NaN
# 3              -1    True        True  plasma   NaN  ...  midazolam   NaN
# 4              -1    True        True  plasma   NaN  ...  midazolam   NaN
# 5              -1    True        True  plasma  7.00  ...  midazolam   NaN
# 6              -1    True        True  plasma   NaN  ...  midazolam   NaN
# 7              -1    True        True  plasma   NaN  ...  midazolam   NaN
# 8              -1    True        True  plasma  7.01  ...  midazolam   NaN
# 9              -1    True        True  plasma   NaN  ...  midazolam   NaN
# 10             -1    True        True  plasma   NaN  ...  midazolam   NaN
# 11             -1    True        True  plasma   NaN  ...  midazolam   NaN
# 12             -1    True        True  plasma   NaN  ...  midazolam   NaN
# 13             -1    True        True  plasma   NaN  ...  midazolam   NaN
# 14             -1    True        True  plasma   NaN  ...  midazolam   NaN
# 15             -1    True        True  plasma   NaN  ...  midazolam   NaN
#
#           mean median  min  max  sd  se  cv                     unit
# 0     0.006200    NaN  NaN  NaN NaN NaN NaN               1 / minute
# 1     0.000134    NaN  NaN  NaN NaN NaN NaN             gram / liter
# 2     0.006300    NaN  NaN  NaN NaN NaN NaN               1 / minute
# 3     0.000310    NaN  NaN  NaN NaN NaN NaN      gram * hour / liter
# 4     0.000372    NaN  NaN  NaN NaN NaN NaN      gram * hour / liter
# 5     0.000282    NaN  NaN  NaN NaN NaN NaN      gram * hour / liter
# 6     0.242000    NaN  NaN  NaN NaN NaN NaN  liter / hour / kilogram
# 7     0.650000    NaN  NaN  NaN NaN NaN NaN         liter / kilogram
# 8     0.000343    NaN  NaN  NaN NaN NaN NaN      gram * hour / liter
# 9    37.900000    NaN  NaN  NaN NaN NaN NaN             liter / hour
# 10    0.000185    NaN  NaN  NaN NaN NaN NaN             gram / liter
# 11    1.860000    NaN  NaN  NaN NaN NaN NaN                     hour
# 12    0.000000    NaN  NaN  NaN NaN NaN NaN                     hour
# 13    1.830000    NaN  NaN  NaN NaN NaN NaN                     hour
# 14  100.000000    NaN  NaN  NaN NaN NaN NaN                    liter
# 15    0.750000    NaN  NaN  NaN NaN NaN NaN                     hour
#
# [16 rows x 23 columns]
# timecourses
#    study_sid   study_name  timecourse_pk  intervention_pk  group_pk  \
# 0  PKDB00181  Allonen1981              3                6         1
# 1  PKDB00181  Allonen1981              4                4         1
#
#    individual_pk  normed  tissue  \
# 0             -1    True  plasma
# 1             -1    True  plasma
#
#                                                 time time_unit  ...  \
# 0  [0.00e+00, 1.70e-01, 3.30e-01, 5.00e-01, 7.50e...        hr  ...
# 1  [1.70e-01, 3.30e-01, 7.50e-01, 1.00e+00, 1.50e...        hr  ...
#
#    substance value                                               mean median  \
# 0  midazolam  None  [1.85e-04, 1.44e-04, 1.21e-04, 1.06e-04, 8.38e...   None
# 1  midazolam  None  [1.01e-05, 1.32e-04, 1.34e-04, 9.67e-05, 9.66e...   None
#
#     min   max                                                 sd  \
# 0  None  None  [2.33e-05, 1.82e-05, 2.06e-05, 2.68e-05, 1.03e...
# 1  None  None  [4.76e-06, 7.49e-05, 3.01e-05, 4.23e-05, 5.29e...
#
#                                                   se  \
# 0  [9.52e-06, 7.42e-06, 8.40e-06, 1.09e-05, 4.19e...
# 1  [1.94e-06, 3.06e-05, 1.23e-05, 1.73e-05, 2.16e...
#
#                                                   cv          unit
# 0  [1.26e-01, 1.26e-01, 1.71e-01, 2.53e-01, 1.23e...  gram / liter
# 1  [4.71e-01, 5.66e-01, 2.24e-01, 4.37e-01, 5.48e...  gram / liter
#
# [2 rows x 22 columns]

# %%
data.to_hdf5("example1.h5")
data2 = pka.PKDBData.from_hdf5("example1.h5")
# Out:
# WARNING:root:interventions
# /home/janekg/Env/pkdb_analysis/lib/python3.6/site-packages/ipykernel_launcher.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block3_values] [items->['study_sid', 'study_name', 'name', 'route', 'form', 'application', 'time_unit', 'measurement_type', 'choice', 'substance', 'unit']]
#
#   """Entry point for launching an IPython kernel.
# WARNING:root:individuals
# /home/janekg/Env/pkdb_analysis/lib/python3.6/site-packages/ipykernel_launcher.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->['study_sid', 'study_name', 'individual_name', 'measurement_type', 'choice', 'substance', 'unit']]
#
#   """Entry point for launching an IPython kernel.
# WARNING:root:groups
# /home/janekg/Env/pkdb_analysis/lib/python3.6/site-packages/ipykernel_launcher.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->['study_sid', 'study_name', 'group_name', 'measurement_type', 'choice', 'substance', 'unit']]
#
#   """Entry point for launching an IPython kernel.
# WARNING:root:outputs
# /home/janekg/Env/pkdb_analysis/lib/python3.6/site-packages/ipykernel_launcher.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block3_values] [items->['study_sid', 'study_name', 'tissue', 'time_unit', 'measurement_type', 'choice', 'substance', 'unit']]
#
#   """Entry point for launching an IPython kernel.
# WARNING:root:timecourses
# /home/janekg/Env/pkdb_analysis/lib/python3.6/site-packages/ipykernel_launcher.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->['study_sid', 'study_name', 'tissue', 'time', 'time_unit', 'measurement_type', 'choice', 'substance', 'value', 'mean', 'median', 'min', 'max', 'sd', 'se', 'cv', 'unit']]
#
#   """Entry point for launching an IPython kernel.
# WARNING:root:/characteristica
# WARNING:root:/groups
# WARNING:root:/individuals
# WARNING:root:/interventions
# WARNING:root:/outputs
# WARNING:root:/timecourses
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-fb7fe704064e> in <module>
#       1 data.to_hdf5("example1.h5")
# ----> 2 data2 = pka.PKDBData.from_hdf5("example1.h5")
#
# ~/Dev/pkdb_analysis/pkdb_analysis/data.py in from_hdf5(path)
#     171         store.close()
#     172
# --> 173         return PKDBData(**data_dict)
#     174
#     175     def to_hdf5(self, path):
#
# TypeError: __init__() got an unexpected keyword argument 'characteristica'

# %% [markdown]
# # Example queries
#
# ## 1. Query study

# %%
# Allonen1981 (sid=PKDB00181)
# TODO: queries

# %% [markdown]
# ## Query groups and individuals
# ### 2.1 Get data for groups with characteristica/keywords X
# healthy=True, smoking=F, disease=None,
#  individual queries and combinations.
#
# TODO: implement merge of PKDBData
#
# ### 2.2 Get data for individuals with characteristica X
# ### 2.3 Get data for an exclusion criteria, i.e. NOT diease=None

# %% [markdown]
# ## 3 Query interventions
# ### 3.1 Get outputs/timecourses for intervention with substance
# intervention with measurement_type "dosing" and substance "caffeine"
# ### 3.2 Get outputs/timecourses where multiple interventions were given

# %% [markdown]
# ## 4 Query outputs/timecourses
# ### 4.1 query by measurement_type
# ### 4.2 complex
# query all outputs
