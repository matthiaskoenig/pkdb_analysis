# %%
import pandas as pd

from sklearn.preprocessing import Normalizer, MaxAbsScaler
from sklearn.cluster import AgglomerativeClustering

#my utils
from utils import  PkdbModel
from circos_utils import substance_cooccurrence_matrix \
    ,study_expand, bubbles_data, find_label, add_label_and_type, create_config_files, substance_combinations \
    ,create_ideogram, create_links
# Out:
# {'token': '4241a1580f26a51f470a716cbb84be132808f5a3'}

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Configuration for Circular Plots
#
# This notebook creates the configuration files for the circular plots.
#
# Tasks performed by the notebook:
#
#  1. Classifies substances by co-occurrence in studies. Derived substances are replaced but their parents already by the database. Label for a class is chosen to be most frequent substance within a class.
#  2. Classifies studies into the same classes as substances. The most frequent class of substances used in a study is chosen to be the class of the study.
#  3. Builds configuration files for circus plots for:
#      1. Circular study plot with bars .  &rightarrow;  /circos/study/
#      2. Circular study plot with bubbles.   &rightarrow;  /circos/study1/
#      3. Circular plots with subset of study plots for each substance class. &rightarrow;  /circos/substance1/
#      4. Circular substance plots with co-occurrence links and bubbles. &rightarrow;  /circos/study_caffeine/ ...

# %% [markdown]
# ## 1. Classifies Substances and Studies

# %%
# load data
studies = PkdbModel("studies", destination="1-preprocessed") 
substances = PkdbModel("substances", destination="1-preprocessed") 
substances.read()
studies.read()

# %%
coocurence_matrix = substance_cooccurrence_matrix(studies.data, substances.data)
# Out:
# /home/janekg89/Envs/pkdb_analysis/lib/python3.6/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
norm_coocurence_matrix = Normalizer(norm="l2").fit_transform(coocurence_matrix)
norm_coocurence_matrix = pd.DataFrame(norm_coocurence_matrix, index=coocurence_matrix.index, columns=coocurence_matrix.columns)

# %%
classification_model = AgglomerativeClustering(linkage="single",n_clusters=4)
classes = classification_model.fit_predict(norm_coocurence_matrix.T.corr())

# %%
# Classfied substances into types
substance_to_type = pd.DataFrame(classes, index=norm_coocurence_matrix.index, columns=["type"]).to_dict()["type"]

studies.data, substances.data =  add_label_and_type(studies.data, substances.data, substance_to_type)

# %%
studies.data
# Out:
#                 name                                         substances  \
# 126      Loetsch2006  codeine, codeine-6-glucuronide, norcodeine, mo...
# 59        Balogh1992                                           caffeine
# 147        Arias1988  5-dehydrosparteine, sparteine, sparteine sulfa...
# 88            IKP243                                           caffeine
# 112       Stille1987       caffeine, ofloxacin, ciprofloxacin, enoxacin
# 139         Yue1991B  codeine, 4-hydroxydebrisoquine, codeine-6-gluc...
# 136           Wu2014  morphine-3-glucuronide, codeine, morphine-6-gl...
# 118         Chen1991  codeine, codeine-6-glucuronide, dextromethorph...
# 137         Vree1992  codeine, codeine-6-glucuronide, norcodeine, no...
# 99        McLean2002  theophylline, caffeine, theobromine, paraxanthine
# 142        Yue1989-2  codeine, 4-hydroxydebrisoquine, codeine-6-gluc...
# 57         Beach1986                               caffeine, disulfiram
# 64         Carbo1989  caffeine, theophylline, pipemidic acid, norflo...
# 129     Molanaei2010  morphine-3-glucuronide, codeine phosphate, mor...
# 4           Chan1997  paracetamol, paracetamol sulfate, paracetamol ...
# 111      TangLiu1983  caffeine, 3MX, 7MX, 13MU, 7MU, 137MU, theophyl...
# 124       Caraco1996  codeine, 4-hydroxydebrisoquine, codeine-6-gluc...
# 84      M K       M K, J G             2               12
# 97      M K            M K             3               12
# 55      M K  M K, D E, J G             1               12
# 117     J G  J G, M K, D E             1               12
# 91      M K            M K             3               12
# 36      M K            M K             3               20
# 54      M K       M K, J G             7               20
# 21      J B  M K, J B, J G             1                8
# 46      M K            M K             7             1082
# ..      ...            ...           ...              ...
# 122     J G  M K, D E, J G             1                9
# 120     J G       J G, M K             3               24
# 31      M K       M K, K G             1               17
# 61      M K  M K, D E, J G             9               44
# 105     M K            M K             5                8
# 132     J G       M K, J G             1                4
# 130     J G       J G, M K             1               17
# 131     J G  M K, D E, J G             1               10
# 146     J G       J G, M K             1               12
# 77      M K       M K, J G             4               33
# 115     M K       M K, J G             1               12
# 125     J G  M K, D E, J G             3               23
# 93      M K       M K, D E             1                6
# 145     J G       J G, M K             3              132
# 85      M K       M K, J G             2               12
# 51      M K       M K, K G             1                9
# 89      M K            M K             0                0
# 144     J B            J B             0                0
# 80      M K            M K             0                0
# 79      M K            M K             0                0
# 16      J B            J B             0                0
# 17      J B            J B             0                0
# 71      M K       M K, D E             0                0
# 70      M K            M K             0                0
# 116     M K            M K             0                0
# 26      M K            M K             0                0
# 62      M K       M K, D E             1                6
# 53      M K       M K, K G             0                0
# 52      M K       M K, K G             0                0
# 98      M K            M K             0                0
#
#                                                 groups  individuals_count  \
# 126                     [{'count': 11, 'name': 'all'}]                 11
# 59                      [{'count': 12, 'name': 'all'}]                 12
# 147                    [{'count': 142, 'name': 'all'}]                142
# 88                     [{'count': 102, 'name': 'all'}]                102
# 112                     [{'count': 12, 'name': 'all'}]                 12
# 139  [{'count': 20, 'name': 'all'}, {'count': 3, 'n...                 14
# 136  [{'count': 9, 'name': '*10/*10'}, {'count': 10...                208
# 118  [{'count': 8, 'name': 'all'}, {'count': 6, 'na...                  8
# 137                      [{'count': 8, 'name': 'all'}]                  8
# 99   [{'count': 14, 'name': 'all'}, {'count': 8, 'n...                  0
# 142  [{'count': 132, 'name': 'all'}, {'count': 18, ...                132
# 57   [{'count': 21, 'name': 'all'}, {'count': 10, '...                 21
# 64                       [{'count': 6, 'name': 'all'}]                  6
# 129  [{'count': 11, 'name': 'all'}, {'count': 9, 'n...                  9
# 4    [{'count': 38, 'name': 'all'}, {'count': 8, 'n...                  0
# 111                      [{'count': 6, 'name': 'all'}]                  6
# 124  [{'count': 16, 'name': 'all'}, {'count': 10, '...                 15
# 121                     [{'count': 13, 'name': 'all'}]                 13
# 69                       [{'count': 4, 'name': 'all'}]                  4
# 30   [{'count': 30, 'name': 'all'}, {'count': 11, '...                  0
# 47   [{'count': 28, 'name': 'all'}, {'count': 10, '...                 20
# 84   [{'count': 12, 'name': 'all'}, {'count': 12, '...                  0
# 97   [{'count': 12, 'name': 'all'}, {'count': 6, 'n...                 12
# 55                      [{'count': 12, 'name': 'all'}]                 20
# 117                     [{'count': 12, 'name': 'all'}]                  0
# 91   [{'count': 12, 'name': 'all'}, {'count': 6, 'n...                 12
# 36   [{'count': 20, 'name': 'all'}, {'count': 10, '...                  0
# 54   [{'count': 10, 'name': 'A'}, {'count': 20, 'na...                 40
# 21                       [{'count': 8, 'name': 'all'}]                  0
# 46   [{'count': 1082, 'name': 'all'}, {'count': 353...                  0
# ..                                                 ...                ...
# 122                      [{'count': 9, 'name': 'all'}]                  0
# 120  [{'count': 24, 'name': 'all'}, {'count': 12, '...                  0
# 31                      [{'count': 17, 'name': 'all'}]                  0
# 61   [{'count': 44, 'name': 'all'}, {'count': 21, '...                  0
# 105  [{'count': 8, 'name': 'all'}, {'count': 8, 'na...                  0
# 132                      [{'count': 4, 'name': 'all'}]                  4
# 130                     [{'count': 17, 'name': 'all'}]                  0
# 131                     [{'count': 10, 'name': 'all'}]                  0
# 146                     [{'count': 12, 'name': 'all'}]                  0
# 77   [{'count': 33, 'name': 'all'}, {'count': 15, '...                  0
# 115                     [{'count': 12, 'name': 'all'}]                  0
# 125  [{'count': 23, 'name': 'all'}, {'count': 12, '...                  0
# 93                       [{'count': 6, 'name': 'all'}]                  6
# 145  [{'count': 132, 'name': 'all'}, {'count': 114,...                  0
# 85   [{'count': 12, 'name': 'all'}, {'count': 12, '...                  0
# 51                       [{'count': 9, 'name': 'all'}]                  0
# 89                                                  []                  0
# 144                                                 []                  0
# 80                                                  []                  0
# 79                                                  []                  0
# 16                                                  []                  0
# 17                                                  []                  0
# 71                                                  []                  0
# 70                                                  []                  0
# 116                                                 []                  0
# 26                                                  []                  0
# 62                       [{'count': 6, 'name': 'all'}]                  0
# 53                                                  []                  0
# 52                                                  []                  0
# 98                                                  []                  0
#
#                                            individuals  interventions_count  \
# 126  ['1', '2', '3', '4', '5', '6', '7', '8', '9', ...                    2
# 59   ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', ...                    1
# 147  ['1', '2', '3', '4', '7', '8', '9', '10', '11'...                    1
# 88   ['IKP243-1039', 'IKP243-1041', 'IKP243-1043', ...                    1
# 112  ['A', 'B', 'C', 'E', 'F', 'G', 'H', 'I', 'K', ...                   13
# 139  ['1_EM', '2_EM', '3_EM', '4_EM', '5_EM', '6_EM...                   11
# 136  ['1_1/1_COD', '2_1/1_COD', '3_1/1_COD', '4_1/1...                    1
# 118           ['6', '7', '8', '1', '2', '3', '4', '5']                    9
# 137           ['1', '2', '3', '4', '5', '6', '7', '8']                    1
# 99                                                 NaN                    1
# 142  ['50_EM', '51_EM', '52_EM', '53_EM', '54_EM', ...                    2
# 57   ['1', '2', '3', '4', '5', '6', '7', '8', '9', ...                    3
# 64                      ['1', '2', '3', '4', '5', '6']                    3
# 129  ['PM1', 'PM2', 'EM1', 'EM2', 'EM3', 'EM4', 'EM...                    2
# 4                                                  NaN                    1
# 111               ['LR', 'SB', 'CC', 'JM', 'TK', 'MB']                    2
# 124  ['1_EM', '2_EM', '3_EM', '4_EM', '5_EM', '6_EM...                    4
# 121  ['1', '2', '3', '4', '5', '6', '7', '8', '9', ...                    2
# 69                                ['A', 'B', 'C', 'D']                    5
# 30                                                 NaN                    1
# 47   ['1C', '2C', '3C', '4C', '5C', '6C', '7C', '8C...                    1
# 84                                                 NaN                   37
# 97   ['1', '2', '3', '4', '5', '6', '7', '8', '9', ...                    2
# 55   ['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8...                    4
# 117                                                NaN                    3
# 91   ['1', '2', '3', '4', '5', '6', '7', '8', '9', ...                    1
# 36                                                 NaN                    2
# 54   ['4', '5', '9', '10', '11', '12', '16', '17', ...                    4
# 21                                                 NaN                   24
# 46                                                 NaN                    1
# ..                                                 ...                  ...
# 122                                                NaN                    1
# 120                                                NaN                    2
# 31                                                 NaN                    1
# 61                                                 NaN                    1
# 105                                                NaN                    2
# 132                               ['C', 'E', 'F', 'O']                    1
# 130                                                NaN                    1
# 131                                                NaN                    1
# 146                                                NaN                    3
# 77                                                 NaN                    1
# 115                                                NaN                    1
# 125                                                NaN                    1
# 93                      ['2', '3', '4', '5', '6', '1']                    1
# 145                                                NaN                    2
# 85                                                 NaN                   37
# 51                                                 NaN                    0
# 89                                                 NaN                    0
# 144                                                NaN                    0
# 80                                                 NaN                    0
# 79                                                 NaN                    0
# 16                                                 NaN                    0
# 17                                                 NaN                    0
# 71                                                 NaN                    0
# 70                                                 NaN                    0
# 116                                                NaN                    0
# 26                                                 NaN                    0
# 62                                                 NaN                    0
# 53                                                 NaN                    0
# 52                                                 NaN                    0
# 98                                                 NaN                    0
#
#      outputs_count  outputs_calculated_count  timecourses_count  \
# 126            692                       692                132
# 59             723                       576                 72
# 147            568                         0                  0
# 88             510                         0                  0
# 112            432                         0                  0
# 139            413                        83                 11
# 136            379                        96                 12
# 118            360                        28                  4
# 137            306                        40                 14
# 99             262                       206                 48
# 142            301                         0                  0
# 57             280                        25                  4
# 64             228                        24                  3
# 129            192                       186                 25
# 4              193                       113                 16
# 111            182                       128                 16
# 124            179                        96                 12
# 121            184                        40                  5
# 69             158                       128                 16
# 30             139                       139                 33
# 47             164                        32                  6
# 84             160                         0                  0
# 97             156                        16                  2
# 55             150                        48                  6
# 117            146                        70                 10
# 91             144                        96                 12
# 36             120                       120                 32
# 54             150                         0                  0
# 21             140                        48                  8
# 46             126                        96                 18
# ..             ...                       ...                ...
# 122             17                        16                  3
# 120             20                         0                  0
# 31              16                        16                  3
# 61              18                         0                  0
# 105             16                         0                  0
# 132             12                        12                  4
# 130             12                         6                  2
# 131             12                         0                  0
# 146             10                         0                  0
# 77              10                         0                  0
# 115              8                         0                  2
# 125              2                         0                  4
# 93               6                         0                  0
# 145              2                         0                  0
# 85               2                         0                  0
# 51               0                         0                  0
# 89               0                         0                  0
# 144              0                         0                  0
# 80               0                         0                  0
# 79               0                         0                  0
# 16               0                         0                  0
# 17               0                         0                  0
# 71               0                         0                  0
# 70               0                         0                  0
# 116              0                         0                  0
# 26               0                         0                  0
# 62               0                         0                  0
# 53               0                         0                  0
# 52               0                         0                  0
# 98               0                         0                  0
#
#      results_count  type        label
# 126            824   2.0      codeine
# 59             795   0.0     caffeine
# 147            568   2.0      codeine
# 88             510   0.0     caffeine
# 112            432   0.0     caffeine
# 139            424   2.0      codeine
# 136            391   2.0      codeine
# 118            364   2.0      codeine
# 137            320   2.0      codeine
# 99             310   0.0     caffeine
# 142            301   2.0      codeine
# 57             284   0.0     caffeine
# 64             231   0.0     caffeine
# 129            217   2.0      codeine
# 4              209   1.0  paracetamol
# 111            198   0.0     caffeine
# 124            191   2.0      codeine
# 121            189   2.0      codeine
# 69             174   0.0     caffeine
# 30             172   3.0      glucose
# 47             170   0.0     caffeine
# 84             160   0.0     caffeine
# 97             158   0.0     caffeine
# 55             156   0.0     caffeine
# 117            156   2.0      codeine
# 91             156   0.0     caffeine
# 36             152   3.0      glucose
# 54             150   0.0     caffeine
# 21             148   1.0  paracetamol
# 46             144   3.0      glucose
# ..             ...   ...          ...
# 122             20   2.0      codeine
# 120             20   2.0      codeine
# 31              19   3.0      glucose
# 61              18   0.0     caffeine
# 105             16   0.0     caffeine
# 132             16   2.0      codeine
# 130             14   2.0      codeine
# 131             12   2.0      codeine
# 146             10   2.0      codeine
# 77              10   0.0     caffeine
# 115             10   0.0     caffeine
# 125              6   2.0      codeine
# 93               6   0.0     caffeine
# 145              2   2.0      codeine
# 85               2   0.0     caffeine
# 51               0   NaN         None
# 89               0   NaN         None
# 144              0   NaN         None
# 80               0   NaN         None
# 79               0   NaN         None
# 16               0   NaN         None
# 17               0   NaN         None
# 71               0   NaN         None
# 70               0   NaN         None
# 116              0   NaN         None
# 26               0   NaN         None
# 62               0   NaN         None
# 53               0   NaN         None
# 52               0   NaN         None
# 98               0   NaN         None
#
# [148 rows x 16 columns]

# %%
studies_data = studies.data.sort_values(by=["label","name"])

# %%
import numpy as np

# %%
studies_data["group_all_count"]= studies_data["group_all_count"].replace(np.nan, 0)
studies_data["group_all_count"]= studies_data["group_all_count"].astype(int)

# %% [markdown]
# ## 2. Build config files for circular plots

# %%
# for study data
create_config_files(studies_data, "circos/study_final")
# Out:
# /home/janekg89/Develop/Pycharm_Projects/pkdb_analysis/circos_utils.py:178: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data["start"] = range(0,len(data)*rows_per_study,rows_per_study)
# /home/janekg89/Develop/Pycharm_Projects/pkdb_analysis/circos_utils.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data["end"] = range(rows_per_study,(len(data)+1)*rows_per_study,rows_per_study)

# %%
studies_data
# Out:
#                 name                                         substances  \
# 49     Abernethy1985                                           caffeine
# 47     Akinyinka2000  theophylline, caffeine, theobromine, paraxanthine
# 45        Amchin1999  caffeine, 17U, AAMU, 1U, venlafaxine, theobrom...
# 58       Backman2008                             caffeine, paraxanthine
# 59        Balogh1992                                           caffeine
# 54        Balogh1995  caffeine, gestodene, ethinylestradiol, levonor...
# 56        Barnet1990              norfloxacin, caffeine, pipemidic acid
# 57         Beach1986                               caffeine, disulfiram
# 61         Begas2007          caffeine, 17U, 1U, AFMU, paraxanthine, 1X
# 60      Benowitz1995                             caffeine, paraxanthine
# 55      Benowitz2003  caffeine, chlorzoxazone, 1U, AAMU, 6-hydroxych...
# 63     Blanchard1982                                           caffeine
# 66    Blanchard1983a                                           caffeine
# 69        Bonati1982  theophylline, caffeine, theobromine, paraxanthine
# 68     Campbell1987a                                           caffeine
# 64         Carbo1989  caffeine, theophylline, pipemidic acid, norflo...
# 65     Carrillo2000a                        caffeine, paraxanthine, 17U
# 67         Cheng1990                                           caffeine
# 78       Cornish1957  caffeine, 3MX, 7MX, 13MU, 7MU, theophylline, 1...
# 75   Culm-Merdek2005  caffeine, fluvoxamine, theophylline, theobromi...
# 77       Desmond1980                                           caffeine
# 73         Faber2004                                           caffeine
# 72         Fuhr1993a                         caffeine, grapefruit juice
# 76        George1986                               caffeine, antipyrine
# 74    Ghassabian2009  caffeine, omeprazole, dextromethorphan, midazo...
# 86      Granfors2005                             caffeine, paraxanthine
# 81        Haller2002                                           caffeine
# 84        Harder1988  caffeine, enoxacin, ofloxacin, pipemidic acid,...
# 85        Harder1989  caffeine, enoxacin, pipemidic acid, ciprofloxa...
[{'count': 12, 'name': 'all'}, {'count': 6, 'n...                  0
# 19   [{'count': 23, 'name': 'all'}, {'count': 7, 'n...                 23
# 25                       [{'count': 6, 'name': 'all'}]                  0
# 21                       [{'count': 8, 'name': 'all'}]                  0
# 23   [{'count': 10, 'name': 'all'}, {'count': 5, 'n...                 10
# 18   [{'count': 10, 'name': 'all'}, {'count': 8, 'n...                  0
# 62                       [{'count': 6, 'name': 'all'}]                  0
# 71                                                  []                  0
# 70                                                  []                  0
# 17                                                  []                  0
# 79                                                  []                  0
# 80                                                  []                  0
# 89                                                  []                  0
# 98                                                  []                  0
# 16                                                  []                  0
# 144                                                 []                  0
# 53                                                  []                  0
# 116                                                 []                  0
# 52                                                  []                  0
# 26                                                  []                  0
# 51                       [{'count': 9, 'name': 'all'}]                  0
#
#                                            individuals  interventions_count  \
# 49   ['1', '2', '3', '4', '5', '6', '7', '8', '9', ...                    1
# 47   ['1C', '2C', '3C', '4C', '5C', '6C', '7C', '8C...                    1
# 45   ['1', '2', '3', '4', '5', '6', '7', '8', '9', ...                    2
# 58   ['1', '2', '3', '4', '5', '6', '7', '8', '9', ...                    1
# 59   ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', ...                    1
# 54   ['4', '5', '9', '10', '11', '12', '16', '17', ...                    4
# 56                      ['1', '2', '3', '4', '5', '6']                    3
# 57   ['1', '2', '3', '4', '5', '6', '7', '8', '9', ...                    3
# 61                                                 NaN                    1
# 60                                                 NaN                    4
# 55   ['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8...                    4
# 63                                                 NaN                    2
# 66                                                 NaN                    2
# 69                                ['A', 'B', 'C', 'D']                    5
# 68   ['oc1', 'oc2', 'oc3', 'oc4', 'oc5', 'ns1', 'ns...                    1
# 64                      ['1', '2', '3', '4', '5', '6']                    3
# 65                                                 NaN                    1
# 67   ['1', '2', '3', '4', '5', '6', '7', '8', '9', ...                    3
# 78                                    ['H.C.', 'F.M.']                    3
# 75                                                 NaN                    5
# 77                                                 NaN                    1
# 73   ['S1', 'S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8...                    1
# 72   ['1', '2', '3', '4', '5', '6', '7', '8', '9', ...                    2
# 76   ['1A', '2A', '3A', '4A', '5A', '6A', '7A', '8A...                    2
# 74   ['1', '2', '3', '4', '5', '6', '7', '8', '9', ...                    5
# 86   ['1', '2', '3', '4', '5', '6', '7', '8', '9', ...                    1
# 81            ['1', '2', '3', '4', '5', '6', '7', '8']                    1
# 84                                                 NaN                   37
# 85                                                 NaN                   37
# 83                                                 NaN                    4
# ..                                                 ...                  ...
# 6                                                  NaN                    1
# 5                                                  NaN                    4
# 1                           ['elderly male volunteer']                    3
# 10                                                 NaN                    2
# 11                                                 NaN                    5
# 15                                                 NaN                    1
# 14                      ['1', '2', '3', '4', '5', '6']                    1
# 12                                                 NaN                    3
# 22   ['Y1', 'Y2', 'Y3', 'Y4', 'Y5', 'Y6', 'Y7', 'Y8...                    1
# 20                                                 NaN                    2
# 19   ['1', '2', '3', '4', '5', '6', '7', '8', '9', ...                    1
# 25                                                 NaN                    4
# 21                                                 NaN                   24
# 23   ['patient1', 'patient2', 'patient3', 'patient4...                    3
# 18                                                 NaN                    2
# 62                                                 NaN                    0
# 71                                                 NaN                    0
# 70                                                 NaN                    0
# 17                                                 NaN                    0
# 79                                                 NaN                    0
# 80                                                 NaN                    0
# 89                                                 NaN                    0
# 98                                                 NaN                    0
# 16                                                 NaN                    0
# 144                                                NaN                    0
# 53                                                 NaN                    0
# 116                                                NaN                    0
# 52                                                 NaN                    0
# 26                                                 NaN                    0
# 51                                                 NaN                    0
#
#      outputs_count  outputs_calculated_count  timecourses_count  \
# 49              64                         0                  0
# 47             164                        32                  6
# 45              72                        16                  2
# 58             140                         0                  0
# 59             723                       576                 72
# 54             150                         0                  0
# 56             120                         0                  0
# 57             280                        25                  4
# 61              18                         0                  0
# 60              39                        33                  8
# 55             150                        48                  6
# 63              82                        32                  4
# 66              23                        16                  2
# 69             158                       128                 16
# 68              54                         0                  0
# 64             228                        24                  3
# 65              75                        19                 16
# 67              87                         0                  0
# 78              60                         0                  0
# 75              49                        27                  6
# 77              10                         0                  0
# 73              26                         0                  0
# 72             104                         0                  0
# 76              64                         0                  0
# 74              33                         0                  0
# 86              62                         0                  0
# 81              62                         8                  1
# 84             160                         0                  0
# 85               2                         0                  0
# 83              20                         0                  0
# ..             ...                       ...                ...
# 6               86                        54                  8
# 5               29                        13                  2
# 1               48                        18                  3
# 10             112                        80                 10
# 11              86                        56                  7
# 15              28                        24                  3
# 14              68                        32                  4
# 12              39                        24                  3
# 22             108                         0                  0
# 20              66                        42                  6
# 19             120                        62                  9
# 25              41                        32                  4
# 21             140                        48                  8
# 23             104                        32                  4
# 18              19                        11                  2
# 62               0                         0                  0
# 71               0                         0                  0
# 70               0                         0                  0
# 17               0                         0                  0
# 79               0                         0                  0
# 80               0                         0                  0
# 89               0                         0                  0
# 98               0                         0                  0
# 16               0                         0                  0
# 144              0                         0                  0
# 53               0                         0                  0
# 116              0                         0                  0
# 52               0                         0                  0
# 26               0                         0                  0
# 51               0                         0                  0
#
#      results_count  type        label
# 49              64   0.0     caffeine
# 47             170   0.0     caffeine
# 45              74   0.0     caffeine
# 58             140   0.0     caffeine
# 59             795   0.0     caffeine
# 54             150   0.0     caffeine
# 56             120   0.0     caffeine
# 57             284   0.0     caffeine
# 61              18   0.0     caffeine
# 60              47   0.0     caffeine
# 55             156   0.0     caffeine
# 63              86   0.0     caffeine
# 66              25   0.0     caffeine
# 69             174   0.0     caffeine
# 68              54   0.0     caffeine
# 64             231   0.0     caffeine
# 65              91   0.0     caffeine
# 67              87   0.0     caffeine
# 78              60   0.0     caffeine
# 75              55   0.0     caffeine
# 77              10   0.0     caffeine
# 73              26   0.0     caffeine
# 72             104   0.0     caffeine
# 76              64   0.0     caffeine
# 74              33   0.0     caffeine
# 86              62   0.0     caffeine
# 81              63   0.0     caffeine
# 84             160   0.0     caffeine
# 85               2   0.0     caffeine
# 83              20   0.0     caffeine
# ..             ...   ...          ...
# 6               94   1.0  paracetamol
# 5               31   1.0  paracetamol
# 1               51   1.0  paracetamol
# 10             122   1.0  paracetamol
# 11              93   1.0  paracetamol
# 15              31   1.0  paracetamol
# 14              72   1.0  paracetamol
# 12              42   1.0  paracetamol
# 22             108   1.0  paracetamol
# 20              72   1.0  paracetamol
# 19             129   1.0  paracetamol
# 25              45   1.0  paracetamol
# 21             148   1.0  paracetamol
# 23             108   1.0  paracetamol
# 18              21   1.0  paracetamol
# 62               0   NaN         None
# 71               0   NaN         None
# 70               0   NaN         None
# 17               0   NaN         None
# 79               0   NaN         None
# 80               0   NaN         None
# 89               0   NaN         None
# 98               0   NaN         None
# 16               0   NaN         None
# 144              0   NaN         None
# 53               0   NaN         None
# 116              0   NaN         None
# 52               0   NaN         None
# 26               0   NaN         None
# 51               0   NaN         None
#
# [148 rows x 16 columns]

# %%
for label, study_data_label in studies_data.groupby("label"):
    create_config_files(study_data_label, f"circos/study_{label}")
# Out:
# /home/janekg89/Develop/Pycharm_Projects/pkdb_analysis/circos_utils.py:178: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data["start"] = range(0,len(data)*rows_per_study,rows_per_study)
# /home/janekg89/Develop/Pycharm_Projects/pkdb_analysis/circos_utils.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data["end"] = range(rows_per_study,(len(data)+1)*rows_per_study,rows_per_study)

# %%
# testing for substances

# %%
frames = []
for substance, data in substances.data.sort_values("label").groupby("label"):
    data["start"] = range(len(data)) 
    data["end"] = range(1,len(data)+1) 
    frames.append(data)
substances_data = pd.concat(frames)
# Out:
# /home/janekg89/Envs/pkdb_analysis/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/janekg89/Envs/pkdb_analysis/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
#substances_data

# %%
len(substances_data)
# Out:
# 98

# %%
unused_substances = substances_data[ (substances_data["study_number"]<2) | ((substances_data["intervention_number"]==0) & (substances_data["timecourse_number"] == 0)  & (substances_data["output_number"] == 0))]["name"]

# %%
substances_data = substances_data[ ~((substances_data["study_number"]<2) | ( (substances_data["intervention_number"]==0) & (substances_data["timecourse_number"] == 0)  & (substances_data["output_number"] == 0)))]

# %%
len(substances_data)
# Out:
# 56

# %%
unused_substances.to_list()
# Out:
# ['venlafaxine',
#  'lomefloxacin',
#  '1-hydroxymidazolam',
#  'exp3174',
#  'cimetidine',
#  'levonorgestrel',
#  'indocyanine green',
#  'grapefruit juice',
#  'glycerol',
#  'gestodene',
#  '137MU',
#  'ethinylestradiol',
#  'disulfiram',
#  'digoxin',
#  'chlorzoxazone',
#  'carbon monoxide',
#  'L-ascorbic acid',
#  'AFMU',
#  '6-hydroxychlorzoxazone',
#  '17MU',
#  'metropolol',
#  'warfarin',
#  'normorphine-glucuronide',
#  'diclofenac',
#  'sulfapyridine',
#  'mephenytoin',
#  'sulfasalazine',
#  'norcodeine-conjugates',
#  '2-dehydrosparteine',
#  '5-dehydrosparteine',
#  '4-hydroxydebrisoquine',
#  '[U-13C]glucose',
#  'lactate',
#  'exenatide',
#  '[6-3H]glucose',
#  '[3-OMG]glucose',
#  '[2-3H]glucose',
#  'GLP-1',
#  'GIP',
#  'propacetamol',
#  'propanolol',
#  'panadol extend']

# %%
all_links = create_links(substances_data,studies_data,unused_substances.to_list())

# %%
length = pd.DataFrame()
length["substance_links"] = all_links["substance1_start"].append(all_links["substance2_start"])
length["label"] = all_links["substance1_label"].append(all_links["substance2_label"])

# %%
frames = []
for label, data_label in length.groupby(["label"]):
    start = 0 
    
    
    for substance_link, substance_linkpositions in data_label.groupby(["substance_links"]):    
        label_position = pd.Series()
        label_position["start"] = start
        label_position["end"] = start + len(substance_linkpositions)
        label_position["label"]  = label
        label_position["substance_number"]  = substance_link

        frames.append(label_position)
        start = label_position["end"] + 1
res = pd.concat(frames, axis=1).T

# %%
substance_data = pd.merge(res,substances_data[["name","label","start","study_number","timecourse_number","output_number","output_raw_number","output_calculated_number","intervention_number"]],left_on=["label","substance_number"], right_on = ["label","start"])
substance_data["start"] = substance_data["start_x"]

# %%
links_new = pd.merge(all_links, substance_data[["start","end","start_y","label"]], left_on=["substance1_label","substance1_start"], right_on = [ "label","start_y"])
links_new[["substance1_start","substance1_end"]] = links_new[["start","end"]]
links_new = pd.merge(links_new, substance_data[["start","end","start_y","label"]], left_on=["substance2_label","substance2_start"], right_on = [ "label","start_y"])
links_new[["substance2_start","substance2_end"]] = links_new[["start_y","end_y"]]

# %%
all_links = links_new[["substance1_label","substance1_start" ,"substance1_end", "substance2_label","substance2_start" ,"substance2_end"]]

# %%
frames = []
for (label,start), data in all_links.groupby(["substance1_label","substance1_start"]):
    data["substance1_start"] = start + range(len(data))
    data["substance1_end"] = data["substance1_start"] + 1
    data["substance1_label"] = label

    frames.append(data)
    
all_links = pd.concat(frames)
# Out:
# /home/janekg89/Envs/pkdb_analysis/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/janekg89/Envs/pkdb_analysis/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/janekg89/Envs/pkdb_analysis/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
frames = []
for (label,end), data in all_links.groupby(["substance2_label","substance2_end"]):
    data["substance2_end"] = end - range(len(data)) 
    data["substance2_start"] = data["substance2_end"] - 1
    data["substance2_label"] = label

    frames.append(data)
    
all_links = pd.concat(frames)
# Out:
# /home/janekg89/Envs/pkdb_analysis/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/janekg89/Envs/pkdb_analysis/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/janekg89/Envs/pkdb_analysis/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
all_links.to_csv("circos/substance_final/data/links.txt", sep=" ",header=False,index=False)

# %%
ideogram = pd.DataFrame(res.sort_values("label").groupby(["label"]).apply(lambda x:  x["end"].max()),columns = ["len"])
ideogram["label"] = ideogram.index

# %%
ideogram
# Out:
#               len        label
# label
# caffeine      647     caffeine
# codeine      1215      codeine
# glucose       290      glucose
# paracetamol   166  paracetamol

# %%
ticks_dict = {}
for label, data in substance_data.groupby("label"):
    mystring = ""
    for x in list(data["start"]):
        mystring += f"{x}u, "
    data["end"].max()
    mystring += f"{data['end'].max()}u"
    ticks_dict[label]=mystring

# %%
from pprint import pprint
pprint(ticks_dict)
# Out:
# {'caffeine': '0u, 112u, 126u, 145u, 155u, 174u, 193u, 212u, 231u, 250u, 264u, '
#              '273u, 288u, 302u, 319u, 327u, 340u, 435u, 450u, 498u, 518u, '
#              '537u, 557u, 574u, 628u, 647u',
#  'codeine': '0u, 23u, 105u, 193u, 304u, 423u, 539u, 661u, 802u, 945u, 1065u, '
#             '1073u, 1102u, 1159u, 1165u, 1185u, 1200u, 1215u',
#  'glucose': '0u, 18u, 70u, 95u, 112u, 137u, 193u, 223u, 266u, 290u',
#  'paracetamol': '0u, 35u, 70u, 114u, 136u, 166u'}

# %%
directory = "circos/substance_final"
with open(f"{directory}/data/ideogram.txt","w") as f:
        number = 0
        for idx, substance in ideogram.iterrows():

            number = number + 1
            #color_mapping[substance.label] = f"fill_color=spectral-5-div-{number}"
            f.write(f"chr - {substance.label} {substance.label} 0 {substance.len} pastel2-6-qual-{number}\n")

# %%
#names 2d track
substance_data["name"] = substance_data["name"].apply(lambda x: x.replace(" ","&nbsp;"))
substance_data[["label","start","end","name"]].to_csv(f"{directory}/data/substance_names.txt", sep=" ",header=False,index=False)
# all subjects number for number track
substance_data[["label","start","end","study_number"]].to_csv(f"{directory}/data/study_number.txt", sep=" ",header=False,index=False)
substance_data[["label","start","end","timecourse_number"]].to_csv(f"{directory}/data/timecourse_number.txt", sep=" ",header=False,index=False)
substance_data[["label","start","end","output_number"]].to_csv(f"{directory}/data/output_number.txt", sep=" ",header=False,index=False)
substance_data[["label","start","end","intervention_number"]].to_csv(f"{directory}/data/intervention_number.txt", sep=" ",header=False,index=False)

bubbles_data_dict = bubbles_data(substance_data,25,"substance")
for name, data in bubbles_data_dict.items():
        data[["label","start","end","type","circle_type"]].to_csv(f"{directory}/data/{name}_bubble.txt", sep=" ",header=False,index=False)

# %%
#old stlye write upper part into utlis !

#create_config_files(substances_data, "circos/substance_final", "substance")
#create_links(substances_data,studies_data).to_csv("circos/substance_final/data/links.txt", sep=" ",header=False,index=False)

# %%
#create_links(substances_data,studies_data)
