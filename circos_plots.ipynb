# %%
import pandas as pd

from sklearn.preprocessing import Normalizer, MaxAbsScaler
from sklearn.cluster import AgglomerativeClustering

#my utils
from utils import  PkdbModel
from circos_utils import substance_cooccurrence_matrix \
    ,study_expand, bubbles_data, find_label, add_label_and_type, create_config_files

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Configuration for Circular Plots
#
# This notebook creates the configuration files for the circular plots.
#
# Tasks performed by the notebook:
#
#  1. Classifies substances by co-occurrence in studies. Derived substances are replaced but their parents already by the database. Label for a class is chosen to be most frequent substance within a class.
#  2. Classifies studies into the same classes as substances. The most frequent class of substances used in a study is chosen to be the class of the study.
#  3. Builds configuration files for circus plots for:
#      1. Circular study plot with bars .  &rightarrow;  /circos/study/
#      2. Circular study plot with bubbles.   &rightarrow;  /circos/study1/
#      3. Circular plots with subset of study plots for each substance class. &rightarrow;  /circos/substance1/
#      4. Circular substance plots with co-occurrence links and bubbles. &rightarrow;  /circos/study_caffeine/ ...

# %% [markdown]
# ## 1. Classifies Substances and Studies

# %%
# load data
studies = PkdbModel("studies", destination="1-preprocessed") 
substances = PkdbModel("substances", destination="1-preprocessed") 
substances.read()
studies.read()

# %%
coocurence_matrix = substance_cooccurrence_matrix(studies.data, substances.data)

# %%
norm_coocurence_matrix = Normalizer(norm="l2").fit_transform(coocurence_matrix)
norm_coocurence_matrix = pd.DataFrame(norm_coocurence_matrix, index=coocurence_matrix.index, columns=coocurence_matrix.columns)

# %%
classification_model = AgglomerativeClustering(linkage="single",n_clusters=4)
classes = classification_model.fit_predict(norm_coocurence_matrix.T.corr())

# %%
# Classfied substances into types
substance_to_type = pd.DataFrame(classes, index=norm_coocurence_matrix.index, columns=["type"]).to_dict()["type"]

studies.data, substances.data =  add_label_and_type(studies.data, substances.data, substance_to_type)

# %%
studies.data
# Out:
#                 name                                         substances  \
# 10        Balogh1992                                           caffeine
# 38       Loetsch2006  morphine, morphine-6-glucuronide, normorphine,...
# 17           Test243                                           caffeine
# 69        Stille1987       caffeine, ciprofloxacin, ofloxacin, enoxacin
# 55          Yue1991B  morphine, morphine-3-glucuronide, morphine-6-g...
# 42          Chen1991  morphine, morphine-3-glucuronide, morphine-6-g...
# 61          Vree1992  morphine, morphine-3-glucuronide, morphine-6-g...
# 54         Yue1989-2  morphine, morphine-3-glucuronide, morphine-6-g...
# 32         Beach1986                               caffeine, disulfiram
# 21        McLean2002  caffeine, paraxanthine, theophylline, theobromine
# 66         Carbo1989  caffeine, px/caf, tp/caf, 1X/px, 1X/tp, norflo...
# 102         Chan1997  paracetamol sulfate, paracetamol cysteine, par...
# 44      Molanaei2010  morphine-3-glucuronide, morphine-6-glucuronide...
# 47       Lafolie1996  morphine, morphine-3-glucuronide, morphine-6-g...
# 60        Caraco1996  morphine, morphine-3-glucuronide, morphine-6-g...
# 59            Wu2014  morphine, morphine-3-glucuronide, morphine-6-g...
# 27     Akinyinka2000  caffeine, paraxanthine, theophylline, theobrom...
# 67        Harder1988  caffeine, paraxanthine, norfloxacin, ciproflox...
[{'count': 12, 'name': 'all'}, {'count': 6, 'n...                 12
# 71                      [{'count': 12, 'name': 'all'}]                 20
# 35   [{'count': 20, 'name': 'all'}, {'count': 10, '...                 40
# 19   [{'count': 12, 'name': 'all'}, {'count': 6, 'n...                 12
# 25   [{'count': 71, 'name': 'all'}, {'count': 53, '...                 70
# 78                      [{'count': 12, 'name': 'all'}]                  0
# 100  [{'count': 127, 'name': 'NGT_1990'}, {'count':...                  0
# 15   [{'count': 36, 'name': 'all'}, {'count': 10, '...                 36
# 65                       [{'count': 6, 'name': 'all'}]                  6
# 104  [{'count': 31, 'name': 'all'}, {'count': 9, 'n...                  0
# ..                                                 ...                ...
# 39                      [{'count': 20, 'name': 'all'}]                  0
# 76                       [{'count': 8, 'name': 'all'}]                  0
# 87                       [{'count': 6, 'name': 'all'}]                  0
# 64                       [{'count': 6, 'name': 'all'}]                  0
# 1    [{'count': 12, 'name': 'all'}, {'count': 12, '...                 24
# 106                     [{'count': 10, 'name': 'all'}]                  0
# 99                      [{'count': 10, 'name': 'all'}]                  0
# 108                      [{'count': 1, 'name': 'all'}]                  1
# 79   [{'count': 25, 'name': 'all'}, {'count': 11, '...                  0
# 7                       [{'count': 10, 'name': 'all'}]                  0
# 37                      [{'count': 10, 'name': 'all'}]                  0
# 103  [{'count': 22, 'name': 'all'}, {'count': 10, '...                  0
# 36   [{'count': 44, 'name': 'all'}, {'count': 21, '...                  0
# 53   [{'count': 24, 'name': 'all'}, {'count': 12, '...                  0
# 52                       [{'count': 9, 'name': 'all'}]                  0
# 91                      [{'count': 17, 'name': 'all'}]                  0
# 74   [{'count': 8, 'name': 'all'}, {'count': 8, 'na...                  0
# 46                      [{'count': 17, 'name': 'all'}]                  0
# 41                      [{'count': 10, 'name': 'all'}]                  0
# 40                       [{'count': 4, 'name': 'all'}]                  4
# 31                      [{'count': 12, 'name': 'all'}]                  0
# 9    [{'count': 33, 'name': 'all'}, {'count': 15, '...                  0
# 57                      [{'count': 12, 'name': 'all'}]                  0
# 30                       [{'count': 6, 'name': 'all'}]                  6
# 98                       [{'count': 6, 'name': 'all'}]                  0
# 48   [{'count': 23, 'name': 'all'}, {'count': 11, '...                  0
# 68   [{'count': 12, 'name': 'all'}, {'count': 12, '...                  0
# 107                      [{'count': 9, 'name': 'all'}]                  0
# 63   [{'count': 132, 'name': 'all'}, {'count': 18, ...                  0
# 0                                                   []                  0
#
#                                            individuals  interventions_count  \
# 10   ['M', 'L', 'K', 'I', 'H', 'G', 'F', 'E', 'D', ...                    1
# 38   ['11', '10', '9', '8', '7', '6', '5', '4', '3'...                    2
# 17   ['IKP243-2079', 'IKP243-2075', 'IKP243-2074', ...                    1
# 69   ['N', 'M', 'L', 'K', 'I', 'H', 'G', 'F', 'E', ...                   13
# 55   ['14_PM', '13_PM', '12_PM', '11_PM', '10_PM', ...                   11
# 42            ['8', '7', '6', '5', '4', '3', '2', '1']                    8
# 61            ['8', '7', '6', '5', '4', '3', '2', '1']                    1
# 54   ['132_EM', '131_EM', '130_EM', '129_EM', '128_...                    2
# 32   ['K', 'J', 'I', 'H', 'G', 'F', 'E', 'D', 'C', ...                    3
# 21                                                 NaN                    1
# 66                      ['6', '5', '4', '3', '2', '1']                    3
# 102                                                NaN                    1
# 44   ['PM2', 'PM1', 'EM7', 'EM6', 'EM5', 'EM4', 'EM...                    2
# 47   ['13', '12', '11', '10', '9', '8', '7', '6', '...                    2
# 60   ['6_PM', '5_PM', '4_PM', '3_PM', '2_PM', '1_PM...                    4
# 59                                                 NaN                    1
# 27   ['10M', '9M', '8M', '7M', '6M', '5M', '4M', '3...                    1
# 67                                                 NaN                   37
# 20                                ['A', 'B', 'C', 'D']                    5
# 86                                                 NaN                    1
# 34   ['12', '11', '10', '9', '8', '7', '6', '5', '4...                    2
# 71   ['A9', 'A8', 'A7', 'A6', 'A5', 'A4', 'A3', 'A2...                    4
# 35   ['18_oc', '15_oc', '14_oc', '13_oc', '8_oc', '...                    4
# 19   ['12', '11', '10', '9', '8', '7', '6', '5', '4...                    1
# 25   ['70', '69', '68', '67', '66', '65', '64', '63...                    1
# 78                                                 NaN                    3
# 100                                                NaN                    1
# 15   ['BD', 'CB', 'HS', 'FW', 'PH', 'EC', 'HP', 'UM...                    1
# 65                      ['6', '5', '4', '3', '2', '1']                    3
# 104                                                NaN                    1
# ..                                                 ...                  ...
# 39                                                 NaN                    1
# 76                                                 NaN                    2
# 87                                                 NaN                    4
# 64                                                 NaN                    8
# 1    ['NS12', 'NS11', 'NS10', 'NS9', 'NS8', 'NS7', ...                    1
# 106                                                NaN                    2
# 99                                                 NaN                    2
# 108                                              ['1']                    2
# 79                                                 NaN                    1
# 7                                                  NaN                    2
# 37                                                 NaN                    4
# 103                                                NaN                    1
# 36                                                 NaN                    1
# 53                                                 NaN                    2
# 52                                                 NaN                    1
# 91                                                 NaN                    1
# 74                                                 NaN                    2
# 46                                                 NaN                    1
# 41                                                 NaN                    1
# 40                                ['O', 'F', 'E', 'C']                    1
# 31                                                 NaN                    1
# 9                                                  NaN                    1
# 57                                                 NaN                    3
# 30                      ['6', '5', '4', '3', '2', '1']                    1
# 98                                                 NaN                    1
# 48                                                 NaN                    1
# 68                                                 NaN                   37
# 107                                                NaN                    0
# 63                                                 NaN                    2
# 0                                                  NaN                    0
#
#      outputs_count  outputs_calculated_count  timecourses_count  \
# 10             651                       504                 72
# 38             546                       546                132
# 17             510                         0                  0
# 69             432                         0                  0
# 55             398                        72                 11
# 42             344                        24                  4
# 61             301                        35                 14
# 54             299                         0                  0
# 32             254                        19                  4
# 21             190                       134                 48
# 66             221                        17                  3
# 102            177                        97                 16
# 44             167                       161                 25
# 47             179                        35                  5
# 60             165                        84                 12
# 59             159                        84                 12
# 27             160                        28                  6
# 67             160                         0                  0
# 20             142                       112                 16
# 86             121                       121                 33
# 34             152                        12                  2
# 71             144                        42                  6
# 35             150                         0                  0
# 19             132                        84                 12
# 25             140                         0                  0
# 78             125                        50                 10
# 100            114                        84                 18
# 15             120                         0                  0
# 65             120                         0                  0
# 104             84                        84                 32
# ..             ...                       ...                ...
# 39              26                        14                  2
# 76              19                        19                  8
# 87              23                        23                  4
# 64              26                         0                  0
# 1               26                         0                  0
# 106             24                        14                  2
# 99              10                        10                 14
# 108             22                        14                  2
# 79              10                        10                 14
# 7               21                        14                  2
# 37              20                         0                  0
# 103             14                        14                  6
# 36              18                         0                  0
# 53              18                         0                  0
# 52              14                        14                  3
# 91              14                        14                  3
# 74              16                         0                  0
# 46              10                         4                  3
# 41              12                         0                  0
# 40               8                         8                  4
# 31               8                         0                  2
# 9               10                         0                  0
# 57               9                         0                  0
# 30               6                         0                  0
# 98               0                         0                  4
# 48               0                         0                  4
# 68               2                         0                  0
# 107              0                         0                  0
# 63               0                         0                  0
# 0                0                         0                  0
#
#      results_count  type        label
# 10             723   0.0     caffeine
# 38             678   2.0      codeine
# 17             510   0.0     caffeine
# 69             432   0.0     caffeine
# 55             409   2.0      codeine
# 42             348   2.0      codeine
# 61             315   2.0      codeine
# 54             299   2.0      codeine
# 32             258   0.0     caffeine
# 21             238   0.0     caffeine
# 66             224   0.0     caffeine
# 102            193   3.0  paracetamol
# 44             192   2.0      codeine
# 47             184   2.0      codeine
# 60             177   2.0      codeine
# 59             171   2.0      codeine
# 27             166   0.0     caffeine
# 67             160   0.0     caffeine
# 20             158   0.0     caffeine
# 86             154   1.0      glucose
# 34             154   0.0     caffeine
# 71             150   0.0     caffeine
# 35             150   0.0     caffeine
# 19             144   0.0     caffeine
# 25             140   0.0     caffeine
# 78             135   2.0      codeine
# 100            132   1.0      glucose
# 15             120   0.0     caffeine
# 65             120   0.0     caffeine
# 104            116   1.0      glucose
# ..             ...   ...          ...
# 39              28   2.0      codeine
# 76              27   0.0     caffeine
# 87              27   1.0      glucose
# 64              26   2.0      codeine
# 1               26   0.0     caffeine
# 106             26   3.0  paracetamol
# 99              24   1.0      glucose
# 108             24   3.0  paracetamol
# 79              24   1.0      glucose
# 7               23   0.0     caffeine
# 37              20   0.0     caffeine
# 103             20   1.0      glucose
# 36              18   0.0     caffeine
# 53              18   2.0      codeine
# 52              17   2.0      codeine
# 91              17   1.0      glucose
# 74              16   0.0     caffeine
# 46              13   2.0      codeine
# 41              12   2.0      codeine
# 40              12   2.0      codeine
# 31              10   0.0     caffeine
# 9               10   0.0     caffeine
# 57               9   2.0      codeine
# 30               6   0.0     caffeine
# 98               4   1.0      glucose
# 48               4   2.0      codeine
# 68               2   0.0     caffeine
# 107              0   1.0      glucose
# 63               0   2.0      codeine
# 0                0   NaN         None
#
# [113 rows x 16 columns]

# %%
studies_data = studies.data.sort_values(by=["label","name"])

# %% [markdown]
# ## 2. Build config files for circular plots

# %%
# for study data
create_config_files(studies_data, "circos/study_final")
# Out:
# /home/janekg89/Develop/Pycharm_Projects/pkdb_analysis/circos_utils.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   studies_data[["label","start","end","name"]].to_csv(f"{directory}/data/study_names.txt", sep=" ",header=False,index=False)
# /home/janekg89/Develop/Pycharm_Projects/pkdb_analysis/circos_utils.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # all subjects number for number track

# %%
for label, study_data_label in studies_data.groupby("label"):
    
    create_config_files(study_data_label, f"circos/study_{label}")
# Out:
# /home/janekg89/Develop/Pycharm_Projects/pkdb_analysis/circos_utils.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   #names 2d track
# /home/janekg89/Develop/Pycharm_Projects/pkdb_analysis/circos_utils.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   studies_data[["label","start","end","name"]].to_csv(f"{directory}/data/study_names.txt", sep=" ",header=False,index=False)
