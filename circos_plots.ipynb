# %%
import pandas as pd

from sklearn.preprocessing import Normalizer, MaxAbsScaler
from sklearn.cluster import AgglomerativeClustering

#my utils
from utils import  PkdbModel
from circos_utils import substance_cooccurrence_matrix \
    ,study_expand, bubbles_data, find_label, add_label_and_type, create_config_files, substance_combinations \
    ,create_ideogram, create_links
# Out:
# {'token': 'a94a309b0392aff5ed02b52a25ba44d7abd41aa6'}

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Configuration for Circular Plots
#
# This notebook creates the configuration files for the circular plots.
#
# Tasks performed by the notebook:
#
#  1. Classifies substances by co-occurrence in studies. Derived substances are replaced but their parents already by the database. Label for a class is chosen to be most frequent substance within a class.
#  2. Classifies studies into the same classes as substances. The most frequent class of substances used in a study is chosen to be the class of the study.
#  3. Builds configuration files for circus plots for:
#      1. Circular study plot with bars .  &rightarrow;  /circos/study/
#      2. Circular study plot with bubbles.   &rightarrow;  /circos/study1/
#      3. Circular plots with subset of study plots for each substance class. &rightarrow;  /circos/substance1/
#      4. Circular substance plots with co-occurrence links and bubbles. &rightarrow;  /circos/study_caffeine/ ...

# %% [markdown]
# ## 1. Classifies Substances and Studies

# %%
# load data
studies = PkdbModel("studies", destination="1-preprocessed") 
substances = PkdbModel("substances", destination="1-preprocessed") 
substances.read()
studies.read()

# %%
coocurence_matrix = substance_cooccurrence_matrix(studies.data, substances.data)
# Out:
# /home/janek/.virtualenvs/pkdb_analysis/lib/python3.6/site-packages/pandas/core/frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
norm_coocurence_matrix = Normalizer(norm="l2").fit_transform(coocurence_matrix)
norm_coocurence_matrix = pd.DataFrame(norm_coocurence_matrix, index=coocurence_matrix.index, columns=coocurence_matrix.columns)

# %%
classification_model = AgglomerativeClustering(linkage="single",n_clusters=4)
classes = classification_model.fit_predict(norm_coocurence_matrix.T.corr())

# %%
# Classfied substances into types
substance_to_type = pd.DataFrame(classes, index=norm_coocurence_matrix.index, columns=["type"]).to_dict()["type"]

studies.data, substances.data =  add_label_and_type(studies.data, substances.data, substance_to_type)

# %%
studies.data
# Out:
#                 name                                         substances  \
# 67       Loetsch2006  normorphine, morphine-6-glucuronide, morphine ...
# 157        Arias1988  2-dehydrosparteine, sparteine, sparteine sulfa...
# 54            IKP243                                           caffeine
# 33        Balogh1992                                           caffeine
# 58        Stille1987       ciprofloxacin, ofloxacin, enoxacin, caffeine
# 76          Yue1991B  normorphine, morphine-3-glucuronide, morphine-...
# 77            Wu2014  morphine-3-glucuronide, codeine, morphine, mor...
# 143         Chen1991  norcodeine-conjugates, morphine-3-glucuronide,...
# 75          Vree1992  normorphine, morphine-3-glucuronide, morphine-...
# 81         Yue1989-2  normorphine, morphine-3-glucuronide, morphine-...
# 112        Beach1986                               caffeine, disulfiram
# 129       McLean2002  theophylline, caffeine, theobromine, paraxanthine
# 38         Carbo1989  pipemidic acid, theophylline, paraxanthine, no...
# 4           Chan1997  paracetamol sulfate, paracetamol cysteine, par...
# 141      TangLiu1983  theophylline, paraxanthine, 1MX, 17MU, 7MU, 1M...
# 145       Caraco1996  normorphine, morphine-3-glucuronide, morphine-...
# 5       J B       J B, M K             6               10
# 23      M K       M K, K G             5               30
# 32      M K  M K, D E, J G             4               28
# 121     M K            M K             1               17
# 151     J G  M K, J G, D E             3               11
# 48      M K       M K, J G             2               12
# 42      M K  M K, D E, J G             1                4
# 137     M K            M K             3               12
# 132     M K            M K             3               12
# 140     J G  J G, M K, D E             1               12
# 114     M K  M K, D E, J G             1               12
# 28      M K       M K, J G             7               20
# 12      J B  M K, J B, J G             1                8
# ..      ...            ...           ...              ...
# 11      J B       J B, M K             3               24
# 49      M K       M K, J G             1               10
# 19      M K       M K, K G             1               17
# 116     M K  M K, D E, J G             9               44
# 133     M K            M K             5                8
# 153     J G       M K, J G             1                4
# 96      J B       J B, M K             1               12
# 150     J G       J G, M K             1               17
# 25      M K       M K, K G             1                6
# 152     J G  M K, D E, J G             1               10
# 74      J G       J G, M K             1               12
# 63      M K       M K, J G             1               12
# 43      M K       M K, J G             4               33
# 71      J G  M K, D E, J G             3               23
# 135     M K       M K, D E             1                6
# 80      J G       J G, M K             3              132
# 50      M K       M K, J G             2               12
# 128     M K            M K             0                0
# 45      M K            M K             0                0
# 92      J B            J B             0                0
# 36      M K       M K, K G             0                0
# 110     M K       M K, K G             0                0
# 35      M K       M K, K G             1                9
# 73      M K       M K, D E             0                0
# 118     M K       M K, D E             1                6
# 119     M K       M K, D E             0                0
# 155     M K       M K, D E             0                0
# 156     M K       M K, D E             0                0
# 72      M K       M K, D E             0                0
# 127     M K            M K             0                0
#
#                                                 groups  individuals_count  \
# 67                      [{'count': 11, 'name': 'all'}]                 11
# 157                    [{'count': 142, 'name': 'all'}]                142
# 54                     [{'count': 102, 'name': 'all'}]                102
# 33                      [{'count': 12, 'name': 'all'}]                 12
# 58                      [{'count': 12, 'name': 'all'}]                 12
# 76   [{'count': 20, 'name': 'all'}, {'count': 8, 'n...                 14
# 77   [{'count': 29, 'name': 'all'}, {'count': 10, '...                208
# 143  [{'count': 8, 'name': 'all'}, {'count': 2, 'na...                  8
# 75                       [{'count': 8, 'name': 'all'}]                  8
# 81   [{'count': 132, 'name': 'all'}, {'count': 18, ...                132
# 112  [{'count': 21, 'name': 'all'}, {'count': 10, '...                 21
# 129  [{'count': 14, 'name': 'all'}, {'count': 8, 'n...                  0
# 38                       [{'count': 6, 'name': 'all'}]                  6
# 4    [{'count': 38, 'name': 'all'}, {'count': 8, 'n...                  0
# 141                      [{'count': 6, 'name': 'all'}]                  6
# 145  [{'count': 16, 'name': 'all'}, {'count': 6, 'n...                 15
# 69                      [{'count': 13, 'name': 'all'}]                 13
# 5    [{'count': 10, 'name': 'all'}, {'count': 4, 'n...                  0
# 23   [{'count': 30, 'name': 'all'}, {'count': 11, '...                  0
# 32   [{'count': 28, 'name': 'all'}, {'count': 10, '...                 20
# 121                     [{'count': 17, 'name': 'all'}]                  0
# 151  [{'count': 11, 'name': 'all'}, {'count': 9, 'n...                  9
# 48   [{'count': 12, 'name': 'all'}, {'count': 12, '...                  0
# 42                       [{'count': 4, 'name': 'all'}]                  4
# 137  [{'count': 12, 'name': 'all'}, {'count': 6, 'n...                 12
# 132  [{'count': 12, 'name': 'all'}, {'count': 6, 'n...                 12
# 140                     [{'count': 12, 'name': 'all'}]                  0
# 114                     [{'count': 12, 'name': 'all'}]                 20
# 28   [{'count': 20, 'name': 'all'}, {'count': 10, '...                 40
# 12                       [{'count': 8, 'name': 'all'}]                  0
# ..                                                 ...                ...
# 11   [{'count': 24, 'name': 'all'}, {'count': 12, '...                  0
# 49                      [{'count': 10, 'name': 'all'}]                  0
# 19                      [{'count': 17, 'name': 'all'}]                  0
# 116  [{'count': 44, 'name': 'all'}, {'count': 21, '...                  0
# 133  [{'count': 8, 'name': 'all'}, {'count': 8, 'na...                  0
# 153                      [{'count': 4, 'name': 'all'}]                  4
# 96                      [{'count': 12, 'name': 'all'}]                  0
# 150                     [{'count': 17, 'name': 'all'}]                  0
# 25                       [{'count': 6, 'name': 'all'}]                  0
# 152                     [{'count': 10, 'name': 'all'}]                  0
# 74                      [{'count': 12, 'name': 'all'}]                  0
# 63                      [{'count': 12, 'name': 'all'}]                  0
# 43   [{'count': 33, 'name': 'all'}, {'count': 15, '...                  0
# 71   [{'count': 23, 'name': 'all'}, {'count': 11, '...                  0
# 135                      [{'count': 6, 'name': 'all'}]                  6
# 80   [{'count': 132, 'name': 'all'}, {'count': 18, ...                  0
# 50   [{'count': 12, 'name': 'all'}, {'count': 12, '...                  0
# 128                                                 []                  0
# 45                                                  []                  0
# 92                                                  []                  0
# 36                                                  []                  0
# 110                                                 []                  0
# 35                       [{'count': 9, 'name': 'all'}]                  0
# 73                                                  []                  0
# 118                      [{'count': 6, 'name': 'all'}]                  0
# 119                                                 []                  0
# 155                                                 []                  0
# 156                                                 []                  0
# 72                                                  []                  0
# 127                                                 []                  0
#
#                                            individuals  interventions_count  \
# 67   ['11', '10', '9', '8', '7', '6', '5', '4', '3'...                    2
# 157  ['203', '202', '201', '200', '199', '198', '19...                    1
# 54   ['IKP243-2079', 'IKP243-2075', 'IKP243-2074', ...                    1
# 33   ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', ...                    1
# 58   ['N', 'M', 'L', 'K', 'I', 'H', 'G', 'F', 'E', ...                   13
# 76   ['14_PM', '13_PM', '12_PM', '11_PM', '10_PM', ...                   11
# 77   ['8_10/10_M6G', '7_10/10_M6G', '6_10/10_M6G', ...                    1
# 143           ['8', '7', '6', '5', '4', '3', '2', '1']                    9
# 75            ['8', '7', '6', '5', '4', '3', '2', '1']                    1
# 81   ['132_EM', '131_EM', '130_EM', '129_EM', '128_...                    2
# 112  ['K', 'J', 'I', 'H', 'G', 'F', 'E', 'D', 'C', ...                    3
# 129                                                NaN                    1
# 38                      ['6', '5', '4', '3', '2', '1']                    3
# 4                                                  NaN                    1
# 141               ['MB', 'TK', 'JM', 'CC', 'SB', 'LR']                    2
# 145  ['6_PM', '5_PM', '4_PM', '3_PM', '2_PM', '1_PM...                    4
# 69   ['13', '12', '11', '10', '9', '8', '7', '6', '...                    2
# 5                                                  NaN                    2
# 23                                                 NaN                    1
# 32   ['1C', '2C', '3C', '4C', '5C', '6C', '7C', '8C...                    1
# 121                                                NaN                    6
# 151  ['PM2', 'PM1', 'EM7', 'EM6', 'EM5', 'EM4', 'EM...                    2
# 48                                                 NaN                   37
# 42                                ['A', 'B', 'C', 'D']                    5
# 137  ['12', '11', '10', '9', '8', '7', '6', '5', '4...                    2
# 132  ['12', '11', '10', '9', '8', '7', '6', '5', '4...                    1
# 140                                                NaN                    3
# 114  ['A9', 'A8', 'A7', 'A6', 'A5', 'A4', 'A3', 'A2...                    4
# 28   ['4', '5', '9', '10', '11', '12', '16', '17', ...                    4
# 12                                                 NaN                   24
# ..                                                 ...                  ...
# 11                                                 NaN                    1
# 49                                                 NaN                    4
# 19                                                 NaN                    1
# 116                                                NaN                    1
# 133                                                NaN                    2
# 153                               ['O', 'F', 'E', 'C']                    1
# 96                                                 NaN                    1
# 150                                                NaN                    1
# 25                                                 NaN                    1
# 152                                                NaN                    1
# 74                                                 NaN                    3
# 63                                                 NaN                    1
# 43                                                 NaN                    1
# 71                                                 NaN                    1
# 135                     ['6', '5', '4', '3', '2', '1']                    1
# 80                                                 NaN                    2
# 50                                                 NaN                   37
# 128                                                NaN                    0
# 45                                                 NaN                    0
# 92                                                 NaN                    0
# 36                                                 NaN                    0
# 110                                                NaN                    0
# 35                                                 NaN                    0
# 73                                                 NaN                    0
# 118                                                NaN                    0
# 119                                                NaN                    0
# 155                                                NaN                    0
# 156                                                NaN                    0
# 72                                                 NaN                    0
# 127                                                NaN                    0
#
#      outputs_count  outputs_calculated_count  timecourses_count  \
# 67             691                       691                132
# 157            568                         0                  0
# 54             510                         0                  0
# 33             363                       216                 72
# 58             432                         0                  0
# 76             413                        83                 11
# 77             379                        96                 12
# 143            360                        28                  4
# 75             306                        40                 14
# 81             301                         0                  0
# 112            281                        26                  4
# 129            196                       140                 32
# 38             210                        24                  3
# 4              193                       113                 16
# 141            182                       128                 16
# 145            179                        96                 12
# 69             184                        40                  5
# 5              156                        70                 20
# 23             139                       139                 33
# 32             164                        32                  6
# 121            160                        60                 10
# 151            139                       133                 25
# 48             160                         0                  0
# 42             143                       113                 16
# 137            156                        16                  2
# 132            144                        96                 12
# 140            146                        70                 10
# 114            150                        48                  6
# 28             150                         0                  0
# 12             140                        48                  8
# ..             ...                       ...                ...
# 11              20                         0                  0
# 49              20                         0                  0
# 19              16                        16                  3
# 116             18                         0                  0
# 133             16                         0                  0
# 153             12                        12                  4
# 96              15                         8                  1
# 150             12                         6                  2
# 25               8                         8                  4
# 152             12                         0                  0
# 74              10                         0                  0
# 63               8                         0                  2
# 43              10                         0                  0
# 71               2                         0                  4
# 135              6                         0                  0
# 80               2                         0                  0
# 50               2                         0                  0
# 128              0                         0                  0
# 45               0                         0                  0
# 92               0                         0                  0
# 36               0                         0                  0
# 110              0                         0                  0
# 35               0                         0                  0
# 73               0                         0                  0
# 118              0                         0                  0
# 119              0                         0                  0
# 155              0                         0                  0
# 156              0                         0                  0
# 72               0                         0                  0
# 127              0                         0                  0
#
#      results_count  type        label
# 67             823   2.0      codeine
# 157            568   2.0      codeine
# 54             510   0.0     caffeine
# 33             435   0.0     caffeine
# 58             432   0.0     caffeine
# 76             424   2.0      codeine
# 77             391   2.0      codeine
# 143            364   2.0      codeine
# 75             320   2.0      codeine
# 81             301   2.0      codeine
# 112            285   0.0     caffeine
# 129            228   0.0     caffeine
# 38             213   0.0     caffeine
# 4              209   1.0  paracetamol
# 141            198   0.0     caffeine
# 145            191   2.0      codeine
# 69             189   2.0      codeine
# 5              176   1.0  paracetamol
# 23             172   3.0      glucose
# 32             170   0.0     caffeine
# 121            170   0.0     caffeine
# 151            164   2.0      codeine
# 48             160   0.0     caffeine
# 42             159   0.0     caffeine
# 137            158   0.0     caffeine
# 132            156   0.0     caffeine
# 140            156   2.0      codeine
# 114            156   0.0     caffeine
# 28             150   0.0     caffeine
# 12             148   1.0  paracetamol
# ..             ...   ...          ...
# 11              20   1.0  paracetamol
# 49              20   0.0     caffeine
# 19              19   3.0      glucose
# 116             18   0.0     caffeine
# 133             16   0.0     caffeine
# 153             16   2.0      codeine
# 96              16   1.0  paracetamol
# 150             14   2.0      codeine
# 25              12   3.0      glucose
# 152             12   2.0      codeine
# 74              10   2.0      codeine
# 63              10   0.0     caffeine
# 43              10   0.0     caffeine
# 71               6   2.0      codeine
# 135              6   0.0     caffeine
# 80               2   2.0      codeine
# 50               2   0.0     caffeine
# 128              0   NaN         None
# 45               0   NaN         None
# 92               0   NaN         None
# 36               0   NaN         None
# 110              0   NaN         None
# 35               0   NaN         None
# 73               0   NaN         None
# 118              0   NaN         None
# 119              0   NaN         None
# 155              0   NaN         None
# 156              0   NaN         None
# 72               0   NaN         None
# 127              0   NaN         None
#
# [159 rows x 16 columns]

# %%
studies_data = studies.data.sort_values(by=["label","name"])

# %%
import numpy as np

# %%
studies_data["group_all_count"]= studies_data["group_all_count"].replace(np.nan, 0)
studies_data["group_all_count"]= studies_data["group_all_count"].astype(int)

# %% [markdown]
# ## 2. Build config files for circular plots

# %%
# for study data
create_config_files(studies_data, "circos/study_final")
# Out:
# /home/janek/Dev/pkdb_analysis/circos_utils.py:178: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data["start"] = range(0,len(data)*rows_per_study,rows_per_study)
# /home/janek/Dev/pkdb_analysis/circos_utils.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data["end"] = range(rows_per_study,(len(data)+1)*rows_per_study,rows_per_study)

# %%
studies_data
# Out:
#                 name                                         substances  \
# 34     Abernethy1985                                           caffeine
# 32     Akinyinka2000  theophylline, caffeine, theobromine, paraxanthine
# 29        Amchin1999  paraxanthine, 17U, 1X, AAMU, 1U, caffeine, ven...
# 30       Backman2008                             caffeine, paraxanthine
# 33        Balogh1992                                           caffeine
# 28        Balogh1995  levonorgestrel, ethinylestradiol, caffeine, ge...
# 113       Barnet1990              pipemidic acid, caffeine, norfloxacin
# 112        Beach1986                               caffeine, disulfiram
# 116        Begas2007          paraxanthine, 17U, AFMU, 1U, caffeine, 1X
# 117     Benowitz1995                             caffeine, paraxanthine
# 114     Benowitz2003  carbon monoxide, 6-hydroxychlorzoxazone, AAMU,...
# 111    Blanchard1982                                           caffeine
{'count': 12, 'name': 'all'}, {'count': 6, 'n...                 12
# 126  [{'count': 10, 'name': 'all'}, {'count': 10, '...                 20
# 122                     [{'count': 11, 'name': 'all'}]                 11
# 125  [{'count': 30, 'name': 'all'}, {'count': 15, '...                 30
# 120                      [{'count': 8, 'name': 'all'}]                  8
# 48   [{'count': 12, 'name': 'all'}, {'count': 12, '...                  0
# 50   [{'count': 12, 'name': 'all'}, {'count': 12, '...                  0
# ..                                                 ...                ...
# 86                       [{'count': 5, 'name': 'all'}]                  0
# 90                       [{'count': 6, 'name': 'all'}]                  0
# 87                      [{'count': 12, 'name': 'all'}]                  0
# 89                       [{'count': 6, 'name': 'all'}]                  6
# 15                       [{'count': 6, 'name': 'all'}]                  0
# 13   [{'count': 18, 'name': 'all'}, {'count': 12, '...                  0
# 14   [{'count': 16, 'name': 'all'}, {'count': 8, 'n...                 16
# 11   [{'count': 24, 'name': 'all'}, {'count': 12, '...                  0
# 10   [{'count': 23, 'name': 'all'}, {'count': 10, '...                 23
# 16                       [{'count': 6, 'name': 'all'}]                  0
# 17                       [{'count': 8, 'name': 'all'}]                  0
# 12                       [{'count': 8, 'name': 'all'}]                  0
# 98   [{'count': 10, 'name': 'all'}, {'count': 5, 'n...                 10
# 99                       [{'count': 8, 'name': 'all'}]                  0
# 93   [{'count': 10, 'name': 'all'}, {'count': 8, 'n...                  0
# 94   [{'count': 47, 'name': 'all'}, {'count': 19, '...                 47
# 96                      [{'count': 12, 'name': 'all'}]                  0
# 118                      [{'count': 6, 'name': 'all'}]                  0
# 119                                                 []                  0
# 45                                                  []                  0
# 72                                                  []                  0
# 73                                                  []                  0
# 92                                                  []                  0
# 127                                                 []                  0
# 128                                                 []                  0
# 110                                                 []                  0
# 155                                                 []                  0
# 156                                                 []                  0
# 36                                                  []                  0
# 35                       [{'count': 9, 'name': 'all'}]                  0
#
#                                            individuals  interventions_count  \
# 34   ['1', '2', '3', '4', '5', '6', '7', '8', '9', ...                    1
# 32   ['1C', '2C', '3C', '4C', '5C', '6C', '7C', '8C...                    1
# 29   ['1', '2', '3', '4', '5', '6', '7', '8', '9', ...                    2
# 30   ['1', '2', '3', '4', '5', '6', '7', '8', '9', ...                    1
# 33   ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', ...                    1
# 28   ['4', '5', '9', '10', '11', '12', '16', '17', ...                    4
# 113                     ['1', '2', '3', '4', '5', '6']                    3
# 112  ['K', 'J', 'I', 'H', 'G', 'F', 'E', 'D', 'C', ...                    3
# 116                                                NaN                    1
# 117                                                NaN                    4
# 114  ['A9', 'A8', 'A7', 'A6', 'A5', 'A4', 'A3', 'A2...                    4
# 111                                                NaN                    2
# 115                                                NaN                    2
# 42                                ['A', 'B', 'C', 'D']                    5
# 41   ['s5', 's4', 's3', 's2', 's1', 'ns5', 'ns4', '...                    1
# 38                      ['6', '5', '4', '3', '2', '1']                    3
# 37                                                 NaN                    1
# 40   ['13', '12', '11', '10', '9', '8', '7', '6', '...                    3
# 44                                    ['H.C.', 'F.M.']                    3
# 39                                                 NaN                    5
# 43                                                 NaN                    1
# 121                                                NaN                    6
# 124  ['NS12', 'NS11', 'NS10', 'NS9', 'NS8', 'NS7', ...                    1
# 123  ['12', '11', '10', '9', '8', '7', '6', '5', '4...                    2
# 126  ['10C', '9C', '8C', '7C', '6C', '5C', '4C', '3...                    2
# 122  ['11', '10', '9', '8', '7', '6', '5', '4', '3'...                    5
# 125  ['15', '14', '13', '12', '11', '10', '9', '8',...                    1
# 120           ['8', '7', '6', '5', '4', '3', '2', '1']                    1
# 48                                                 NaN                   37
# 50                                                 NaN                   37
# ..                                                 ...                  ...
# 86                                                 NaN                    3
# 90                                                 NaN                    1
# 87                                                 NaN                    2
# 89                      ['1', '2', '3', '4', '5', '6']                    1
# 15                                                 NaN                    3
# 13                                                 NaN                    4
# 14   ['Y1', 'Y2', 'Y3', 'Y4', 'Y5', 'Y6', 'Y7', 'Y8...                    1
# 11                                                 NaN                    1
# 10   ['1', '2', '3', '4', '5', '6', '7', '8', '9', ...                    1
# 16                                                 NaN                    4
# 17                                                 NaN                    6
# 12                                                 NaN                   24
# 98   ['patient1', 'patient2', 'patient3', 'patient4...                    3
# 99                                                 NaN                    3
# 93                                                 NaN                    2
# 94   ['Y1', 'Y2', 'Y3', 'Y4', 'Y5', 'Y6', 'Y7', 'Y8...                    1
# 96                                                 NaN                    1
# 118                                                NaN                    0
# 119                                                NaN                    0
# 45                                                 NaN                    0
# 72                                                 NaN                    0
# 73                                                 NaN                    0
# 92                                                 NaN                    0
# 127                                                NaN                    0
# 128                                                NaN                    0
# 110                                                NaN                    0
# 155                                                NaN                    0
# 156                                                NaN                    0
# 36                                                 NaN                    0
# 35                                                 NaN                    0
#
#      outputs_count  outputs_calculated_count  timecourses_count  \
# 34              64                         0                  0
# 32             164                        32                  6
# 29              72                        16                  2
# 30             140                         0                  0
# 33             363                       216                 72
# 28             150                         0                  0
# 113            120                         0                  0
# 112            281                        26                  4
# 116             18                         0                  0
# 117             34                        28                  8
# 114            150                        48                  6
# 111             82                        32                  4
# 115             23                        16                  2
# 42             143                       113                 16
# 41              54                         0                  0
# 38             210                        24                  3
# 37             130                        26                 16
# 40              87                         0                  0
# 44              60                         0                  0
# 39              51                        29                  6
# 43              10                         0                  0
# 121            160                        60                 10
# 124             26                         0                  0
# 123            104                         0                  0
# 126             64                         0                  0
# 122             33                         0                  0
# 125             62                         0                  0
# 120             62                         8                  1
# 48             160                         0                  0
# 50               2                         0                  0
# ..             ...                       ...                ...
# 86             101                        74                 11
# 90              28                        24                  3
# 87              91                        41                  6
# 89              68                        32                  4
# 15              39                        24                  3
# 13              66                         0                  0
# 14             108                         0                  0
# 11              20                         0                  0
# 10             122                        64                  9
# 16              41                        32                  4
# 17              60                        48                  6
# 12             140                        48                  8
# 98             104                        32                  4
# 99              24                        16                  4
# 93              19                        11                  2
# 94              74                         0                  0
# 96              15                         8                  1
# 118              0                         0                  0
# 119              0                         0                  0
# 45               0                         0                  0
# 72               0                         0                  0
# 73               0                         0                  0
# 92               0                         0                  0
# 127              0                         0                  0
# 128              0                         0                  0
# 110              0                         0                  0
# 155              0                         0                  0
# 156              0                         0                  0
# 36               0                         0                  0
# 35               0                         0                  0
#
#      results_count  type        label
# 34              64   0.0     caffeine
# 32             170   0.0     caffeine
# 29              74   0.0     caffeine
# 30             140   0.0     caffeine
# 33             435   0.0     caffeine
# 28             150   0.0     caffeine
# 113            120   0.0     caffeine
# 112            285   0.0     caffeine
# 116             18   0.0     caffeine
# 117             42   0.0     caffeine
# 114            156   0.0     caffeine
# 111             86   0.0     caffeine
# 115             25   0.0     caffeine
# 42             159   0.0     caffeine
# 41              54   0.0     caffeine
# 38             213   0.0     caffeine
# 37             146   0.0     caffeine
# 40              87   0.0     caffeine
# 44              60   0.0     caffeine
# 39              57   0.0     caffeine
# 43              10   0.0     caffeine
# 121            170   0.0     caffeine
# 124             26   0.0     caffeine
# 123            104   0.0     caffeine
# 126             64   0.0     caffeine
# 122             33   0.0     caffeine
# 125             62   0.0     caffeine
# 120             63   0.0     caffeine
# 48             160   0.0     caffeine
# 50               2   0.0     caffeine
# ..             ...   ...          ...
# 86             112   1.0  paracetamol
# 90              31   1.0  paracetamol
# 87              97   1.0  paracetamol
# 89              72   1.0  paracetamol
# 15              42   1.0  paracetamol
# 13              66   1.0  paracetamol
# 14             108   1.0  paracetamol
# 11              20   1.0  paracetamol
# 10             131   1.0  paracetamol
# 16              45   1.0  paracetamol
# 17              66   1.0  paracetamol
# 12             148   1.0  paracetamol
# 98             108   1.0  paracetamol
# 99              28   1.0  paracetamol
# 93              21   1.0  paracetamol
# 94              74   1.0  paracetamol
# 96              16   1.0  paracetamol
# 118              0   NaN         None
# 119              0   NaN         None
# 45               0   NaN         None
# 72               0   NaN         None
# 73               0   NaN         None
# 92               0   NaN         None
# 127              0   NaN         None
# 128              0   NaN         None
# 110              0   NaN         None
# 155              0   NaN         None
# 156              0   NaN         None
# 36               0   NaN         None
# 35               0   NaN         None
#
# [159 rows x 16 columns]

# %%
for label, study_data_label in studies_data.groupby("label"):
    create_config_files(study_data_label, f"circos/study_{label}")

# %%
# testing for substances

# %%
frames = []
for substance, data in substances.data.sort_values("label").groupby("label"):
    data["start"] = range(len(data)) 
    data["end"] = range(1,len(data)+1) 
    frames.append(data)
substances_data = pd.concat(frames)
# Out:
# /home/janek/.virtualenvs/pkdb_analysis/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/janek/.virtualenvs/pkdb_analysis/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
#substances_data

# %%
len(substances_data)
# Out:
# 106

# %%
unused_substances = substances_data[ (substances_data["study_number"]<2) | ((substances_data["intervention_number"]==0) & (substances_data["timecourse_number"] == 0)  & (substances_data["output_number"] == 0))]["name"]

# %%
substances_data = substances_data[ ~((substances_data["study_number"]<2) | ( (substances_data["intervention_number"]==0) & (substances_data["timecourse_number"] == 0)  & (substances_data["output_number"] == 0)))]

# %%
len(substances_data)
# Out:
# 61

# %%
list(unused_substances)
# Out:
# ['AFMU',
#  'glycerol',
#  '137MU',
#  'silexan',
#  'carbon monoxide',
#  'chlorzoxazone',
#  'digoxin',
#  'disulfiram',
#  'ethinylestradiol',
#  'metropolol',
#  'lomefloxacin',
#  'levonorgestrel',
#  'indocyanine green',
#  'gestodene',
#  'grapefruit juice',
#  'L-ascorbic acid',
#  'venlafaxine',
#  'tolbutamide',
#  '17MU',
#  '6-hydroxychlorzoxazone',
#  '4-hydroxydebrisoquine',
#  'mephenytoin',
#  'sulfapyridine',
#  'sulfasalazine',
#  '5-dehydrosparteine',
#  'normorphine-glucuronide',
#  '2-dehydrosparteine',
#  'norcodeine-conjugates',
#  'diclofenac',
#  '[6-3H]glucose',
#  '[U-13C]glucose',
#  'exenatide',
#  '[3-OMG]glucose',
#  'lactate',
#  '[2-3H]glucose',
#  'GLP-1',
#  'GIP',
#  'nizatidine',
#  'propanolol',
#  'propacetamol',
#  'sorbitol',
#  'imatinib',
#  'sulfinpyrazone',
#  'panadol extend',
#  'watercress']

# %%
all_links = create_links(substances_data,studies_data,list(unused_substances))

# %%
length = pd.DataFrame()
length["substance_links"] = all_links["substance1_start"].append(all_links["substance2_start"])
length["label"] = all_links["substance1_label"].append(all_links["substance2_label"])

# %%
frames = []
for label, data_label in length.groupby(["label"]):
    start = 0 
    
    
    for substance_link, substance_linkpositions in data_label.groupby(["substance_links"]):    
        label_position = pd.Series()
        label_position["start"] = start
        label_position["end"] = start + len(substance_linkpositions)
        label_position["label"]  = label
        label_position["substance_number"]  = substance_link

        frames.append(label_position)
        start = label_position["end"] + 1
res = pd.concat(frames, axis=1).T

# %%
substances_data["start"]
# Out:
# 29      0
# 16      1
# 10      2
# 5       3
# 50      4
# 15      6
# 2       7
# 6       8
# 17      9
# 104    11
# 4      12
# 63     13
# 45     14
# 13     15
# 49     16
# 79     17
# 76     36
# 0      37
# 101    38
# 80     39
# 40     40
# 8      41
# 7      42
# 89     43
# 41     44
# 88     45
# 66     46
# 33     47
# 100    48
# 77      0
#        ..
# 74      4
# 37      5
# 67      7
# 70      9
# 69     10
# 39     11
# 36     12
# 95     15
# 96     16
# 68     18
# 72     19
# 34     22
# 92     23
# 59      1
# 53      4
# 56      7
# 52      8
# 75      9
# 46     11
# 19     12
# 38     15
# 28     16
# 27      0
# 82      1
# 85      2
# 86      4
# 32      5
# 87      6
# 84     11
# 83     14
# Name: start, Length: 61, dtype: int64

# %%
res["substance_number"] = res["substance_number"].astype(int)

# %%
substance_data = pd.merge(res,substances_data[["name","label","start","study_number","timecourse_number","output_number","output_raw_number","output_calculated_number","intervention_number"]],left_on=["label","substance_number"], right_on = ["label","start"])
substance_data["start"] = substance_data["start_x"]

# %%
links_new = pd.merge(all_links, substance_data[["start","end","start_y","label"]], left_on=["substance1_label","substance1_start"], right_on = [ "label","start_y"])
links_new[["substance1_start","substance1_end"]] = links_new[["start","end"]]
links_new = pd.merge(links_new, substance_data[["start","end","start_y","label"]], left_on=["substance2_label","substance2_start"], right_on = [ "label","start_y"])
links_new[["substance2_start","substance2_end"]] = links_new[["start_y","end_y"]]

# %%
all_links = links_new[["substance1_label","substance1_start" ,"substance1_end", "substance2_label","substance2_start" ,"substance2_end"]]

# %%
frames = []
for (label,start), data in all_links.groupby(["substance1_label","substance1_start"]):
    data["substance1_start"] = start + range(len(data))
    data["substance1_end"] = data["substance1_start"] + 1
    data["substance1_label"] = label

    frames.append(data)
    
all_links = pd.concat(frames)
# Out:
# /home/janek/.virtualenvs/pkdb_analysis/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/janek/.virtualenvs/pkdb_analysis/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/janek/.virtualenvs/pkdb_analysis/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
frames = []
for (label,end), data in all_links.groupby(["substance2_label","substance2_end"]):
    data["substance2_end"] = end - range(len(data)) 
    data["substance2_start"] = data["substance2_end"] - 1
    data["substance2_label"] = label

    frames.append(data)
    
all_links = pd.concat(frames)
# Out:
# /home/janek/.virtualenvs/pkdb_analysis/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/janek/.virtualenvs/pkdb_analysis/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/janek/.virtualenvs/pkdb_analysis/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
all_links.to_csv("circos/substance_final/data/links.txt", sep=" ",header=False,index=False)

# %%
ideogram = pd.DataFrame(res.sort_values("label").groupby(["label"]).apply(lambda x:  x["end"].max()),columns = ["len"])
ideogram["label"] = ideogram.index

# %%
ideogram
# Out:
#               len        label
# label
# caffeine      873     caffeine
# codeine      1163      codeine
# glucose       302      glucose
# paracetamol   247  paracetamol

# %%
ticks_dict = {}
for label, data in substance_data.groupby("label"):
    mystring = ""
    for x in list(data["start"]):
        mystring += f"{x}u, "
    data["end"].max()
    mystring += f"{data['end'].max()}u"
    ticks_dict[label]=mystring

# %%
from pprint import pprint
pprint(ticks_dict)
# Out:
# {'caffeine': '0u, 134u, 153u, 172u, 191u, 200u, 219u, 238u, 257u, 267u, 276u, '
#              '291u, 316u, 331u, 356u, 375u, 390u, 410u, 429u, 477u, 513u, '
#              '560u, 584u, 602u, 622u, 656u, 765u, 803u, 820u, 873u',
#  'codeine': '0u, 88u, 210u, 292u, 412u, 553u, 672u, 788u, 845u, 851u, 871u, '
#             '887u, 895u, 1006u, 1149u, 1163u',
#  'glucose': '0u, 55u, 114u, 139u, 185u, 203u, 228u, 245u, 270u, 302u',
#  'paracetamol': '0u, 8u, 69u, 77u, 103u, 109u, 161u, 213u, 247u'}

# %%
directory = "circos/substance_final"
with open(f"{directory}/data/ideogram.txt","w") as f:
        number = 0
        for idx, substance in ideogram.iterrows():

            number = number + 1
            #color_mapping[substance.label] = f"fill_color=spectral-5-div-{number}"
            f.write(f"chr - {substance.label} {substance.label} 0 {substance.len} pastel2-6-qual-{number}\n")

# %%
#names 2d track
substance_data["name"] = substance_data["name"].apply(lambda x: x.replace(" ","&nbsp;"))
substance_data[["label","start","end","name"]].to_csv(f"{directory}/data/substance_names.txt", sep=" ",header=False,index=False)
# all subjects number for number track
substance_data[["label","start","end","study_number"]].to_csv(f"{directory}/data/study_number.txt", sep=" ",header=False,index=False)
substance_data[["label","start","end","timecourse_number"]].to_csv(f"{directory}/data/timecourse_number.txt", sep=" ",header=False,index=False)
substance_data[["label","start","end","output_number"]].to_csv(f"{directory}/data/output_number.txt", sep=" ",header=False,index=False)
substance_data[["label","start","end","intervention_number"]].to_csv(f"{directory}/data/intervention_number.txt", sep=" ",header=False,index=False)

bubbles_data_dict = bubbles_data(substance_data,25,"substance")
for name, data in bubbles_data_dict.items():
        data[["label","start","end","type","circle_type"]].to_csv(f"{directory}/data/{name}_bubble.txt", sep=" ",header=False,index=False)

# %%
#old stlye write upper part into utlis !

#create_config_files(substances_data, "circos/substance_final", "substance")
#create_links(substances_data,studies_data).to_csv("circos/substance_final/data/links.txt", sep=" ",header=False,index=False)

# %%
#create_links(substances_data,studies_data)
