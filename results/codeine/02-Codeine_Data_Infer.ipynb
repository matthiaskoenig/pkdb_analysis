# %%
from utils import PkdbModel,measurement_type_data, filter_out, convert_unit
from collections import namedtuple
import pandas as pd
from IPython.display import display, HTML

def multi_table(table_list):
    ''' Acceps a list of IpyTable objects and returns a table which contains each IpyTable in a cell    '''
    return HTML(
         '<table><tr style="background-color:white;">' +
         ''.join(['<td>' + table._repr_html_() + '</td>' for table in table_list]) +
         '</tr></table>'
     )

# %%
def codeine_n_idx(data):
    return (data.substance_intervention == 'codeine phosphate') \
           & (data.substance == 'codeine') \
           & (data['tissue'] == 'plasma')

# %%
def all_codeine_idx(data, substance="codeine"):
     return ((data.substance_intervention == 'codeine phosphate') \
           |(data.substance_intervention == 'codeine sulphate') \
           |(data.substance_intervention == 'codeine')) \
           & (data["substance"] == substance) \
           & (data['tissue'] == 'plasma')

# %%
Inference = namedtuple("Inference",["name","filter_out","measurement_type"])
def inferences(substance):
        return [
    Inference(
        name=f"{substance}_clearance",
        filter_out= {"unit":[ 'microgram * milliliter / hour / micromole']},
        measurement_type = "clearance",
    ),
    Inference(
        name=f"{substance}_timecourse",
        filter_out= {"unit":["mole / liter"]},
        measurement_type = "concentration"
    ),
    Inference(
        name=f"{substance}_thalf",
        filter_out= {},
        measurement_type = "thalf"
    ), 
    Inference(
        name=f"{substance}_tmax",
        filter_out= {},
        measurement_type = "tmax"
    ),
    Inference(
        name=f"{substance}_vd",
        filter_out= {"unit":[ 'liter * milligram / millimole']},
        measurement_type = "vd"
    ),
     Inference(
        name=f"{substance}_auc_inf",
        filter_out= {},
        measurement_type = "auc_inf"
    ),
     Inference(
        name=f"{substance}_auc_end",
        filter_out= {},
        measurement_type = "auc_end"
    ),
    Inference(
        name=f"{substance}_kel",
        filter_out= {},
        measurement_type = "kel"
    ),
]

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
substances = ["codeine", "morphine", "codeine-6-glucuronide", "morphine-6-glucuronide", "morphine-3-glucuronide", "norcodeine", "normorphine"]

# %%
all_complete = PkdbModel("all_complete", destination="2-merged")
all_complete.read()
all_complete.to_numeric()

for substance in substances:
    complete_substance = all_complete.data.loc[all_codeine_idx(all_complete.data,substance)]
    complete_substance["inferred"] = False
    
    for inference in inferences(substance):
        print(inference.name)
        data = measurement_type_data(complete_substance,inference.measurement_type)
        data_class = PkdbModel(inference.name,destination="3-inferred")
        data_class.data = data
        [data_class.filter_out(k,v)for k,v in inference.filter_out.items()]
        data_class.infer_from_interventions()
        data_class.infer_from_outputs()
        data_class.save()

        t1 = pd.DataFrame(data_class.data.groupby(["unit", "unit_intervention"]).apply(len), columns=["count"])
        t2 = pd.DataFrame(data_class.data.groupby(["inferred"]).apply(len), columns=["count"])
        t3 = pd.DataFrame(data_class.data.groupby(["calculated"]).apply(len), columns=["count"])
        display(multi_table([t1,t2,t3]))
# Out:
# codeine_clearance
# /home/janekg/Env/pkdb_analysis/local/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">liter / hour</th>
#       <th>gram</th>
#       <td>72</td>
#     </tr>
#     <tr>
#       <th>gram / kilogram</th>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">liter / hour / kilogram</th>
#       <th>gram</th>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>gram / kilogram</th>
#       <td>50</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>72</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>150</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>118</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>104</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# codeine_timecourse
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">gram / kilogram / liter</th>
#       <th>gram</th>
#       <td>27</td>
#     </tr>
#     <tr>
#       <th>gram / kilogram</th>
#       <td>27</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">gram / liter</th>
#       <th>gram</th>
#       <td>48</td>
#     </tr>
#     <tr>
#       <th>gram / kilogram</th>
#       <td>27</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>48</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>81</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# codeine_thalf
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">hour / kilogram</th>
#       <th>gram</th>
#       <td>56</td>
#     </tr>
#     <tr>
#       <th>gram / kilogram</th>
#       <td>56</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">hour</th>
#       <th>gram</th>
#       <td>93</td>
#     </tr>
#     <tr>
#       <th>gram / kilogram</th>
#       <td>56</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>93</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>168</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>157</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>104</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# codeine_tmax
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">hour / kilogram</th>
#       <th>gram</th>
#       <td>47</td>
#     </tr>
#     <tr>
#       <th>gram / kilogram</th>
#       <td>47</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">hour</th>
#       <th>gram</th>
#       <td>84</td>
#     </tr>
#     <tr>
#       <th>gram / kilogram</th>
#       <td>47</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>84</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>141</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>116</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>109</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# codeine_vd
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">liter</th>
#       <th>gram</th>
#       <td>40</td>
#     </tr>
#     <tr>
#       <th>gram / kilogram</th>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">liter / kilogram</th>
#       <th>gram</th>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>gram / kilogram</th>
#       <td>23</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>69</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>104</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# codeine_auc_inf
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">gram * hour / kilogram / liter</th>
#       <th>gram</th>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>gram / kilogram</th>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">gram * hour / liter</th>
#       <th>gram</th>
#       <td>67</td>
#     </tr>
#     <tr>
#       <th>gram / kilogram</th>
#       <td>35</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>67</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>105</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>76</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>96</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# codeine_auc_end
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">gram * hour / kilogram / liter</th>
#       <th>gram</th>
#       <td>26</td>
#     </tr>
#     <tr>
#       <th>gram / kilogram</th>
#       <td>26</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">gram * hour / liter</th>
#       <th>gram</th>
#       <td>79</td>
#     </tr>
#     <tr>
#       <th>gram / kilogram</th>
#       <td>26</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>79</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>78</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>56</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>101</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# codeine_kel
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">1 / kilogram / minute</th>
#       <th>gram</th>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>gram / kilogram</th>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">1 / minute</th>
#       <th>gram</th>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th>gram / kilogram</th>
#       <td>23</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>69</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>104</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# morphine_clearance
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">liter / hour / kilogram</th>
#       <th>g/kg</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">liter / hour</th>
#       <th>g/kg</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>31</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>31</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>39</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>57</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# morphine_timecourse
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">gram / kilogram / liter</th>
#       <th>g/kg</th>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">gram / liter</th>
#       <th>g/kg</th>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>37</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>37</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>57</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# morphine_thalf
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">hour / kilogram</th>
#       <th>g/kg</th>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">hour</th>
#       <th>g/kg</th>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>37</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>37</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>42</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>61</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# morphine_tmax
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">hour / kilogram</th>
#       <th>g/kg</th>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">hour</th>
#       <th>g/kg</th>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>44</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>44</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>51</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>74</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# morphine_vd
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">liter</th>
#       <th>g/kg</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">liter / kilogram</th>
#       <th>g/kg</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>12</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>26</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>33</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>57</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# morphine_auc_inf
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">gram * hour / kilogram / liter</th>
#       <th>g/kg</th>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">gram * hour / liter</th>
#       <th>g/kg</th>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>35</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>42</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>56</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# morphine_auc_end
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">gram * hour / kilogram / liter</th>
#       <th>g/kg</th>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">gram * hour / liter</th>
#       <th>g/kg</th>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>66</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>66</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>45</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>42</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>69</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# morphine_kel
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">1 / kilogram / minute</th>
#       <th>g/kg</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">1 / minute</th>
#       <th>g/kg</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>26</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>26</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>36</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>61</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# codeine-6-glucuronide_clearance
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">liter / hour / kilogram</th>
#       <th>g/kg</th>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">liter / hour</th>
#       <th>g/kg</th>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>22</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>54</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>68</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# codeine-6-glucuronide_timecourse
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">gram / kilogram / liter</th>
#       <th>g/kg</th>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">gram / liter</th>
#       <th>g/kg</th>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>23</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>57</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# codeine-6-glucuronide_thalf
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">hour / kilogram</th>
#       <th>g/kg</th>
#       <td>29</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>29</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">hour</th>
#       <th>g/kg</th>
#       <td>29</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>46</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>87</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>65</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>68</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# codeine-6-glucuronide_tmax
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">hour / kilogram</th>
#       <th>g/kg</th>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">hour</th>
#       <th>g/kg</th>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>35</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>57</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>68</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# codeine-6-glucuronide_vd
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">liter / kilogram</th>
#       <th>g/kg</th>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">liter</th>
#       <th>g/kg</th>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>20</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>48</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>True</th>
#       <td>68</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# codeine-6-glucuronide_auc_inf
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">gram * hour / kilogram / liter</th>
#       <th>g/kg</th>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">gram * hour / liter</th>
#       <th>g/kg</th>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>42</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>42</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>90</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>64</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>68</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# codeine-6-glucuronide_auc_end
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">gram * hour / kilogram / liter</th>
#       <th>g/kg</th>
#       <td>17</td>
#     </tr>
# ...
#       <th>g/kg</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>27</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>True</th>
#       <td>38</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# normorphine_timecourse
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">gram / kilogram / liter</th>
#       <th>g/kg</th>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">gram / liter</th>
#       <th>g/kg</th>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>15</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>45</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# </div></td></tr></table>
# normorphine_thalf
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">hour / kilogram</th>
#       <th>g/kg</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">hour</th>
#       <th>g/kg</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>15</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>30</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>38</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# normorphine_tmax
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">hour / kilogram</th>
#       <th>g/kg</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">hour</th>
#       <th>g/kg</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>17</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>36</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>51</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# normorphine_vd
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">liter / kilogram</th>
#       <th>g/kg</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">liter</th>
#       <th>g/kg</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>27</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>True</th>
#       <td>38</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# normorphine_auc_inf
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">gram * hour / kilogram / liter</th>
#       <th>g/kg</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">gram * hour / liter</th>
#       <th>g/kg</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>15</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>33</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>38</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# normorphine_auc_end
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">gram * hour / kilogram / liter</th>
#       <th>g/kg</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">gram * hour / liter</th>
#       <th>g/kg</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>16</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>33</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>47</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# normorphine_kel
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">1 / kilogram / minute</th>
#       <th>g/kg</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">1 / minute</th>
#       <th>g/kg</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>gram</th>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>27</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>True</th>
#       <td>38</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
