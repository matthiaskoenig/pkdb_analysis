# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
from utils import PkdbModel, paraxanthine_idx, measurement_type_data, filter_out, convert_unit, unstring, to_numeric
plt.style.use('seaborn-whitegrid')
import numpy as np
from collections import namedtuple

# %%
from IPython.display import display, HTML

def multi_table(table_list):
    ''' Acceps a list of IpyTable objects and returns a table which contains each IpyTable in a cell    '''
    return HTML(
         '<table><tr style="background-color:white;">' +
         ''.join(['<td>' + table._repr_html_() + '</td>' for table in table_list]) +
         '</tr></table>'
     )

# %%
# %load_ext autoreload
# %autoreload 2

# %%
all_complete = PkdbModel("all_complete", destination="2-merged")
all_complete.read()
all_complete.to_numeric()
all_complete.data.loc[(all_complete.data[("sex","choice")] == "M"),("oral contraceptives","choice")] = "N"
complete_paraxanthine = all_complete.data[paraxanthine_idx(all_complete.data)]
# Out:
# /home/janekg89/Envs/pkdb_analysis/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2903: DtypeWarning: Columns (15,25,28,29,30,31,44,71,72,88,114,115,117,119,121,123,124,126,127,128,129,132,133,134,136,140,142,146,155,157,158,159,161,162,168,169,170,171,180,181,182,183,185,186,188,190,192,197,198,199,200,207,208,212,215,216,224,229,233,234,239,243) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
Inference = namedtuple("Inference",["name","filter_out","measurement_type"])

# %%
inferences = [
    Inference(
        name="paraxanthine_clearance",
        filter_out= {},
        measurement_type = "clearance",
    ),
    Inference(
        name="paraxanthine_timecourse",
        filter_out= {},
        measurement_type = "concentration"
    ),
    Inference(
        name="paraxanthine_thalf",
        filter_out= {},
        measurement_type = "thalf"
    ), 
    Inference(
        name="paraxanthine_tmax",
        filter_out= {},
        measurement_type = "tmax"
    ),
    Inference(
        name="paraxanthine_vd",
        filter_out= {},
        measurement_type = "vd"
    ),
     Inference(
        name="paraxanthine_auc_inf",
        filter_out= {},
        measurement_type = "auc_inf"
    ),
     Inference(
        name="paraxanthine_auc_end",
        filter_out= {},
        measurement_type = "auc_end"
    ),
    Inference(
        name="paraxanthine_kel",
        filter_out= {},
        measurement_type = "kel"
    ),
]

# %%
for inference in inferences:
    print(inference.name)
    data = measurement_type_data(complete_paraxanthine,inference.measurement_type)
    data_class = PkdbModel(inference.name,destination="3-inferred")
    data_class.data = data
    [data_class.filter_out(k,v)for k,v in inference.filter_out.items()]
    data_class.infer_from_interventions()
    data_class.infer_from_outputs()
    data_class.save()

    t1 = pd.DataFrame(data_class.data.groupby(["unit", "unit_intervention"]).apply(len), columns=["count"])
    t2 = pd.DataFrame(data_class.data.groupby(["inferred"]).apply(len), columns=["count"])
    t3 = pd.DataFrame(data_class.data.groupby(["calculated"]).apply(len), columns=["count"])
    display(multi_table([t1,t2,t3]))
# Out:
# {'token': '55388d17d53f133a3f7eb7c69dd0874731fe3445'}
# paraxanthine_clearance
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">liter / hour</th>
#       <th>gram</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>gram / kilogram</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">liter / hour / kilogram</th>
#       <th>gram</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>gram / kilogram</th>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>27</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>True</th>
#       <td>40</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# paraxanthine_timecourse
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">gram / kilogram / liter</th>
#       <th>gram</th>
#       <td>31</td>
#     </tr>
#     <tr>
#       <th>gram / kilogram</th>
#       <td>31</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">gram / liter</th>
#       <th>gram</th>
#       <td>36</td>
#     </tr>
#     <tr>
#       <th>gram / kilogram</th>
#       <td>33</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>38</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>93</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>40</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# paraxanthine_thalf
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">hour / kilogram</th>
#       <th>gram</th>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>gram / kilogram</th>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">hour</th>
#       <th>gram</th>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>gram / kilogram</th>
#       <td>23</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>63</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>48</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>40</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# paraxanthine_tmax
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">hour / kilogram</th>
#       <th>gram</th>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>gram / kilogram</th>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">hour</th>
#       <th>gram</th>
#       <td>36</td>
#     </tr>
#     <tr>
#       <th>gram / kilogram</th>
#       <td>36</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>42</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>90</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>53</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>79</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# paraxanthine_vd
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">liter</th>
#       <th>gram</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>gram / kilogram</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">liter / kilogram</th>
#       <th>gram</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>gram / kilogram</th>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>27</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>True</th>
#       <td>40</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# paraxanthine_auc_inf
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">gram * hour / kilogram / liter</th>
#       <th>gram</th>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>gram / kilogram</th>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">gram * hour / liter</th>
#       <th>gram</th>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>gram / kilogram</th>
#       <td>21</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>57</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>44</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>36</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# paraxanthine_auc_end
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">gram * hour / kilogram / liter</th>
#       <th>gram</th>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>gram / kilogram</th>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">gram * hour / liter</th>
#       <th>gram</th>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>gram / kilogram</th>
#       <td>27</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>63</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>72</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
# paraxanthine_kel
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <th>unit_intervention</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">1 / kilogram / minute</th>
#       <th>gram</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>gram / kilogram</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">1 / minute</th>
#       <th>gram</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>gram / kilogram</th>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>inferred</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>27</td>
#     </tr>
#   </tbody>
# </table>
# </div></td><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>calculated</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>True</th>
#       <td>40</td>
#     </tr>
#   </tbody>
# </table>
# </div></td></tr></table>
